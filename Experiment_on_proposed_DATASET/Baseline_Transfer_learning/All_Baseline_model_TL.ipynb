# %% [markdown]
# # All Baseline Models — PyTorch (Proposed Dataset)
#
# **Run all cells top-to-bottom.**
# Dataset: `TRAIN_DIR` + `VAL_DIR` split into train/val/test.
# ImageNet pretrained weights used; only the last block of each model is fine-tuned.
# Class weights applied to `CrossEntropyLoss` to handle imbalance.
# All results (weights, history, test metrics, profile) saved to `Model/<ModelName>/`.
#
# | Cell | Content |
# |------|---------|
# | 1 | Imports & Device Setup |
# | 2 | Configuration, Data Loading & Class Weights |
# | 3 | Shared Utilities |
# | 4 | **ResNet50** |
# | 5 | **VGG16** |
# | 6 | **MobileNetV2** |
# | 7 | **InceptionV3** |
# | 8 | Final Summary |

# %%
import os, copy, json, time, warnings
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader
from PIL import Image
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import (accuracy_score, precision_score,
                             recall_score, f1_score, classification_report)

warnings.filterwarnings('ignore')

DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
if DEVICE.type == 'cuda':
    torch.backends.cudnn.benchmark = True

print(f'PyTorch     : {torch.__version__}')
print(f'Torchvision : {torchvision.__version__}')
print(f'Device      : {DEVICE}')
if DEVICE.type == 'cuda':
    print(f'GPU         : {torch.cuda.get_device_name(0)}')
    print(f'CUDA        : {torch.version.cuda}')
    print(f'Total VRAM  : {torch.cuda.get_device_properties(0).total_memory / 1024**3:.2f} GB')
# Out:
# PyTorch     : 2.5.1+cu121
# Torchvision : 0.20.1+cu121
# Device      : cuda
# GPU         : NVIDIA RTX 5000 Ada Generation
# CUDA        : 12.1
# Total VRAM  : 31.99 GB

# %%
# ── Hyper-parameters ──────────────────────────────────────────
BATCH_SIZE  = 64
IMAGE_SIZE  = (224, 224)
EPOCHS      = 50
RANDOM_SEED = 42

TRAIN_DIR  = r'..\Proposed_Dataset\train'
VAL_DIR    = r'..\Proposed_Dataset\validation'
OUTPUT_DIR = 'Model'
os.makedirs(OUTPUT_DIR, exist_ok=True)

torch.manual_seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)

print(f'Output directory : {os.path.abspath(OUTPUT_DIR)}')

# ── Load images from TRAIN_DIR and VAL_DIR ────────────────────
def load_filepaths_labels(directory):
    filepaths, labels = [], []
    for cls in sorted(os.listdir(directory)):
        cls_dir = os.path.join(directory, cls)
        if not os.path.isdir(cls_dir):
            continue
        for f in os.listdir(cls_dir):
            if f.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp')):
                filepaths.append(os.path.join(cls_dir, f))
                labels.append(cls)
    return filepaths, labels

fp_train, lb_train = load_filepaths_labels(TRAIN_DIR)
fp_val,   lb_val   = load_filepaths_labels(VAL_DIR)

# TRAIN_DIR → training set
df_train = pd.DataFrame({'filepath': fp_train, 'label': lb_train})
df_train = df_train.drop_duplicates(subset='filepath').reset_index(drop=True)

# VAL_DIR → 50/50 split into val and test
val_full_df = pd.DataFrame({'filepath': fp_val, 'label': lb_val})
val_full_df = val_full_df.drop_duplicates(subset='filepath').reset_index(drop=True)

df_val, df_test = train_test_split(
    val_full_df, test_size=0.50, shuffle=True,
    stratify=val_full_df['label'], random_state=123
)

# Derive class metadata
all_labels   = sorted(set(df_train['label'].unique()) | set(val_full_df['label'].unique()))
classes      = all_labels
class_to_idx = {c: i for i, c in enumerate(classes)}
NUM_CLASSES  = len(classes)

print(f'Train images     : {len(df_train)}')
print(f'Val images       : {len(df_val)}')
print(f'Test images      : {len(df_test)}')
print(f'Number of classes: {NUM_CLASSES}')
print(f'Class names      : {classes}')
print()
print('Train label distribution:')
print(df_train['label'].value_counts())
print(f'\nTrain : {len(df_train)}  |  Val : {len(df_val)}  |  Test : {len(df_test)}')

# ── Class weights ─────────────────────────────────────────────
y_train_encoded  = df_train['label'].map(class_to_idx).values
class_weights    = compute_class_weight(
    class_weight='balanced',
    classes=np.arange(NUM_CLASSES),
    y=y_train_encoded
)
class_weights_tensor = torch.tensor(class_weights, dtype=torch.float32)

print('Class weights:')
for cls, w in zip(classes, class_weights):
    print(f'  {cls:<25} : {w:.4f}')
# Out:
# Output directory : c:\Users\km1612\Documents\riceMobileNet\RiceMobileNet_final\RiceMobileNEt Code\Experiment_on_proposed_DATASET\Baseline_Transfer_learning\Model
# Train images     : 5603
# Val images       : 744
# Test images      : 745
# Number of classes: 6
# Class names      : ['bacterial_leaf_blight', 'brown_spot', 'healthy', 'leaf_blast', 'leaf_scald', 'narrow_brown_spot']
#
# Train label distribution:
# label
# brown_spot               1148
# leaf_blast               1016
# healthy                   972
# bacterial_leaf_blight     913
# leaf_scald                875
# narrow_brown_spot         679
# Name: count, dtype: int64
#
# Train : 5603  |  Val : 744  |  Test : 745
# Class weights:
#   bacterial_leaf_blight     : 1.0228
#   brown_spot                : 0.8134
#   healthy                   : 0.9607
#   leaf_blast                : 0.9191
#   leaf_scald                : 1.0672
#   narrow_brown_spot         : 1.3753

# %%
# =============================================================================
#  SHARED UTILITIES  (run once — used by every model below)
# =============================================================================

# ── Custom Dataset ────────────────────────────────────────────
class ImageDataFrameDataset(Dataset):
    def __init__(self, df, transform=None):
        self.df        = df.reset_index(drop=True)
        self.transform = transform
        self.encoded   = [class_to_idx[l] for l in self.df['label']]
    def __len__(self):
        return len(self.df)
    def __getitem__(self, idx):
        img = Image.open(self.df.iloc[idx]['filepath']).convert('RGB')
        if self.transform:
            img = self.transform(img)
        return img, self.encoded[idx]


# ── Normalization constants ───────────────────────────────────
IMAGENET_NORM = transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
MINUSONE_NORM = transforms.Normalize([0.5,   0.5,   0.5  ], [0.5,   0.5,   0.5  ])
IDENTITY_NORM = transforms.Normalize([0.0,   0.0,   0.0  ], [1.0,   1.0,   1.0  ])


# ── Early Stopping ────────────────────────────────────────────
class EarlyStopping:
    def __init__(self, patience=7):
        self.patience     = patience
        self.best_loss    = float('inf')
        self.counter      = 0
        self.best_weights = None
    def __call__(self, val_loss, model):
        if val_loss < self.best_loss:
            self.best_loss    = val_loss
            self.counter      = 0
            self.best_weights = copy.deepcopy(model.state_dict())
            return False
        self.counter += 1
        return self.counter >= self.patience
    def restore(self, model):
        if self.best_weights is not None:
            model.load_state_dict(self.best_weights)


# ── DataLoader factory ────────────────────────────────────────
def make_loaders(train_t, val_t, batch_size=BATCH_SIZE):
    pin = (DEVICE.type == 'cuda')
    train_loader = DataLoader(
        ImageDataFrameDataset(df_train, train_t),
        batch_size=batch_size, shuffle=True,  num_workers=0, pin_memory=pin)
    val_loader = DataLoader(
        ImageDataFrameDataset(df_val, val_t),
        batch_size=batch_size, shuffle=False, num_workers=0, pin_memory=pin)
    test_loader = DataLoader(
        ImageDataFrameDataset(df_test, val_t),
        batch_size=batch_size, shuffle=False, num_workers=0, pin_memory=pin)
    return train_loader, val_loader, test_loader


# ── Keras-style progress bar ──────────────────────────────────
def _bar(current, total, width=30):
    filled = int(width * current / total)
    return '=' * filled + '-' * (width - filled)


# ── Training Engine ───────────────────────────────────────────
def train_model(model, model_name, train_loader, val_loader):
    criterion = nn.CrossEntropyLoss(weight=class_weights_tensor.to(DEVICE), label_smoothing=0.1)
    optimizer = torch.optim.Adam(
        filter(lambda p: p.requires_grad, model.parameters()), lr=1e-5
    )
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, mode='min', patience=3, factor=0.5
    )
    scaler = torch.cuda.amp.GradScaler(enabled=(DEVICE.type == 'cuda'))
    es     = EarlyStopping(patience=7)

    history = {k: [] for k in [
        'loss', 'accuracy', 'precision', 'recall', 'f1',
        'val_loss', 'val_accuracy', 'val_precision', 'val_recall', 'val_f1'
    ]}

    n_batches = len(train_loader)

    print(f'\nModel  : {model_name}')
    print(f'Train batches : {n_batches}  |  Val batches : {len(val_loader)}')
    print(f'Device : {DEVICE}' + (
        f'  ({torch.cuda.get_device_name(0)})' if DEVICE.type == 'cuda' else ''))
    print('-' * 110)

    for epoch in range(1, EPOCHS + 1):
        # ── Train ──
        model.train()
        t0 = time.time()
        ep_loss = 0.0
        ep_preds, ep_labels = [], []

        for bi, (imgs, labels) in enumerate(train_loader, 1):
            imgs   = imgs.to(DEVICE,   non_blocking=True)
            labels = labels.to(DEVICE, non_blocking=True)

            optimizer.zero_grad(set_to_none=True)

            with torch.cuda.amp.autocast(enabled=(DEVICE.type == 'cuda')):
                out = model(imgs)
                if isinstance(out, torchvision.models.inception.InceptionOutputs):
                    out = out.logits
                loss = criterion(out, labels)

            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()

            ep_loss += loss.item() * imgs.size(0)
            ep_preds.extend(out.argmax(1).detach().cpu().numpy())
            ep_labels.extend(labels.detach().cpu().numpy())

            print(f'\rEpoch {epoch}/{EPOCHS} {bi}/{n_batches} [{_bar(bi, n_batches)}]',
                  end='', flush=True)

        # ── Train metrics ──
        tr_loss = ep_loss / len(train_loader.dataset)
        tr_acc  = accuracy_score(ep_labels, ep_preds)
        tr_prec = precision_score(ep_labels, ep_preds, average='weighted', zero_division=0)
        tr_rec  = recall_score(ep_labels,   ep_preds, average='weighted', zero_division=0)
        tr_f1   = f1_score(ep_labels,       ep_preds, average='weighted', zero_division=0)

        # ── Validate ──
        model.eval()
        vl_loss = 0.0
        vl_preds, vl_labels = [], []

        with torch.no_grad():
            for imgs, labels in val_loader:
                imgs   = imgs.to(DEVICE,   non_blocking=True)
                labels = labels.to(DEVICE, non_blocking=True)
                with torch.cuda.amp.autocast(enabled=(DEVICE.type == 'cuda')):
                    out = model(imgs)
                    if isinstance(out, torchvision.models.inception.InceptionOutputs):
                        out = out.logits
                    loss = criterion(out, labels)
                vl_loss += loss.item() * imgs.size(0)
                vl_preds.extend(out.argmax(1).cpu().numpy())
                vl_labels.extend(labels.cpu().numpy())

        vl_loss /= len(val_loader.dataset)
        vl_acc   = accuracy_score(vl_labels, vl_preds)
        vl_prec  = precision_score(vl_labels, vl_preds, average='weighted', zero_division=0)
        vl_rec   = recall_score(vl_labels,   vl_preds, average='weighted', zero_division=0)
        vl_f1    = f1_score(vl_labels,       vl_preds, average='weighted', zero_division=0)

        elapsed   = time.time() - t0
        step_time = elapsed / n_batches

        print(
            f'\rEpoch {epoch}/{EPOCHS} {n_batches}/{n_batches} [{"=" * 30}] - '
            f'{elapsed:.0f}s {step_time:.1f}s/step - '
            f'loss: {tr_loss:.4f} - accuracy: {tr_acc:.4f} - '
            f'precision: {tr_prec:.4f} - recall: {tr_rec:.4f} - f1: {tr_f1:.4f} - '
            f'val_loss: {vl_loss:.4f} - val_accuracy: {vl_acc:.4f} - '
            f'val_precision: {vl_prec:.4f} - val_recall: {vl_rec:.4f} - val_f1: {vl_f1:.4f}',
            flush=True
        )
        print()

        for key, val in [
            ('loss',          tr_loss), ('accuracy',      tr_acc),
            ('precision',     tr_prec), ('recall',        tr_rec),  ('f1',      tr_f1),
            ('val_loss',      vl_loss), ('val_accuracy',  vl_acc),
            ('val_precision', vl_prec), ('val_recall',    vl_rec),  ('val_f1',  vl_f1),
        ]:
            history[key].append(round(float(val), 6))

        scheduler.step(vl_loss)

        if es(vl_loss, model):
            print(f'  >> Early stopping at epoch {epoch}. '
                  f'Best val_loss = {es.best_loss:.4f}')
            break

    es.restore(model)
    return history


# ── Test Evaluation ───────────────────────────────────────────
def evaluate_on_test(model, test_loader):
    criterion = nn.CrossEntropyLoss(weight=class_weights_tensor.to(DEVICE), label_smoothing=0.1)
    model.eval()
    tl, tp, tg = 0.0, [], []
    with torch.no_grad():
        for imgs, labels in test_loader:
            imgs   = imgs.to(DEVICE,   non_blocking=True)
            labels = labels.to(DEVICE, non_blocking=True)
            with torch.cuda.amp.autocast(enabled=(DEVICE.type == 'cuda')):
                out = model(imgs)
                if isinstance(out, torchvision.models.inception.InceptionOutputs):
                    out = out.logits
                loss = criterion(out, labels)
            tl += loss.item() * imgs.size(0)
            tp.extend(out.argmax(1).cpu().numpy())
            tg.extend(labels.cpu().numpy())
    tl   /= len(test_loader.dataset)
    acc   = accuracy_score(tg, tp)
    prec  = precision_score(tg, tp, average='weighted', zero_division=0)
    rec   = recall_score(tg,   tp, average='weighted', zero_division=0)
    f1    = f1_score(tg,       tp, average='weighted', zero_division=0)
    print(f'\n{"=" * 60}')
    print('  TEST EVALUATION')
    print(f'{"=" * 60}')
    print(f'  loss      : {tl:.4f}')
    print(f'  accuracy  : {acc:.4f}')
    print(f'  precision : {prec:.4f}')
    print(f'  recall    : {rec:.4f}')
    print(f'  f1_score  : {f1:.4f}')
    print(f'{"=" * 60}')
    print()
    print('Classification Report:')
    print(classification_report(tg, tp, target_names=classes, digits=4))
    return {'test_loss': round(tl,6), 'test_accuracy': round(acc,6),
            'test_precision': round(prec,6), 'test_recall': round(rec,6),
            'test_f1': round(f1,6)}


# ── Model Profiling ───────────────────────────────────────────
def profile_model(model, model_name, model_dir):
    """Compute Total Params, Trainable Params, Disk Size, FLOPs, Inference time, FPS."""
    import time as _time

    # Params
    total_params     = sum(p.numel() for p in model.parameters())
    trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)

    # Disk size (from saved .pth)
    pth_path = os.path.join(model_dir, f'{model_name}_weights.pth')
    disk_mb  = os.path.getsize(pth_path) / (1024 ** 2) if os.path.exists(pth_path) else 0.0

    # FLOPs via torch.profiler (fallback: manual count with thop if available)
    dummy = torch.randn(1, 3, *IMAGE_SIZE).to(DEVICE)
    flops_g = 0.0
    try:
        from thop import profile as thop_profile
        macs, _ = thop_profile(model, inputs=(dummy,), verbose=False)
        flops_g = macs * 2 / 1e9   # MACs -> FLOPs (multiply by 2)
    except Exception:
        flops_g = float('nan')

    # Inference time & FPS (100 warm-up + 200 timed runs, batch=1)
    model.eval()
    with torch.no_grad():
        for _ in range(100):
            _ = model(dummy)
    if DEVICE.type == 'cuda':
        torch.cuda.synchronize()
    runs = 200
    t0 = _time.perf_counter()
    with torch.no_grad():
        for _ in range(runs):
            out = model(dummy)
            if isinstance(out, torchvision.models.inception.InceptionOutputs):
                out = out.logits
    if DEVICE.type == 'cuda':
        torch.cuda.synchronize()
    elapsed_s  = _time.perf_counter() - t0
    inf_ms     = (elapsed_s / runs) * 1000
    fps        = runs / elapsed_s

    profile = {
        'model':               model_name,
        'total_params_M':      round(total_params     / 1e6, 3),
        'trainable_params_M':  round(trainable_params / 1e6, 3),
        'disk_size_MB':        round(disk_mb,  2),
        'flops_G':             round(flops_g,  3) if not __import__('math').isnan(flops_g) else 'N/A',
        'inference_ms':        round(inf_ms,   3),
        'fps':                 round(fps,      2),
    }

    print(f'\n  {"─"*55}')
    print(f'  MODEL PROFILE : {model_name}')
    print(f'  {"─"*55}')
    print(f'  Total Params (M)      : {profile["total_params_M"]}')
    print(f'  Trainable Params (M)  : {profile["trainable_params_M"]}')
    print(f'  Disk Size (MB)        : {profile["disk_size_MB"]}')
    print(f'  FLOPs (G)             : {profile["flops_G"]}')
    print(f'  Inference (ms)        : {profile["inference_ms"]}')
    print(f'  FPS                   : {profile["fps"]}')
    print(f'  {"─"*55}\n')
    return profile


# ── Save utilities ────────────────────────────────────────────
def save_model_results(model, model_name, history, test_metrics, profile):
    """Save weights, history, test metrics, and profile into Model/<model_name>/ folder."""
    model_dir = os.path.join(OUTPUT_DIR, model_name)
    os.makedirs(model_dir, exist_ok=True)

    # Weights
    pth_path = os.path.join(model_dir, f'{model_name}_weights.pth')
    torch.save(model.state_dict(), pth_path)
    print(f'  Weights saved  ->  {pth_path}')

    # Training history
    hist_path = os.path.join(model_dir, f'{model_name}_history.json')
    with open(hist_path, 'w') as f:
        json.dump(history, f, indent=2)
    print(f'  History saved  ->  {hist_path}')

    # Test metrics
    test_path = os.path.join(model_dir, f'{model_name}_test_metrics.json')
    with open(test_path, 'w') as f:
        json.dump(test_metrics, f, indent=2)
    print(f'  Test metrics   ->  {test_path}')

    # Profile
    prof_path = os.path.join(model_dir, f'{model_name}_profile.json')
    with open(prof_path, 'w') as f:
        json.dump(profile, f, indent=2)
    print(f'  Profile saved  ->  {prof_path}')

    return model_dir


print('All shared utilities ready.')
# Out:
# All shared utilities ready.

# %%
# =============================================================================
#  MODEL 1 : ResNet50
# =============================================================================
print('=' * 70)
print('  MODEL: ResNet50')
print('=' * 70)

# ── Transforms ────────────────────────────────────────────────
resnet_train_t = transforms.Compose([
    transforms.Resize(IMAGE_SIZE),
    transforms.RandomRotation(25),
    transforms.RandomAffine(degrees=0, translate=(0.15, 0.15), shear=5.7),
    transforms.ToTensor(),
    IMAGENET_NORM,
])
resnet_val_t = transforms.Compose([
    transforms.Resize(IMAGE_SIZE),
    transforms.ToTensor(),
    IMAGENET_NORM,
])

resnet_train_loader, resnet_val_loader, resnet_test_loader = make_loaders(resnet_train_t, resnet_val_t)

# ── Architecture ──────────────────────────────────────────────
# weights=IMAGENET1K_V1  → ImageNet pretrained weights
# Freeze all pretrained layers first, then unfreeze layer4 (last residual block)
def build_resnet50(num_classes=NUM_CLASSES):
    model = torchvision.models.resnet50(
        weights=torchvision.models.ResNet50_Weights.IMAGENET1K_V1
    )

    # Freeze all pretrained layers first
    for p in model.parameters():
        p.requires_grad = False

    for p in model.layer4[-1].parameters():
        p.requires_grad = True

    model.fc = nn.Linear(model.fc.in_features, num_classes)

    return model

resnet_model = build_resnet50(NUM_CLASSES).to(DEVICE)
total_p     = sum(p.numel() for p in resnet_model.parameters())
trainable_p = sum(p.numel() for p in resnet_model.parameters() if p.requires_grad)
print(f'Total params     : {total_p:,}')
print(f'Trainable params : {trainable_p:,}')

resnet_history     = train_model(resnet_model, 'ResNet50', resnet_train_loader, resnet_val_loader)
resnet_test_metrics = evaluate_on_test(resnet_model, resnet_test_loader)

resnet_model_dir = save_model_results.__wrapped__ if hasattr(save_model_results, '__wrapped__') else None
resnet_model_dir = os.path.join(OUTPUT_DIR, 'ResNet50')
os.makedirs(resnet_model_dir, exist_ok=True)
torch.save(resnet_model.state_dict(), os.path.join(resnet_model_dir, 'ResNet50_weights.pth'))

resnet_profile = profile_model(resnet_model, 'ResNet50', resnet_model_dir)
save_model_results(resnet_model, 'ResNet50', resnet_history, resnet_test_metrics, resnet_profile)

del resnet_model, resnet_train_loader, resnet_val_loader, resnet_test_loader
if DEVICE.type == 'cuda': torch.cuda.empty_cache()
print('\nResNet50 done.\n')
# Out:
# ======================================================================
#   MODEL: ResNet50
# ======================================================================
# Total params     : 23,520,326
# Trainable params : 4,474,886
#
# Model  : ResNet50
# Train batches : 88  |  Val batches : 12
# Device : cuda  (NVIDIA RTX 5000 Ada Generation)
# --------------------------------------------------------------------------------------------------------------
# Epoch 1/50 88/88 [==============================] - 53s 0.6s/step - loss: 1.6450 - accuracy: 0.4380 - precision: 0.4321 - recall: 0.4380 - f1: 0.4265 - val_loss: 1.4934 - val_accuracy: 0.5444 - val_precision: 0.5588 - val_recall: 0.5444 - val_f1: 0.5288
#
# Epoch 2/50 88/88 [==============================] - 15s 0.2s/step - loss: 1.2964 - accuracy: 0.6655 - precision: 0.6797 - recall: 0.6655 - f1: 0.6565 - val_loss: 1.2149 - val_accuracy: 0.6384 - val_precision: 0.6625 - val_recall: 0.6384 - val_f1: 0.6272
#
# Epoch 3/50 88/88 [==============================] - 15s 0.2s/step - loss: 1.0498 - accuracy: 0.7585 - precision: 0.7702 - recall: 0.7585 - f1: 0.7541 - val_loss: 1.0398 - val_accuracy: 0.7204 - val_precision: 0.7366 - val_recall: 0.7204 - val_f1: 0.7133
#
# Epoch 4/50 88/88 [==============================] - 16s 0.2s/step - loss: 0.9029 - accuracy: 0.8115 - precision: 0.8206 - recall: 0.8115 - f1: 0.8087 - val_loss: 0.9398 - val_accuracy: 0.7715 - val_precision: 0.7777 - val_recall: 0.7715 - val_f1: 0.7686
#
# Epoch 5/50 88/88 [==============================] - 15s 0.2s/step - loss: 0.8063 - accuracy: 0.8551 - precision: 0.8585 - recall: 0.8551 - f1: 0.8535 - val_loss: 0.8607 - val_accuracy: 0.8051 - val_precision: 0.8132 - val_recall: 0.8051 - val_f1: 0.8044
#
# Epoch 6/50 88/88 [==============================] - 16s 0.2s/step - loss: 0.7431 - accuracy: 0.8785 - precision: 0.8822 - recall: 0.8785 - f1: 0.8777 - val_loss: 0.8190 - val_accuracy: 0.8212 - val_precision: 0.8305 - val_recall: 0.8212 - val_f1: 0.8214
#
# Epoch 7/50 88/88 [==============================] - 15s 0.2s/step - loss: 0.7009 - accuracy: 0.8993 - precision: 0.9012 - recall: 0.8993 - f1: 0.8986 - val_loss: 0.7939 - val_accuracy: 0.8347 - val_precision: 0.8477 - val_recall: 0.8347 - val_f1: 0.8357
#
# Epoch 8/50 88/88 [==============================] - 15s 0.2s/step - loss: 0.6720 - accuracy: 0.9167 - precision: 0.9174 - recall: 0.9167 - f1: 0.9162 - val_loss: 0.7697 - val_accuracy: 0.8495 - val_precision: 0.8599 - val_recall: 0.8495 - val_f1: 0.8507
#
# Epoch 9/50 88/88 [==============================] - 15s 0.2s/step - loss: 0.6549 - accuracy: 0.9204 - precision: 0.9213 - recall: 0.9204 - f1: 0.9201 - val_loss: 0.7454 - val_accuracy: 0.8602 - val_precision: 0.8709 - val_recall: 0.8602 - val_f1: 0.8612
#
# Epoch 10/50 88/88 [==============================] - 15s 0.2s/step - loss: 0.6396 - accuracy: 0.9254 - precision: 0.9261 - recall: 0.9254 - f1: 0.9251 - val_loss: 0.7222 - val_accuracy: 0.8683 - val_precision: 0.8770 - val_recall: 0.8683 - val_f1: 0.8690
#
# Epoch 11/50 88/88 [==============================] - 15s 0.2s/step - loss: 0.6236 - accuracy: 0.9356 - precision: 0.9363 - recall: 0.9356 - f1: 0.9354 - val_loss: 0.7088 - val_accuracy: 0.8763 - val_precision: 0.8861 - val_recall: 0.8763 - val_f1: 0.8777
#
# Epoch 12/50 88/88 [==============================] - 16s 0.2s/step - loss: 0.6140 - accuracy: 0.9424 - precision: 0.9432 - recall: 0.9424 - f1: 0.9422 - val_loss: 0.6984 - val_accuracy: 0.8790 - val_precision: 0.8869 - val_recall: 0.8790 - val_f1: 0.8796
#
# Epoch 13/50 88/88 [==============================] - 15s 0.2s/step - loss: 0.6042 - accuracy: 0.9434 - precision: 0.9437 - recall: 0.9434 - f1: 0.9432 - val_loss: 0.6888 - val_accuracy: 0.8844 - val_precision: 0.8916 - val_recall: 0.8844 - val_f1: 0.8854
#
# Epoch 14/50 88/88 [==============================] - 15s 0.2s/step - loss: 0.5873 - accuracy: 0.9541 - precision: 0.9544 - recall: 0.9541 - f1: 0.9540 - val_loss: 0.6816 - val_accuracy: 0.8911 - val_precision: 0.8986 - val_recall: 0.8911 - val_f1: 0.8920
#
# Epoch 15/50 88/88 [==============================] - 16s 0.2s/step - loss: 0.5820 - accuracy: 0.9529 - precision: 0.9531 - recall: 0.9529 - f1: 0.9527 - val_loss: 0.6641 - val_accuracy: 0.9086 - val_precision: 0.9146 - val_recall: 0.9086 - val_f1: 0.9094
#
# Epoch 16/50 88/88 [==============================] - 15s 0.2s/step - loss: 0.5776 - accuracy: 0.9584 - precision: 0.9588 - recall: 0.9584 - f1: 0.9583 - val_loss: 0.6498 - val_accuracy: 0.9140 - val_precision: 0.9170 - val_recall: 0.9140 - val_f1: 0.9141
#
# Epoch 17/50 88/88 [==============================] - 16s 0.2s/step - loss: 0.5695 - accuracy: 0.9584 - precision: 0.9587 - recall: 0.9584 - f1: 0.9583 - val_loss: 0.6453 - val_accuracy: 0.9234 - val_precision: 0.9267 - val_recall: 0.9234 - val_f1: 0.9238
#
# Epoch 18/50 88/88 [==============================] - 16s 0.2s/step - loss: 0.5681 - accuracy: 0.9584 - precision: 0.9587 - recall: 0.9584 - f1: 0.9583 - val_loss: 0.6315 - val_accuracy: 0.9301 - val_precision: 0.9327 - val_recall: 0.9301 - val_f1: 0.9304
#
# Epoch 19/50 88/88 [==============================] - 16s 0.2s/step - loss: 0.5612 - accuracy: 0.9634 - precision: 0.9636 - recall: 0.9634 - f1: 0.9633 - val_loss: 0.6323 - val_accuracy: 0.9261 - val_precision: 0.9288 - val_recall: 0.9261 - val_f1: 0.9263
#
# Epoch 20/50 88/88 [==============================] - 14s 0.2s/step - loss: 0.5574 - accuracy: 0.9636 - precision: 0.9637 - recall: 0.9636 - f1: 0.9635 - val_loss: 0.6190 - val_accuracy: 0.9341 - val_precision: 0.9354 - val_recall: 0.9341 - val_f1: 0.9344
#
# Epoch 21/50 88/88 [==============================] - 14s 0.2s/step - loss: 0.5503 - accuracy: 0.9707 - precision: 0.9707 - recall: 0.9707 - f1: 0.9707 - val_loss: 0.6179 - val_accuracy: 0.9328 - val_precision: 0.9343 - val_recall: 0.9328 - val_f1: 0.9328
#
# Epoch 22/50 88/88 [==============================] - 14s 0.2s/step - loss: 0.5510 - accuracy: 0.9668 - precision: 0.9669 - recall: 0.9668 - f1: 0.9667 - val_loss: 0.6165 - val_accuracy: 0.9395 - val_precision: 0.9418 - val_recall: 0.9395 - val_f1: 0.9398
#
# Epoch 23/50 88/88 [==============================] - 14s 0.2s/step - loss: 0.5460 - accuracy: 0.9704 - precision: 0.9704 - recall: 0.9704 - f1: 0.9703 - val_loss: 0.6076 - val_accuracy: 0.9382 - val_precision: 0.9406 - val_recall: 0.9382 - val_f1: 0.9386
#
# Epoch 24/50 88/88 [==============================] - 14s 0.2s/step - loss: 0.5442 - accuracy: 0.9688 - precision: 0.9688 - recall: 0.9688 - f1: 0.9687 - val_loss: 0.6025 - val_accuracy: 0.9422 - val_precision: 0.9436 - val_recall: 0.9422 - val_f1: 0.9424
#
# Epoch 25/50 88/88 [==============================] - 15s 0.2s/step - loss: 0.5358 - accuracy: 0.9718 - precision: 0.9719 - recall: 0.9718 - f1: 0.9717 - val_loss: 0.6000 - val_accuracy: 0.9476 - val_precision: 0.9488 - val_recall: 0.9476 - val_f1: 0.9478
#
# Epoch 26/50 88/88 [==============================] - 14s 0.2s/step - loss: 0.5364 - accuracy: 0.9739 - precision: 0.9741 - recall: 0.9739 - f1: 0.9739 - val_loss: 0.5973 - val_accuracy: 0.9462 - val_precision: 0.9472 - val_recall: 0.9462 - val_f1: 0.9463
#
# Epoch 27/50 88/88 [==============================] - 14s 0.2s/step - loss: 0.5333 - accuracy: 0.9763 - precision: 0.9763 - recall: 0.9763 - f1: 0.9762 - val_loss: 0.5961 - val_accuracy: 0.9503 - val_precision: 0.9517 - val_recall: 0.9503 - val_f1: 0.9505
#
# Epoch 28/50 88/88 [==============================] - 14s 0.2s/step - loss: 0.5339 - accuracy: 0.9714 - precision: 0.9715 - recall: 0.9714 - f1: 0.9714 - val_loss: 0.5916 - val_accuracy: 0.9530 - val_precision: 0.9540 - val_recall: 0.9530 - val_f1: 0.9530
#
# Epoch 29/50 88/88 [==============================] - 14s 0.2s/step - loss: 0.5243 - accuracy: 0.9797 - precision: 0.9797 - recall: 0.9797 - f1: 0.9796 - val_loss: 0.5882 - val_accuracy: 0.9543 - val_precision: 0.9553 - val_recall: 0.9543 - val_f1: 0.9544
#
# Epoch 30/50 88/88 [==============================] - 14s 0.2s/step - loss: 0.5270 - accuracy: 0.9763 - precision: 0.9763 - recall: 0.9763 - f1: 0.9762 - val_loss: 0.5717 - val_accuracy: 0.9610 - val_precision: 0.9616 - val_recall: 0.9610 - val_f1: 0.9611
#
# Epoch 31/50 88/88 [==============================] - 15s 0.2s/step - loss: 0.5261 - accuracy: 0.9789 - precision: 0.9790 - recall: 0.9789 - f1: 0.9789 - val_loss: 0.5741 - val_accuracy: 0.9556 - val_precision: 0.9560 - val_recall: 0.9556 - val_f1: 0.9557
#
# Epoch 32/50 88/88 [==============================] - 14s 0.2s/step - loss: 0.5254 - accuracy: 0.9770 - precision: 0.9771 - recall: 0.9770 - f1: 0.9769 - val_loss: 0.5698 - val_accuracy: 0.9583 - val_precision: 0.9588 - val_recall: 0.9583 - val_f1: 0.9583
#
# Epoch 33/50 88/88 [==============================] - 14s 0.2s/step - loss: 0.5205 - accuracy: 0.9784 - precision: 0.9785 - recall: 0.9784 - f1: 0.9784 - val_loss: 0.5693 - val_accuracy: 0.9570 - val_precision: 0.9573 - val_recall: 0.9570 - val_f1: 0.9569
#
# Epoch 34/50 88/88 [==============================] - 14s 0.2s/step - loss: 0.5212 - accuracy: 0.9811 - precision: 0.9811 - recall: 0.9811 - f1: 0.9811 - val_loss: 0.5661 - val_accuracy: 0.9597 - val_precision: 0.9601 - val_recall: 0.9597 - val_f1: 0.9596
#
# Epoch 35/50 88/88 [==============================] - 14s 0.2s/step - loss: 0.5177 - accuracy: 0.9811 - precision: 0.9810 - recall: 0.9811 - f1: 0.9810 - val_loss: 0.5607 - val_accuracy: 0.9624 - val_precision: 0.9628 - val_recall: 0.9624 - val_f1: 0.9623
#
# Epoch 36/50 88/88 [==============================] - 14s 0.2s/step - loss: 0.5172 - accuracy: 0.9807 - precision: 0.9807 - recall: 0.9807 - f1: 0.9807 - val_loss: 0.5598 - val_accuracy: 0.9610 - val_precision: 0.9614 - val_recall: 0.9610 - val_f1: 0.9610
#
# Epoch 37/50 88/88 [==============================] - 14s 0.2s/step - loss: 0.5158 - accuracy: 0.9807 - precision: 0.9807 - recall: 0.9807 - f1: 0.9807 - val_loss: 0.5569 - val_accuracy: 0.9651 - val_precision: 0.9654 - val_recall: 0.9651 - val_f1: 0.9650
#
# Epoch 38/50 88/88 [==============================] - 13s 0.2s/step - loss: 0.5119 - accuracy: 0.9855 - precision: 0.9856 - recall: 0.9855 - f1: 0.9855 - val_loss: 0.5537 - val_accuracy: 0.9664 - val_precision: 0.9667 - val_recall: 0.9664 - val_f1: 0.9664
#
# Epoch 39/50 88/88 [==============================] - 13s 0.2s/step - loss: 0.5136 - accuracy: 0.9807 - precision: 0.9807 - recall: 0.9807 - f1: 0.9807 - val_loss: 0.5566 - val_accuracy: 0.9637 - val_precision: 0.9640 - val_recall: 0.9637 - val_f1: 0.9637
#
# Epoch 40/50 88/88 [==============================] - 14s 0.2s/step - loss: 0.5133 - accuracy: 0.9809 - precision: 0.9809 - recall: 0.9809 - f1: 0.9809 - val_loss: 0.5549 - val_accuracy: 0.9651 - val_precision: 0.9655 - val_recall: 0.9651 - val_f1: 0.9650
#
# Epoch 41/50 88/88 [==============================] - 14s 0.2s/step - loss: 0.5116 - accuracy: 0.9839 - precision: 0.9840 - recall: 0.9839 - f1: 0.9839 - val_loss: 0.5537 - val_accuracy: 0.9664 - val_precision: 0.9667 - val_recall: 0.9664 - val_f1: 0.9664
#
# Epoch 42/50 88/88 [==============================] - 14s 0.2s/step - loss: 0.5081 - accuracy: 0.9818 - precision: 0.9818 - recall: 0.9818 - f1: 0.9817 - val_loss: 0.5494 - val_accuracy: 0.9677 - val_precision: 0.9682 - val_recall: 0.9677 - val_f1: 0.9677
#
# Epoch 43/50 88/88 [==============================] - 14s 0.2s/step - loss: 0.5076 - accuracy: 0.9832 - precision: 0.9832 - recall: 0.9832 - f1: 0.9832 - val_loss: 0.5453 - val_accuracy: 0.9651 - val_precision: 0.9655 - val_recall: 0.9651 - val_f1: 0.9650
#
# Epoch 44/50 88/88 [==============================] - 14s 0.2s/step - loss: 0.5027 - accuracy: 0.9857 - precision: 0.9857 - recall: 0.9857 - f1: 0.9857 - val_loss: 0.5487 - val_accuracy: 0.9718 - val_precision: 0.9719 - val_recall: 0.9718 - val_f1: 0.9717
#
# Epoch 45/50 88/88 [==============================] - 14s 0.2s/step - loss: 0.5031 - accuracy: 0.9848 - precision: 0.9848 - recall: 0.9848 - f1: 0.9848 - val_loss: 0.5435 - val_accuracy: 0.9704 - val_precision: 0.9706 - val_recall: 0.9704 - val_f1: 0.9704
#
# Epoch 46/50 88/88 [==============================] - 14s 0.2s/step - loss: 0.5028 - accuracy: 0.9870 - precision: 0.9870 - recall: 0.9870 - f1: 0.9869 - val_loss: 0.5446 - val_accuracy: 0.9691 - val_precision: 0.9696 - val_recall: 0.9691 - val_f1: 0.9690
#
# Epoch 47/50 88/88 [==============================] - 14s 0.2s/step - loss: 0.5029 - accuracy: 0.9852 - precision: 0.9852 - recall: 0.9852 - f1: 0.9852 - val_loss: 0.5400 - val_accuracy: 0.9718 - val_precision: 0.9718 - val_recall: 0.9718 - val_f1: 0.9717
#
# Epoch 48/50 88/88 [==============================] - 14s 0.2s/step - loss: 0.5012 - accuracy: 0.9873 - precision: 0.9873 - recall: 0.9873 - f1: 0.9873 - val_loss: 0.5384 - val_accuracy: 0.9704 - val_precision: 0.9706 - val_recall: 0.9704 - val_f1: 0.9703
#
# Epoch 49/50 88/88 [==============================] - 14s 0.2s/step - loss: 0.5003 - accuracy: 0.9882 - precision: 0.9882 - recall: 0.9882 - f1: 0.9882 - val_loss: 0.5341 - val_accuracy: 0.9758 - val_precision: 0.9760 - val_recall: 0.9758 - val_f1: 0.9757
#
# Epoch 50/50 88/88 [==============================] - 14s 0.2s/step - loss: 0.4983 - accuracy: 0.9857 - precision: 0.9858 - recall: 0.9857 - f1: 0.9857 - val_loss: 0.5375 - val_accuracy: 0.9704 - val_precision: 0.9706 - val_recall: 0.9704 - val_f1: 0.9704
#
#
# ============================================================
#   TEST EVALUATION
# ============================================================
#   loss      : 0.5492
#   accuracy  : 0.9664
#   precision : 0.9666
#   recall    : 0.9664
#   f1_score  : 0.9663
# ============================================================
#
# Classification Report:
#                        precision    recall  f1-score   support
#
# bacterial_leaf_blight     0.9925    0.9852    0.9888       135
#            brown_spot     0.9419    0.9799    0.9605       149
#               healthy     0.9431    0.9587    0.9508       121
#            leaf_blast     0.9580    0.9048    0.9306       126
#            leaf_scald     0.9911    1.0000    0.9955       111
#     narrow_brown_spot     0.9804    0.9709    0.9756       103
#
#              accuracy                         0.9664       745
#             macro avg     0.9678    0.9666    0.9670       745
#          weighted avg     0.9666    0.9664    0.9663       745
#
#
#   ───────────────────────────────────────────────────────
#   MODEL PROFILE : ResNet50
#   ───────────────────────────────────────────────────────
#   Total Params (M)      : 23.52
#   Trainable Params (M)  : 4.475
#   Disk Size (MB)        : 90.03
#   FLOPs (G)             : N/A
#   Inference (ms)        : 4.405
#   FPS                   : 227.03
#   ───────────────────────────────────────────────────────
#
#   Weights saved  ->  Model\ResNet50\ResNet50_weights.pth
#   History saved  ->  Model\ResNet50\ResNet50_history.json
#   Test metrics   ->  Model\ResNet50\ResNet50_test_metrics.json
#   Profile saved  ->  Model\ResNet50\ResNet50_profile.json
#
# ResNet50 done.

# %%
# =============================================================================
#  MODEL 2 : VGG16
# =============================================================================
print('=' * 70)
print('  MODEL: VGG16')
print('=' * 70)

# ── Transforms ────────────────────────────────────────────────
vgg_train_t = transforms.Compose([
    transforms.Resize(IMAGE_SIZE),
    transforms.RandomRotation(25),
    transforms.RandomAffine(degrees=0, translate=(0.15, 0.15), shear=5.7),
    transforms.ToTensor(),
    IMAGENET_NORM,
])
vgg_val_t = transforms.Compose([
    transforms.Resize(IMAGE_SIZE),
    transforms.ToTensor(),
    IMAGENET_NORM,
])

vgg_train_loader, vgg_val_loader, vgg_test_loader = make_loaders(vgg_train_t, vgg_val_t)

# ── Architecture ──────────────────────────────────────────────
# weights=IMAGENET1K_V1  → ImageNet pretrained weights
# VGG16 has no named 'layerN' blocks; last conv block = features[24:31] (Conv block 5)
# Freeze all pretrained layers first, then unfreeze last conv block (features[24:])
def build_vgg16(num_classes=NUM_CLASSES):
    model = torchvision.models.vgg16(weights=torchvision.models.VGG16_Weights.IMAGENET1K_V1)
    # Freeze all pretrained layers first
    for p in model.parameters():
        p.requires_grad = False
    # Fine-tune last block (conv block 5: features indices 24-30)
    for p in model.features[25:].parameters():
        p.requires_grad = True
    # Replace classifier
    model.avgpool    = nn.AdaptiveAvgPool2d(1)
    model.classifier = nn.Sequential(
        nn.Flatten(),
        nn.Linear(512, 512),
        nn.ReLU(inplace=True),
        nn.Dropout(0.5),
        nn.Linear(512, num_classes),
    )
    return model

vgg_model = build_vgg16(NUM_CLASSES).to(DEVICE)
total_p     = sum(p.numel() for p in vgg_model.parameters())
trainable_p = sum(p.numel() for p in vgg_model.parameters() if p.requires_grad)
print(f'Total params     : {total_p:,}')
print(f'Trainable params : {trainable_p:,}')

vgg_history      = train_model(vgg_model, 'VGG16', vgg_train_loader, vgg_val_loader)
vgg_test_metrics = evaluate_on_test(vgg_model, vgg_test_loader)

vgg_model_dir = os.path.join(OUTPUT_DIR, 'VGG16')
os.makedirs(vgg_model_dir, exist_ok=True)
torch.save(vgg_model.state_dict(), os.path.join(vgg_model_dir, 'VGG16_weights.pth'))

vgg_profile = profile_model(vgg_model, 'VGG16', vgg_model_dir)
save_model_results(vgg_model, 'VGG16', vgg_history, vgg_test_metrics, vgg_profile)

del vgg_model, vgg_train_loader, vgg_val_loader, vgg_test_loader
if DEVICE.type == 'cuda': torch.cuda.empty_cache()
print('\nVGG16 done.\n')
# Out:
# ======================================================================
#   MODEL: VGG16
# ======================================================================
# Total params     : 14,980,422
# Trainable params : 4,985,350
#
# Model  : VGG16
# Train batches : 88  |  Val batches : 12
# Device : cuda  (NVIDIA RTX 5000 Ada Generation)
# --------------------------------------------------------------------------------------------------------------
# Epoch 1/50 88/88 [==============================] - 16s 0.2s/step - loss: 1.7814 - accuracy: 0.2334 - precision: 0.2308 - recall: 0.2334 - f1: 0.2226 - val_loss: 1.7411 - val_accuracy: 0.4046 - val_precision: 0.3875 - val_recall: 0.4046 - val_f1: 0.3626
#
# Epoch 2/50 88/88 [==============================] - 14s 0.2s/step - loss: 1.6717 - accuracy: 0.4028 - precision: 0.3933 - recall: 0.4028 - f1: 0.3891 - val_loss: 1.5476 - val_accuracy: 0.5000 - val_precision: 0.4096 - val_recall: 0.5000 - val_f1: 0.4424
#
# Epoch 3/50 88/88 [==============================] - 14s 0.2s/step - loss: 1.4059 - accuracy: 0.5520 - precision: 0.5467 - recall: 0.5520 - f1: 0.5374 - val_loss: 1.3027 - val_accuracy: 0.5511 - val_precision: 0.5379 - val_recall: 0.5511 - val_f1: 0.5134
#
# Epoch 4/50 88/88 [==============================] - 15s 0.2s/step - loss: 1.2077 - accuracy: 0.6318 - precision: 0.6274 - recall: 0.6318 - f1: 0.6214 - val_loss: 1.1789 - val_accuracy: 0.6196 - val_precision: 0.6288 - val_recall: 0.6196 - val_f1: 0.5986
#
# Epoch 5/50 88/88 [==============================] - 15s 0.2s/step - loss: 1.1013 - accuracy: 0.6927 - precision: 0.6903 - recall: 0.6927 - f1: 0.6847 - val_loss: 1.1124 - val_accuracy: 0.6559 - val_precision: 0.6640 - val_recall: 0.6559 - val_f1: 0.6342
#
# Epoch 6/50 88/88 [==============================] - 15s 0.2s/step - loss: 1.0199 - accuracy: 0.7303 - precision: 0.7305 - recall: 0.7303 - f1: 0.7239 - val_loss: 1.0735 - val_accuracy: 0.6788 - val_precision: 0.6931 - val_recall: 0.6788 - val_f1: 0.6511
#
# Epoch 7/50 88/88 [==============================] - 15s 0.2s/step - loss: 0.9649 - accuracy: 0.7489 - precision: 0.7497 - recall: 0.7489 - f1: 0.7427 - val_loss: 1.0610 - val_accuracy: 0.7231 - val_precision: 0.7341 - val_recall: 0.7231 - val_f1: 0.7077
#
# Epoch 8/50 88/88 [==============================] - 14s 0.2s/step - loss: 0.9184 - accuracy: 0.7823 - precision: 0.7849 - recall: 0.7823 - f1: 0.7772 - val_loss: 1.0281 - val_accuracy: 0.7352 - val_precision: 0.7581 - val_recall: 0.7352 - val_f1: 0.7287
#
# Epoch 9/50 88/88 [==============================] - 14s 0.2s/step - loss: 0.8799 - accuracy: 0.7978 - precision: 0.8002 - recall: 0.7978 - f1: 0.7941 - val_loss: 0.9989 - val_accuracy: 0.7540 - val_precision: 0.7747 - val_recall: 0.7540 - val_f1: 0.7445
#
# Epoch 10/50 88/88 [==============================] - 14s 0.2s/step - loss: 0.8544 - accuracy: 0.8097 - precision: 0.8121 - recall: 0.8097 - f1: 0.8065 - val_loss: 0.9320 - val_accuracy: 0.8024 - val_precision: 0.8142 - val_recall: 0.8024 - val_f1: 0.7983
#
# Epoch 11/50 88/88 [==============================] - 14s 0.2s/step - loss: 0.8225 - accuracy: 0.8281 - precision: 0.8302 - recall: 0.8281 - f1: 0.8252 - val_loss: 0.9127 - val_accuracy: 0.8078 - val_precision: 0.8179 - val_recall: 0.8078 - val_f1: 0.8040
#
# Epoch 12/50 88/88 [==============================] - 14s 0.2s/step - loss: 0.7936 - accuracy: 0.8474 - precision: 0.8503 - recall: 0.8474 - f1: 0.8453 - val_loss: 0.9026 - val_accuracy: 0.8212 - val_precision: 0.8335 - val_recall: 0.8212 - val_f1: 0.8200
#
# Epoch 13/50 88/88 [==============================] - 14s 0.2s/step - loss: 0.7828 - accuracy: 0.8576 - precision: 0.8596 - recall: 0.8576 - f1: 0.8561 - val_loss: 0.8997 - val_accuracy: 0.8159 - val_precision: 0.8304 - val_recall: 0.8159 - val_f1: 0.8115
#
# Epoch 14/50 88/88 [==============================] - 14s 0.2s/step - loss: 0.7589 - accuracy: 0.8653 - precision: 0.8673 - recall: 0.8653 - f1: 0.8634 - val_loss: 0.8469 - val_accuracy: 0.8548 - val_precision: 0.8633 - val_recall: 0.8548 - val_f1: 0.8541
#
# Epoch 15/50 88/88 [==============================] - 15s 0.2s/step - loss: 0.7437 - accuracy: 0.8749 - precision: 0.8777 - recall: 0.8749 - f1: 0.8737 - val_loss: 0.8418 - val_accuracy: 0.8602 - val_precision: 0.8659 - val_recall: 0.8602 - val_f1: 0.8578
#
# Epoch 16/50 88/88 [==============================] - 15s 0.2s/step - loss: 0.7259 - accuracy: 0.8865 - precision: 0.8890 - recall: 0.8865 - f1: 0.8852 - val_loss: 0.8394 - val_accuracy: 0.8495 - val_precision: 0.8597 - val_recall: 0.8495 - val_f1: 0.8479
#
# Epoch 17/50 88/88 [==============================] - 15s 0.2s/step - loss: 0.7192 - accuracy: 0.8868 - precision: 0.8883 - recall: 0.8868 - f1: 0.8860 - val_loss: 0.7803 - val_accuracy: 0.8790 - val_precision: 0.8843 - val_recall: 0.8790 - val_f1: 0.8784
#
# Epoch 18/50 88/88 [==============================] - 15s 0.2s/step - loss: 0.6996 - accuracy: 0.8954 - precision: 0.8974 - recall: 0.8954 - f1: 0.8945 - val_loss: 0.8100 - val_accuracy: 0.8629 - val_precision: 0.8706 - val_recall: 0.8629 - val_f1: 0.8605
#
# Epoch 19/50 88/88 [==============================] - 15s 0.2s/step - loss: 0.6879 - accuracy: 0.9042 - precision: 0.9054 - recall: 0.9042 - f1: 0.9034 - val_loss: 0.7561 - val_accuracy: 0.8884 - val_precision: 0.8918 - val_recall: 0.8884 - val_f1: 0.8872
#
# Epoch 20/50 88/88 [==============================] - 14s 0.2s/step - loss: 0.6837 - accuracy: 0.9072 - precision: 0.9085 - recall: 0.9072 - f1: 0.9067 - val_loss: 0.7638 - val_accuracy: 0.8817 - val_precision: 0.8867 - val_recall: 0.8817 - val_f1: 0.8804
#
# Epoch 21/50 88/88 [==============================] - 14s 0.2s/step - loss: 0.6736 - accuracy: 0.9097 - precision: 0.9109 - recall: 0.9097 - f1: 0.9090 - val_loss: 0.7308 - val_accuracy: 0.9019 - val_precision: 0.9060 - val_recall: 0.9019 - val_f1: 0.9014
#
# Epoch 22/50 88/88 [==============================] - 14s 0.2s/step - loss: 0.6605 - accuracy: 0.9184 - precision: 0.9195 - recall: 0.9184 - f1: 0.9180 - val_loss: 0.7257 - val_accuracy: 0.8992 - val_precision: 0.9031 - val_recall: 0.8992 - val_f1: 0.8987
#
# Epoch 23/50 88/88 [==============================] - 15s 0.2s/step - loss: 0.6558 - accuracy: 0.9190 - precision: 0.9198 - recall: 0.9190 - f1: 0.9185 - val_loss: 0.7298 - val_accuracy: 0.9019 - val_precision: 0.9050 - val_recall: 0.9019 - val_f1: 0.9014
#
# Epoch 24/50 88/88 [==============================] - 16s 0.2s/step - loss: 0.6485 - accuracy: 0.9272 - precision: 0.9278 - recall: 0.9272 - f1: 0.9267 - val_loss: 0.7057 - val_accuracy: 0.9086 - val_precision: 0.9125 - val_recall: 0.9086 - val_f1: 0.9085
#
# Epoch 25/50 88/88 [==============================] - 15s 0.2s/step - loss: 0.6379 - accuracy: 0.9304 - precision: 0.9312 - recall: 0.9304 - f1: 0.9301 - val_loss: 0.7033 - val_accuracy: 0.9073 - val_precision: 0.9116 - val_recall: 0.9073 - val_f1: 0.9076
#
# Epoch 26/50 88/88 [==============================] - 14s 0.2s/step - loss: 0.6361 - accuracy: 0.9297 - precision: 0.9306 - recall: 0.9297 - f1: 0.9293 - val_loss: 0.6813 - val_accuracy: 0.9140 - val_precision: 0.9168 - val_recall: 0.9140 - val_f1: 0.9137
#
# Epoch 27/50 88/88 [==============================] - 14s 0.2s/step - loss: 0.6319 - accuracy: 0.9345 - precision: 0.9354 - recall: 0.9345 - f1: 0.9342 - val_loss: 0.6954 - val_accuracy: 0.9113 - val_precision: 0.9146 - val_recall: 0.9113 - val_f1: 0.9110
#
# Epoch 28/50 88/88 [==============================] - 15s 0.2s/step - loss: 0.6224 - accuracy: 0.9336 - precision: 0.9342 - recall: 0.9336 - f1: 0.9333 - val_loss: 0.6918 - val_accuracy: 0.9086 - val_precision: 0.9128 - val_recall: 0.9086 - val_f1: 0.9082
#
# Epoch 29/50 88/88 [==============================] - 15s 0.2s/step - loss: 0.6169 - accuracy: 0.9399 - precision: 0.9405 - recall: 0.9399 - f1: 0.9396 - val_loss: 0.6872 - val_accuracy: 0.9140 - val_precision: 0.9177 - val_recall: 0.9140 - val_f1: 0.9136
#
# Epoch 30/50 88/88 [==============================] - 14s 0.2s/step - loss: 0.6161 - accuracy: 0.9397 - precision: 0.9404 - recall: 0.9397 - f1: 0.9394 - val_loss: 0.6700 - val_accuracy: 0.9234 - val_precision: 0.9260 - val_recall: 0.9234 - val_f1: 0.9232
#
# Epoch 31/50 88/88 [==============================] - 14s 0.2s/step - loss: 0.6092 - accuracy: 0.9436 - precision: 0.9440 - recall: 0.9436 - f1: 0.9434 - val_loss: 0.6794 - val_accuracy: 0.9153 - val_precision: 0.9186 - val_recall: 0.9153 - val_f1: 0.9150
#
# Epoch 32/50 88/88 [==============================] - 15s 0.2s/step - loss: 0.6026 - accuracy: 0.9429 - precision: 0.9434 - recall: 0.9429 - f1: 0.9426 - val_loss: 0.6640 - val_accuracy: 0.9220 - val_precision: 0.9248 - val_recall: 0.9220 - val_f1: 0.9219
#
# Epoch 33/50 88/88 [==============================] - 15s 0.2s/step - loss: 0.6021 - accuracy: 0.9456 - precision: 0.9461 - recall: 0.9456 - f1: 0.9454 - val_loss: 0.6619 - val_accuracy: 0.9234 - val_precision: 0.9259 - val_recall: 0.9234 - val_f1: 0.9231
#
# Epoch 34/50 88/88 [==============================] - 14s 0.2s/step - loss: 0.6000 - accuracy: 0.9441 - precision: 0.9446 - recall: 0.9441 - f1: 0.9440 - val_loss: 0.6553 - val_accuracy: 0.9220 - val_precision: 0.9247 - val_recall: 0.9220 - val_f1: 0.9218
#
# Epoch 35/50 88/88 [==============================] - 14s 0.2s/step - loss: 0.5924 - accuracy: 0.9516 - precision: 0.9522 - recall: 0.9516 - f1: 0.9515 - val_loss: 0.6252 - val_accuracy: 0.9395 - val_precision: 0.9408 - val_recall: 0.9395 - val_f1: 0.9394
#
# Epoch 36/50 88/88 [==============================] - 15s 0.2s/step - loss: 0.5916 - accuracy: 0.9518 - precision: 0.9524 - recall: 0.9518 - f1: 0.9516 - val_loss: 0.6303 - val_accuracy: 0.9328 - val_precision: 0.9348 - val_recall: 0.9328 - val_f1: 0.9329
#
# Epoch 37/50 88/88 [==============================] - 14s 0.2s/step - loss: 0.5868 - accuracy: 0.9534 - precision: 0.9538 - recall: 0.9534 - f1: 0.9533 - val_loss: 0.6338 - val_accuracy: 0.9368 - val_precision: 0.9390 - val_recall: 0.9368 - val_f1: 0.9367
#
# Epoch 38/50 88/88 [==============================] - 14s 0.2s/step - loss: 0.5834 - accuracy: 0.9547 - precision: 0.9551 - recall: 0.9547 - f1: 0.9546 - val_loss: 0.6377 - val_accuracy: 0.9341 - val_precision: 0.9362 - val_recall: 0.9341 - val_f1: 0.9338
#
# Epoch 39/50 88/88 [==============================] - 15s 0.2s/step - loss: 0.5863 - accuracy: 0.9504 - precision: 0.9507 - recall: 0.9504 - f1: 0.9502 - val_loss: 0.6402 - val_accuracy: 0.9288 - val_precision: 0.9306 - val_recall: 0.9288 - val_f1: 0.9284
#
# Epoch 40/50 88/88 [==============================] - 15s 0.2s/step - loss: 0.5767 - accuracy: 0.9557 - precision: 0.9562 - recall: 0.9557 - f1: 0.9556 - val_loss: 0.6356 - val_accuracy: 0.9261 - val_precision: 0.9283 - val_recall: 0.9261 - val_f1: 0.9260
#
# Epoch 41/50 88/88 [==============================] - 15s 0.2s/step - loss: 0.5766 - accuracy: 0.9554 - precision: 0.9556 - recall: 0.9554 - f1: 0.9553 - val_loss: 0.6143 - val_accuracy: 0.9355 - val_precision: 0.9373 - val_recall: 0.9355 - val_f1: 0.9356
#
# Epoch 42/50 88/88 [==============================] - 15s 0.2s/step - loss: 0.5742 - accuracy: 0.9548 - precision: 0.9552 - recall: 0.9548 - f1: 0.9547 - val_loss: 0.6137 - val_accuracy: 0.9409 - val_precision: 0.9422 - val_recall: 0.9409 - val_f1: 0.9408
#
# Epoch 43/50 88/88 [==============================] - 14s 0.2s/step - loss: 0.5703 - accuracy: 0.9593 - precision: 0.9597 - recall: 0.9593 - f1: 0.9592 - val_loss: 0.6102 - val_accuracy: 0.9422 - val_precision: 0.9435 - val_recall: 0.9422 - val_f1: 0.9422
#
# Epoch 44/50 88/88 [==============================] - 15s 0.2s/step - loss: 0.5724 - accuracy: 0.9581 - precision: 0.9585 - recall: 0.9581 - f1: 0.9580 - val_loss: 0.6056 - val_accuracy: 0.9435 - val_precision: 0.9448 - val_recall: 0.9435 - val_f1: 0.9435
#
# Epoch 45/50 88/88 [==============================] - 14s 0.2s/step - loss: 0.5723 - accuracy: 0.9588 - precision: 0.9590 - recall: 0.9588 - f1: 0.9586 - val_loss: 0.6109 - val_accuracy: 0.9409 - val_precision: 0.9427 - val_recall: 0.9409 - val_f1: 0.9407
#
# Epoch 46/50 88/88 [==============================] - 15s 0.2s/step - loss: 0.5677 - accuracy: 0.9591 - precision: 0.9595 - recall: 0.9591 - f1: 0.9590 - val_loss: 0.6093 - val_accuracy: 0.9476 - val_precision: 0.9485 - val_recall: 0.9476 - val_f1: 0.9475
#
# Epoch 47/50 88/88 [==============================] - 14s 0.2s/step - loss: 0.5667 - accuracy: 0.9614 - precision: 0.9616 - recall: 0.9614 - f1: 0.9613 - val_loss: 0.6010 - val_accuracy: 0.9462 - val_precision: 0.9474 - val_recall: 0.9462 - val_f1: 0.9461
#
# Epoch 48/50 88/88 [==============================] - 15s 0.2s/step - loss: 0.5678 - accuracy: 0.9600 - precision: 0.9604 - recall: 0.9600 - f1: 0.9599 - val_loss: 0.6039 - val_accuracy: 0.9409 - val_precision: 0.9422 - val_recall: 0.9409 - val_f1: 0.9408
#
# Epoch 49/50 88/88 [==============================] - 15s 0.2s/step - loss: 0.5700 - accuracy: 0.9577 - precision: 0.9579 - recall: 0.9577 - f1: 0.9576 - val_loss: 0.6101 - val_accuracy: 0.9395 - val_precision: 0.9413 - val_recall: 0.9395 - val_f1: 0.9394
#
# Epoch 50/50 88/88 [==============================] - 14s 0.2s/step - loss: 0.5647 - accuracy: 0.9614 - precision: 0.9617 - recall: 0.9614 - f1: 0.9614 - val_loss: 0.6089 - val_accuracy: 0.9449 - val_precision: 0.9460 - val_recall: 0.9449 - val_f1: 0.9448
#
#
# ============================================================
#   TEST EVALUATION
# ============================================================
#   loss      : 0.6030
#   accuracy  : 0.9490
#   precision : 0.9498
#   recall    : 0.9490
#   f1_score  : 0.9491
# ============================================================
#
# Classification Report:
#                        precision    recall  f1-score   support
#
# bacterial_leaf_blight     0.9921    0.9333    0.9618       135
#            brown_spot     0.9342    0.9530    0.9435       149
#               healthy     0.9355    0.9587    0.9469       121
#            leaf_blast     0.8992    0.9206    0.9098       126
#            leaf_scald     0.9735    0.9910    0.9821       111
#     narrow_brown_spot     0.9700    0.9417    0.9557       103
#
#              accuracy                         0.9490       745
#             macro avg     0.9507    0.9497    0.9500       745
#          weighted avg     0.9498    0.9490    0.9491       745
#
#
#   ───────────────────────────────────────────────────────
#   MODEL PROFILE : VGG16
#   ───────────────────────────────────────────────────────
#   Total Params (M)      : 14.98
#   Trainable Params (M)  : 4.985
#   Disk Size (MB)        : 57.16
#   FLOPs (G)             : N/A
#   Inference (ms)        : 1.032
#   FPS                   : 969.08
#   ───────────────────────────────────────────────────────
#
#   Weights saved  ->  Model\VGG16\VGG16_weights.pth
#   History saved  ->  Model\VGG16\VGG16_history.json
#   Test metrics   ->  Model\VGG16\VGG16_test_metrics.json
#   Profile saved  ->  Model\VGG16\VGG16_profile.json
#
# VGG16 done.

# %%
# =============================================================================
#  MODEL 3 : MobileNetV2
# =============================================================================
print('=' * 70)
print('  MODEL: MobileNetV2')
print('=' * 70)

# ── Transforms ────────────────────────────────────────────────
mobilenet_train_t = transforms.Compose([
    transforms.Resize(IMAGE_SIZE),
    transforms.RandomRotation(25),
    transforms.RandomAffine(degrees=0, translate=(0.15, 0.15), shear=5.7),
    transforms.ToTensor(),
    MINUSONE_NORM,
])
mobilenet_val_t = transforms.Compose([
    transforms.Resize(IMAGE_SIZE),
    transforms.ToTensor(),
    MINUSONE_NORM,
])

mobilenet_train_loader, mobilenet_val_loader, mobilenet_test_loader = make_loaders(
    mobilenet_train_t, mobilenet_val_t
)

# ── Architecture ──────────────────────────────────────────────
# weights=IMAGENET1K_V1  → ImageNet pretrained weights
# MobileNetV2: features is a Sequential of 19 InvertedResidual / Conv blocks
# Last block = features[18] (the final point-wise conv before pooling)
# Freeze all pretrained layers first, then unfreeze features[18] (last block)
def build_mobilenetv2(num_classes=NUM_CLASSES):
    model = torchvision.models.mobilenet_v2(weights=torchvision.models.MobileNet_V2_Weights.IMAGENET1K_V1)
    # Freeze all pretrained layers first
    for p in model.parameters():
        p.requires_grad = False
    # Fine-tune last block (features[18])
    for p in model.features[18].parameters():
        p.requires_grad = True
    # Replace classifier
    model.classifier = nn.Sequential(
        nn.Dropout(0.3),
        nn.Linear(1280, num_classes),
    )
    return model

mobilenet_model = build_mobilenetv2(NUM_CLASSES).to(DEVICE)
total_p     = sum(p.numel() for p in mobilenet_model.parameters())
trainable_p = sum(p.numel() for p in mobilenet_model.parameters() if p.requires_grad)
print(f'Total params     : {total_p:,}')
print(f'Trainable params : {trainable_p:,}')

mobilenet_history      = train_model(mobilenet_model, 'MobileNetV2', mobilenet_train_loader, mobilenet_val_loader)
mobilenet_test_metrics = evaluate_on_test(mobilenet_model, mobilenet_test_loader)

mobilenet_model_dir = os.path.join(OUTPUT_DIR, 'MobileNetV2')
os.makedirs(mobilenet_model_dir, exist_ok=True)
torch.save(mobilenet_model.state_dict(), os.path.join(mobilenet_model_dir, 'MobileNetV2_weights.pth'))

mobilenet_profile = profile_model(mobilenet_model, 'MobileNetV2', mobilenet_model_dir)
save_model_results(mobilenet_model, 'MobileNetV2', mobilenet_history, mobilenet_test_metrics, mobilenet_profile)

del mobilenet_model, mobilenet_train_loader, mobilenet_val_loader, mobilenet_test_loader
if DEVICE.type == 'cuda': torch.cuda.empty_cache()
print('\nMobileNetV2 done.\n')
# Out:
# ======================================================================
#   MODEL: MobileNetV2
# ======================================================================
# Total params     : 2,231,558
# Trainable params : 419,846
#
# Model  : MobileNetV2
# Train batches : 88  |  Val batches : 12
# Device : cuda  (NVIDIA RTX 5000 Ada Generation)
# --------------------------------------------------------------------------------------------------------------
# Epoch 1/50 88/88 [==============================] - 30s 0.3s/step - loss: 1.7457 - accuracy: 0.2461 - precision: 0.3151 - recall: 0.2461 - f1: 0.2226 - val_loss: 1.6491 - val_accuracy: 0.3777 - val_precision: 0.4185 - val_recall: 0.3777 - val_f1: 0.3674
#
# Epoch 2/50 88/88 [==============================] - 18s 0.2s/step - loss: 1.6049 - accuracy: 0.3994 - precision: 0.4269 - recall: 0.3994 - f1: 0.3992 - val_loss: 1.5462 - val_accuracy: 0.5161 - val_precision: 0.5372 - val_recall: 0.5161 - val_f1: 0.5192
#
# Epoch 3/50 88/88 [==============================] - 17s 0.2s/step - loss: 1.5029 - accuracy: 0.4863 - precision: 0.4943 - recall: 0.4863 - f1: 0.4840 - val_loss: 1.4622 - val_accuracy: 0.5874 - val_precision: 0.6043 - val_recall: 0.5874 - val_f1: 0.5882
#
# Epoch 4/50 88/88 [==============================] - 17s 0.2s/step - loss: 1.4255 - accuracy: 0.5556 - precision: 0.5646 - recall: 0.5556 - f1: 0.5527 - val_loss: 1.3921 - val_accuracy: 0.6331 - val_precision: 0.6584 - val_recall: 0.6331 - val_f1: 0.6359
#
# Epoch 5/50 88/88 [==============================] - 17s 0.2s/step - loss: 1.3565 - accuracy: 0.5929 - precision: 0.6016 - recall: 0.5929 - f1: 0.5890 - val_loss: 1.3388 - val_accuracy: 0.6452 - val_precision: 0.6715 - val_recall: 0.6452 - val_f1: 0.6480
#
# Epoch 6/50 88/88 [==============================] - 17s 0.2s/step - loss: 1.2950 - accuracy: 0.6200 - precision: 0.6254 - recall: 0.6200 - f1: 0.6140 - val_loss: 1.2916 - val_accuracy: 0.6694 - val_precision: 0.6904 - val_recall: 0.6694 - val_f1: 0.6693
#
# Epoch 7/50 88/88 [==============================] - 17s 0.2s/step - loss: 1.2449 - accuracy: 0.6530 - precision: 0.6593 - recall: 0.6530 - f1: 0.6489 - val_loss: 1.2499 - val_accuracy: 0.6720 - val_precision: 0.6986 - val_recall: 0.6720 - val_f1: 0.6735
#
# Epoch 8/50 88/88 [==============================] - 18s 0.2s/step - loss: 1.2099 - accuracy: 0.6645 - precision: 0.6717 - recall: 0.6645 - f1: 0.6596 - val_loss: 1.2084 - val_accuracy: 0.6895 - val_precision: 0.7076 - val_recall: 0.6895 - val_f1: 0.6894
#
# Epoch 9/50 88/88 [==============================] - 17s 0.2s/step - loss: 1.1737 - accuracy: 0.6816 - precision: 0.6864 - recall: 0.6816 - f1: 0.6758 - val_loss: 1.1744 - val_accuracy: 0.7043 - val_precision: 0.7193 - val_recall: 0.7043 - val_f1: 0.7048
#
# Epoch 10/50 88/88 [==============================] - 17s 0.2s/step - loss: 1.1401 - accuracy: 0.6948 - precision: 0.7023 - recall: 0.6948 - f1: 0.6893 - val_loss: 1.1503 - val_accuracy: 0.7030 - val_precision: 0.7226 - val_recall: 0.7030 - val_f1: 0.7034
#
# Epoch 11/50 88/88 [==============================] - 17s 0.2s/step - loss: 1.1087 - accuracy: 0.7034 - precision: 0.7122 - recall: 0.7034 - f1: 0.6982 - val_loss: 1.1229 - val_accuracy: 0.7177 - val_precision: 0.7327 - val_recall: 0.7177 - val_f1: 0.7173
#
# Epoch 12/50 88/88 [==============================] - 17s 0.2s/step - loss: 1.0890 - accuracy: 0.7150 - precision: 0.7225 - recall: 0.7150 - f1: 0.7109 - val_loss: 1.0993 - val_accuracy: 0.7258 - val_precision: 0.7427 - val_recall: 0.7258 - val_f1: 0.7262
#
# Epoch 13/50 88/88 [==============================] - 17s 0.2s/step - loss: 1.0674 - accuracy: 0.7216 - precision: 0.7282 - recall: 0.7216 - f1: 0.7167 - val_loss: 1.0850 - val_accuracy: 0.7285 - val_precision: 0.7419 - val_recall: 0.7285 - val_f1: 0.7281
#
# Epoch 14/50 88/88 [==============================] - 18s 0.2s/step - loss: 1.0410 - accuracy: 0.7291 - precision: 0.7355 - recall: 0.7291 - f1: 0.7240 - val_loss: 1.0635 - val_accuracy: 0.7366 - val_precision: 0.7526 - val_recall: 0.7366 - val_f1: 0.7376
#
# Epoch 15/50 88/88 [==============================] - 17s 0.2s/step - loss: 1.0239 - accuracy: 0.7423 - precision: 0.7484 - recall: 0.7423 - f1: 0.7382 - val_loss: 1.0481 - val_accuracy: 0.7406 - val_precision: 0.7535 - val_recall: 0.7406 - val_f1: 0.7404
#
# Epoch 16/50 88/88 [==============================] - 17s 0.2s/step - loss: 1.0152 - accuracy: 0.7426 - precision: 0.7482 - recall: 0.7426 - f1: 0.7384 - val_loss: 1.0341 - val_accuracy: 0.7406 - val_precision: 0.7557 - val_recall: 0.7406 - val_f1: 0.7393
#
# Epoch 17/50 88/88 [==============================] - 18s 0.2s/step - loss: 0.9905 - accuracy: 0.7551 - precision: 0.7612 - recall: 0.7551 - f1: 0.7513 - val_loss: 1.0220 - val_accuracy: 0.7567 - val_precision: 0.7699 - val_recall: 0.7567 - val_f1: 0.7564
#
# Epoch 18/50 88/88 [==============================] - 18s 0.2s/step - loss: 0.9787 - accuracy: 0.7669 - precision: 0.7724 - recall: 0.7669 - f1: 0.7630 - val_loss: 1.0091 - val_accuracy: 0.7527 - val_precision: 0.7621 - val_recall: 0.7527 - val_f1: 0.7514
#
# Epoch 19/50 88/88 [==============================] - 17s 0.2s/step - loss: 0.9668 - accuracy: 0.7699 - precision: 0.7755 - recall: 0.7699 - f1: 0.7656 - val_loss: 0.9952 - val_accuracy: 0.7581 - val_precision: 0.7692 - val_recall: 0.7581 - val_f1: 0.7578
#
# Epoch 20/50 88/88 [==============================] - 17s 0.2s/step - loss: 0.9519 - accuracy: 0.7721 - precision: 0.7793 - recall: 0.7721 - f1: 0.7688 - val_loss: 0.9861 - val_accuracy: 0.7594 - val_precision: 0.7690 - val_recall: 0.7594 - val_f1: 0.7587
#
# Epoch 21/50 88/88 [==============================] - 17s 0.2s/step - loss: 0.9348 - accuracy: 0.7814 - precision: 0.7882 - recall: 0.7814 - f1: 0.7776 - val_loss: 0.9759 - val_accuracy: 0.7621 - val_precision: 0.7727 - val_recall: 0.7621 - val_f1: 0.7619
#
# Epoch 22/50 88/88 [==============================] - 17s 0.2s/step - loss: 0.9232 - accuracy: 0.7928 - precision: 0.7990 - recall: 0.7928 - f1: 0.7899 - val_loss: 0.9672 - val_accuracy: 0.7675 - val_precision: 0.7787 - val_recall: 0.7675 - val_f1: 0.7676
#
# Epoch 23/50 88/88 [==============================] - 17s 0.2s/step - loss: 0.9174 - accuracy: 0.7924 - precision: 0.7981 - recall: 0.7924 - f1: 0.7892 - val_loss: 0.9551 - val_accuracy: 0.7809 - val_precision: 0.7893 - val_recall: 0.7809 - val_f1: 0.7807
#
# Epoch 24/50 88/88 [==============================] - 17s 0.2s/step - loss: 0.9153 - accuracy: 0.7949 - precision: 0.8000 - recall: 0.7949 - f1: 0.7916 - val_loss: 0.9533 - val_accuracy: 0.7742 - val_precision: 0.7841 - val_recall: 0.7742 - val_f1: 0.7739
#
# Epoch 25/50 88/88 [==============================] - 18s 0.2s/step - loss: 0.8989 - accuracy: 0.8010 - precision: 0.8070 - recall: 0.8010 - f1: 0.7985 - val_loss: 0.9369 - val_accuracy: 0.7849 - val_precision: 0.7953 - val_recall: 0.7849 - val_f1: 0.7850
#
# Epoch 26/50 88/88 [==============================] - 17s 0.2s/step - loss: 0.8942 - accuracy: 0.8012 - precision: 0.8060 - recall: 0.8012 - f1: 0.7988 - val_loss: 0.9384 - val_accuracy: 0.7809 - val_precision: 0.7897 - val_recall: 0.7809 - val_f1: 0.7808
#
# Epoch 27/50 88/88 [==============================] - 17s 0.2s/step - loss: 0.8819 - accuracy: 0.8115 - precision: 0.8165 - recall: 0.8115 - f1: 0.8089 - val_loss: 0.9242 - val_accuracy: 0.8011 - val_precision: 0.8085 - val_recall: 0.8011 - val_f1: 0.8021
#
# Epoch 28/50 88/88 [==============================] - 17s 0.2s/step - loss: 0.8734 - accuracy: 0.8155 - precision: 0.8203 - recall: 0.8155 - f1: 0.8132 - val_loss: 0.9174 - val_accuracy: 0.8065 - val_precision: 0.8144 - val_recall: 0.8065 - val_f1: 0.8073
#
# Epoch 29/50 88/88 [==============================] - 18s 0.2s/step - loss: 0.8603 - accuracy: 0.8208 - precision: 0.8246 - recall: 0.8208 - f1: 0.8181 - val_loss: 0.9126 - val_accuracy: 0.8024 - val_precision: 0.8068 - val_recall: 0.8024 - val_f1: 0.8024
#
# Epoch 30/50 88/88 [==============================] - 17s 0.2s/step - loss: 0.8678 - accuracy: 0.8144 - precision: 0.8202 - recall: 0.8144 - f1: 0.8120 - val_loss: 0.9146 - val_accuracy: 0.7917 - val_precision: 0.7980 - val_recall: 0.7917 - val_f1: 0.7919
#
# Epoch 31/50 88/88 [==============================] - 17s 0.2s/step - loss: 0.8567 - accuracy: 0.8251 - precision: 0.8294 - recall: 0.8251 - f1: 0.8227 - val_loss: 0.9052 - val_accuracy: 0.8011 - val_precision: 0.8095 - val_recall: 0.8011 - val_f1: 0.8014
#
# Epoch 32/50 88/88 [==============================] - 17s 0.2s/step - loss: 0.8468 - accuracy: 0.8274 - precision: 0.8322 - recall: 0.8274 - f1: 0.8256 - val_loss: 0.9009 - val_accuracy: 0.8065 - val_precision: 0.8133 - val_recall: 0.8065 - val_f1: 0.8063
#
# Epoch 33/50 88/88 [==============================] - 17s 0.2s/step - loss: 0.8444 - accuracy: 0.8285 - precision: 0.8336 - recall: 0.8285 - f1: 0.8265 - val_loss: 0.8990 - val_accuracy: 0.8011 - val_precision: 0.8073 - val_recall: 0.8011 - val_f1: 0.8009
#
# Epoch 34/50 88/88 [==============================] - 17s 0.2s/step - loss: 0.8327 - accuracy: 0.8317 - precision: 0.8358 - recall: 0.8317 - f1: 0.8295 - val_loss: 0.8850 - val_accuracy: 0.8011 - val_precision: 0.8081 - val_recall: 0.8011 - val_f1: 0.8008
#
# Epoch 35/50 88/88 [==============================] - 18s 0.2s/step - loss: 0.8322 - accuracy: 0.8319 - precision: 0.8369 - recall: 0.8319 - f1: 0.8303 - val_loss: 0.8877 - val_accuracy: 0.8024 - val_precision: 0.8119 - val_recall: 0.8024 - val_f1: 0.8022
#
# Epoch 36/50 88/88 [==============================] - 17s 0.2s/step - loss: 0.8220 - accuracy: 0.8379 - precision: 0.8430 - recall: 0.8379 - f1: 0.8362 - val_loss: 0.8854 - val_accuracy: 0.8038 - val_precision: 0.8105 - val_recall: 0.8038 - val_f1: 0.8040
#
# Epoch 37/50 88/88 [==============================] - 17s 0.2s/step - loss: 0.8191 - accuracy: 0.8422 - precision: 0.8460 - recall: 0.8422 - f1: 0.8406 - val_loss: 0.8754 - val_accuracy: 0.8091 - val_precision: 0.8164 - val_recall: 0.8091 - val_f1: 0.8096
#
# Epoch 38/50 88/88 [==============================] - 17s 0.2s/step - loss: 0.8178 - accuracy: 0.8356 - precision: 0.8401 - recall: 0.8356 - f1: 0.8339 - val_loss: 0.8815 - val_accuracy: 0.8078 - val_precision: 0.8158 - val_recall: 0.8078 - val_f1: 0.8083
#
# Epoch 39/50 88/88 [==============================] - 17s 0.2s/step - loss: 0.8081 - accuracy: 0.8492 - precision: 0.8539 - recall: 0.8492 - f1: 0.8475 - val_loss: 0.8628 - val_accuracy: 0.8105 - val_precision: 0.8173 - val_recall: 0.8105 - val_f1: 0.8106
#
# Epoch 40/50 88/88 [==============================] - 17s 0.2s/step - loss: 0.8081 - accuracy: 0.8429 - precision: 0.8454 - recall: 0.8429 - f1: 0.8411 - val_loss: 0.8755 - val_accuracy: 0.8132 - val_precision: 0.8240 - val_recall: 0.8132 - val_f1: 0.8144
#
# Epoch 41/50 88/88 [==============================] - 17s 0.2s/step - loss: 0.8000 - accuracy: 0.8540 - precision: 0.8573 - recall: 0.8540 - f1: 0.8524 - val_loss: 0.8538 - val_accuracy: 0.8185 - val_precision: 0.8230 - val_recall: 0.8185 - val_f1: 0.8179
#
# Epoch 42/50 88/88 [==============================] - 17s 0.2s/step - loss: 0.7929 - accuracy: 0.8569 - precision: 0.8609 - recall: 0.8569 - f1: 0.8555 - val_loss: 0.8639 - val_accuracy: 0.8172 - val_precision: 0.8256 - val_recall: 0.8172 - val_f1: 0.8173
#
# Epoch 43/50 88/88 [==============================] - 18s 0.2s/step - loss: 0.7932 - accuracy: 0.8588 - precision: 0.8622 - recall: 0.8588 - f1: 0.8574 - val_loss: 0.8606 - val_accuracy: 0.8132 - val_precision: 0.8235 - val_recall: 0.8132 - val_f1: 0.8131
#
# Epoch 44/50 88/88 [==============================] - 18s 0.2s/step - loss: 0.7895 - accuracy: 0.8590 - precision: 0.8623 - recall: 0.8590 - f1: 0.8578 - val_loss: 0.8595 - val_accuracy: 0.8145 - val_precision: 0.8201 - val_recall: 0.8145 - val_f1: 0.8137
#
# Epoch 45/50 88/88 [==============================] - 18s 0.2s/step - loss: 0.7840 - accuracy: 0.8558 - precision: 0.8586 - recall: 0.8558 - f1: 0.8543 - val_loss: 0.8571 - val_accuracy: 0.8118 - val_precision: 0.8228 - val_recall: 0.8118 - val_f1: 0.8123
#
# Epoch 46/50 88/88 [==============================] - 17s 0.2s/step - loss: 0.7800 - accuracy: 0.8583 - precision: 0.8603 - recall: 0.8583 - f1: 0.8568 - val_loss: 0.8639 - val_accuracy: 0.8185 - val_precision: 0.8286 - val_recall: 0.8185 - val_f1: 0.8182
#
# Epoch 47/50 88/88 [==============================] - 18s 0.2s/step - loss: 0.7859 - accuracy: 0.8563 - precision: 0.8611 - recall: 0.8563 - f1: 0.8553 - val_loss: 0.8545 - val_accuracy: 0.8172 - val_precision: 0.8257 - val_recall: 0.8172 - val_f1: 0.8165
#
# Epoch 48/50 88/88 [==============================] - 18s 0.2s/step - loss: 0.7893 - accuracy: 0.8569 - precision: 0.8596 - recall: 0.8569 - f1: 0.8558 - val_loss: 0.8457 - val_accuracy: 0.8199 - val_precision: 0.8275 - val_recall: 0.8199 - val_f1: 0.8199
#
# Epoch 49/50 88/88 [==============================] - 18s 0.2s/step - loss: 0.7778 - accuracy: 0.8606 - precision: 0.8638 - recall: 0.8606 - f1: 0.8593 - val_loss: 0.8402 - val_accuracy: 0.8293 - val_precision: 0.8343 - val_recall: 0.8293 - val_f1: 0.8283
#
# Epoch 50/50 88/88 [==============================] - 17s 0.2s/step - loss: 0.7790 - accuracy: 0.8640 - precision: 0.8682 - recall: 0.8640 - f1: 0.8632 - val_loss: 0.8573 - val_accuracy: 0.8253 - val_precision: 0.8363 - val_recall: 0.8253 - val_f1: 0.8259
#
#
# ============================================================
#   TEST EVALUATION
# ============================================================
#   loss      : 0.8098
#   accuracy  : 0.8416
#   precision : 0.8495
#   recall    : 0.8416
#   f1_score  : 0.8408
# ============================================================
#
# Classification Report:
#                        precision    recall  f1-score   support
#
# bacterial_leaf_blight     0.8929    0.7407    0.8097       135
#            brown_spot     0.9237    0.8121    0.8643       149
#               healthy     0.7419    0.9504    0.8333       121
#            leaf_blast     0.8151    0.7698    0.7918       126
#            leaf_scald     0.8413    0.9550    0.8945       111
#     narrow_brown_spot     0.8627    0.8544    0.8585       103
#
#              accuracy                         0.8416       745
#             macro avg     0.8463    0.8471    0.8420       745
#          weighted avg     0.8495    0.8416    0.8408       745
#
#
#   ───────────────────────────────────────────────────────
#   MODEL PROFILE : MobileNetV2
#   ───────────────────────────────────────────────────────
#   Total Params (M)      : 2.232
#   Trainable Params (M)  : 0.42
#   Disk Size (MB)        : 8.75
#   FLOPs (G)             : N/A
#   Inference (ms)        : 16.837
#   FPS                   : 59.39
#   ───────────────────────────────────────────────────────
#
#   Weights saved  ->  Model\MobileNetV2\MobileNetV2_weights.pth
#   History saved  ->  Model\MobileNetV2\MobileNetV2_history.json
#   Test metrics   ->  Model\MobileNetV2\MobileNetV2_test_metrics.json
#   Profile saved  ->  Model\MobileNetV2\MobileNetV2_profile.json
#
# MobileNetV2 done.

# %%
# =============================================================================
#  MODEL 4 : InceptionV3
# =============================================================================
print('=' * 70)
print('  MODEL: InceptionV3')
print('=' * 70)

# ── Transforms ────────────────────────────────────────────────
inception_train_t = transforms.Compose([
    transforms.Resize(IMAGE_SIZE),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(25),
    transforms.RandomAffine(
        degrees=0,
        translate=(0.2, 0.2),
        scale=(0.7, 1.3),
        shear=8.5,
    ),
    transforms.ColorJitter(brightness=0.3),
    transforms.ToTensor(),
    MINUSONE_NORM,
])
inception_val_t = transforms.Compose([
    transforms.Resize(IMAGE_SIZE),
    transforms.ToTensor(),
    MINUSONE_NORM,
])

inception_train_loader, inception_val_loader, inception_test_loader = make_loaders(
    inception_train_t, inception_val_t
)

# ── Architecture ──────────────────────────────────────────────
# weights=IMAGENET1K_V1  → ImageNet pretrained weights
# aux_logits=False: disable auxiliary branch (not needed for fine-tuning)
# InceptionV3 last block: Mixed_7c (the last Inception module before avg pool)
# Freeze all pretrained layers first, then unfreeze Mixed_7c (last block)

def build_inceptionv3(num_classes=NUM_CLASSES):
    model = torchvision.models.inception_v3(
        weights=torchvision.models.Inception_V3_Weights.IMAGENET1K_V1,
        aux_logits=True
    )

    # Very important for 224x224 input
    model.aux_logits = False
    model.AuxLogits = None

    # Freeze all pretrained layers
    for p in model.parameters():
        p.requires_grad = False

    # Fine-tune last Inception block
    for p in model.Mixed_7c.parameters():
        p.requires_grad = True

    # Replace classifier
    model.fc = nn.Linear(model.fc.in_features, num_classes)

    return model

inception_model = build_inceptionv3(NUM_CLASSES).to(DEVICE)
total_p     = sum(p.numel() for p in inception_model.parameters())
trainable_p = sum(p.numel() for p in inception_model.parameters() if p.requires_grad)
print(f'Total params     : {total_p:,}')
print(f'Trainable params : {trainable_p:,}')

inception_history      = train_model(inception_model, 'InceptionV3', inception_train_loader, inception_val_loader)
inception_test_metrics = evaluate_on_test(inception_model, inception_test_loader)

inception_model_dir = os.path.join(OUTPUT_DIR, 'InceptionV3')
os.makedirs(inception_model_dir, exist_ok=True)
torch.save(inception_model.state_dict(), os.path.join(inception_model_dir, 'InceptionV3_weights.pth'))

inception_profile = profile_model(inception_model, 'InceptionV3', inception_model_dir)
save_model_results(inception_model, 'InceptionV3', inception_history, inception_test_metrics, inception_profile)

del inception_model, inception_train_loader, inception_val_loader, inception_test_loader
if DEVICE.type == 'cuda': torch.cuda.empty_cache()
print('\nInceptionV3 done.\n')
# Out:
# ======================================================================
#   MODEL: InceptionV3
# ======================================================================
# Total params     : 21,797,862
# Trainable params : 6,089,094
#
# Model  : InceptionV3
# Train batches : 88  |  Val batches : 12
# Device : cuda  (NVIDIA RTX 5000 Ada Generation)
# --------------------------------------------------------------------------------------------------------------
# Epoch 1/50 88/88 [==============================] - 22s 0.3s/step - loss: 1.7472 - accuracy: 0.2593 - precision: 0.2611 - recall: 0.2593 - f1: 0.2592 - val_loss: 1.6494 - val_accuracy: 0.4664 - val_precision: 0.4673 - val_recall: 0.4664 - val_f1: 0.4593
#
# Epoch 2/50 88/88 [==============================] - 17s 0.2s/step - loss: 1.5967 - accuracy: 0.4323 - precision: 0.4345 - recall: 0.4323 - f1: 0.4313 - val_loss: 1.5063 - val_accuracy: 0.5981 - val_precision: 0.6114 - val_recall: 0.5981 - val_f1: 0.5911
#
# Epoch 3/50 88/88 [==============================] - 19s 0.2s/step - loss: 1.4655 - accuracy: 0.5440 - precision: 0.5479 - recall: 0.5440 - f1: 0.5392 - val_loss: 1.3852 - val_accuracy: 0.6411 - val_precision: 0.6540 - val_recall: 0.6411 - val_f1: 0.6359
#
# Epoch 4/50 88/88 [==============================] - 17s 0.2s/step - loss: 1.3500 - accuracy: 0.6045 - precision: 0.6114 - recall: 0.6045 - f1: 0.5990 - val_loss: 1.2879 - val_accuracy: 0.6694 - val_precision: 0.6855 - val_recall: 0.6694 - val_f1: 0.6664
#
# Epoch 5/50 88/88 [==============================] - 18s 0.2s/step - loss: 1.2631 - accuracy: 0.6404 - precision: 0.6537 - recall: 0.6404 - f1: 0.6373 - val_loss: 1.1972 - val_accuracy: 0.7016 - val_precision: 0.7173 - val_recall: 0.7016 - val_f1: 0.7001
#
# Epoch 6/50 88/88 [==============================] - 18s 0.2s/step - loss: 1.1834 - accuracy: 0.6787 - precision: 0.6921 - recall: 0.6787 - f1: 0.6756 - val_loss: 1.1180 - val_accuracy: 0.7312 - val_precision: 0.7429 - val_recall: 0.7312 - val_f1: 0.7291
#
# Epoch 7/50 88/88 [==============================] - 16s 0.2s/step - loss: 1.1231 - accuracy: 0.7009 - precision: 0.7096 - recall: 0.7009 - f1: 0.6977 - val_loss: 1.0555 - val_accuracy: 0.7446 - val_precision: 0.7542 - val_recall: 0.7446 - val_f1: 0.7438
#
# Epoch 8/50 88/88 [==============================] - 17s 0.2s/step - loss: 1.0669 - accuracy: 0.7234 - precision: 0.7334 - recall: 0.7234 - f1: 0.7216 - val_loss: 1.0027 - val_accuracy: 0.7608 - val_precision: 0.7698 - val_recall: 0.7608 - val_f1: 0.7590
#
# Epoch 9/50 88/88 [==============================] - 17s 0.2s/step - loss: 1.0258 - accuracy: 0.7469 - precision: 0.7532 - recall: 0.7469 - f1: 0.7451 - val_loss: 0.9729 - val_accuracy: 0.7715 - val_precision: 0.7796 - val_recall: 0.7715 - val_f1: 0.7714
#
# Epoch 10/50 88/88 [==============================] - 17s 0.2s/step - loss: 0.9904 - accuracy: 0.7623 - precision: 0.7701 - recall: 0.7623 - f1: 0.7601 - val_loss: 0.9246 - val_accuracy: 0.7796 - val_precision: 0.7851 - val_recall: 0.7796 - val_f1: 0.7789
#
# Epoch 11/50 88/88 [==============================] - 16s 0.2s/step - loss: 0.9594 - accuracy: 0.7708 - precision: 0.7775 - recall: 0.7708 - f1: 0.7692 - val_loss: 0.9052 - val_accuracy: 0.7957 - val_precision: 0.8015 - val_recall: 0.7957 - val_f1: 0.7948
#
# Epoch 12/50 88/88 [==============================] - 16s 0.2s/step - loss: 0.9278 - accuracy: 0.7799 - precision: 0.7853 - recall: 0.7799 - f1: 0.7778 - val_loss: 0.8745 - val_accuracy: 0.8065 - val_precision: 0.8102 - val_recall: 0.8065 - val_f1: 0.8061
#
# Epoch 13/50 88/88 [==============================] - 16s 0.2s/step - loss: 0.9038 - accuracy: 0.8005 - precision: 0.8048 - recall: 0.8005 - f1: 0.7990 - val_loss: 0.8537 - val_accuracy: 0.8159 - val_precision: 0.8198 - val_recall: 0.8159 - val_f1: 0.8159
#
# Epoch 14/50 88/88 [==============================] - 17s 0.2s/step - loss: 0.8810 - accuracy: 0.8039 - precision: 0.8073 - recall: 0.8039 - f1: 0.8024 - val_loss: 0.8307 - val_accuracy: 0.8239 - val_precision: 0.8280 - val_recall: 0.8239 - val_f1: 0.8239
#
# Epoch 15/50 88/88 [==============================] - 17s 0.2s/step - loss: 0.8666 - accuracy: 0.8060 - precision: 0.8097 - recall: 0.8060 - f1: 0.8045 - val_loss: 0.8189 - val_accuracy: 0.8280 - val_precision: 0.8328 - val_recall: 0.8280 - val_f1: 0.8282
#
# Epoch 16/50 88/88 [==============================] - 17s 0.2s/step - loss: 0.8500 - accuracy: 0.8138 - precision: 0.8194 - recall: 0.8138 - f1: 0.8130 - val_loss: 0.7961 - val_accuracy: 0.8427 - val_precision: 0.8468 - val_recall: 0.8427 - val_f1: 0.8427
#
# Epoch 17/50 88/88 [==============================] - 17s 0.2s/step - loss: 0.8336 - accuracy: 0.8231 - precision: 0.8270 - recall: 0.8231 - f1: 0.8223 - val_loss: 0.7818 - val_accuracy: 0.8427 - val_precision: 0.8458 - val_recall: 0.8427 - val_f1: 0.8424
#
# Epoch 18/50 88/88 [==============================] - 17s 0.2s/step - loss: 0.8145 - accuracy: 0.8340 - precision: 0.8370 - recall: 0.8340 - f1: 0.8329 - val_loss: 0.7720 - val_accuracy: 0.8575 - val_precision: 0.8608 - val_recall: 0.8575 - val_f1: 0.8573
#
# Epoch 19/50 88/88 [==============================] - 17s 0.2s/step - loss: 0.8118 - accuracy: 0.8269 - precision: 0.8300 - recall: 0.8269 - f1: 0.8257 - val_loss: 0.7625 - val_accuracy: 0.8535 - val_precision: 0.8570 - val_recall: 0.8535 - val_f1: 0.8535
#
# Epoch 20/50 88/88 [==============================] - 16s 0.2s/step - loss: 0.7924 - accuracy: 0.8413 - precision: 0.8438 - recall: 0.8413 - f1: 0.8405 - val_loss: 0.7563 - val_accuracy: 0.8548 - val_precision: 0.8581 - val_recall: 0.8548 - val_f1: 0.8548
#
# Epoch 21/50 88/88 [==============================] - 16s 0.2s/step - loss: 0.7866 - accuracy: 0.8428 - precision: 0.8453 - recall: 0.8428 - f1: 0.8421 - val_loss: 0.7447 - val_accuracy: 0.8629 - val_precision: 0.8647 - val_recall: 0.8629 - val_f1: 0.8628
#
# Epoch 22/50 88/88 [==============================] - 17s 0.2s/step - loss: 0.7784 - accuracy: 0.8553 - precision: 0.8578 - recall: 0.8553 - f1: 0.8547 - val_loss: 0.7421 - val_accuracy: 0.8616 - val_precision: 0.8639 - val_recall: 0.8616 - val_f1: 0.8616
#
# Epoch 23/50 88/88 [==============================] - 16s 0.2s/step - loss: 0.7681 - accuracy: 0.8592 - precision: 0.8607 - recall: 0.8592 - f1: 0.8589 - val_loss: 0.7235 - val_accuracy: 0.8790 - val_precision: 0.8806 - val_recall: 0.8790 - val_f1: 0.8789
#
# Epoch 24/50 88/88 [==============================] - 16s 0.2s/step - loss: 0.7516 - accuracy: 0.8633 - precision: 0.8652 - recall: 0.8633 - f1: 0.8626 - val_loss: 0.7196 - val_accuracy: 0.8831 - val_precision: 0.8859 - val_recall: 0.8831 - val_f1: 0.8832
#
# Epoch 25/50 88/88 [==============================] - 15s 0.2s/step - loss: 0.7521 - accuracy: 0.8670 - precision: 0.8686 - recall: 0.8670 - f1: 0.8666 - val_loss: 0.7144 - val_accuracy: 0.8884 - val_precision: 0.8911 - val_recall: 0.8884 - val_f1: 0.8881
#
# Epoch 26/50 88/88 [==============================] - 15s 0.2s/step - loss: 0.7429 - accuracy: 0.8697 - precision: 0.8721 - recall: 0.8697 - f1: 0.8694 - val_loss: 0.7109 - val_accuracy: 0.8831 - val_precision: 0.8873 - val_recall: 0.8831 - val_f1: 0.8831
#
# Epoch 27/50 88/88 [==============================] - 15s 0.2s/step - loss: 0.7436 - accuracy: 0.8670 - precision: 0.8692 - recall: 0.8670 - f1: 0.8666 - val_loss: 0.7055 - val_accuracy: 0.8858 - val_precision: 0.8881 - val_recall: 0.8858 - val_f1: 0.8856
#
# Epoch 28/50 88/88 [==============================] - 15s 0.2s/step - loss: 0.7336 - accuracy: 0.8704 - precision: 0.8724 - recall: 0.8704 - f1: 0.8701 - val_loss: 0.7035 - val_accuracy: 0.8884 - val_precision: 0.8908 - val_recall: 0.8884 - val_f1: 0.8883
#
# Epoch 29/50 88/88 [==============================] - 15s 0.2s/step - loss: 0.7185 - accuracy: 0.8779 - precision: 0.8797 - recall: 0.8779 - f1: 0.8776 - val_loss: 0.6890 - val_accuracy: 0.8884 - val_precision: 0.8910 - val_recall: 0.8884 - val_f1: 0.8882
#
# Epoch 30/50 88/88 [==============================] - 15s 0.2s/step - loss: 0.7227 - accuracy: 0.8824 - precision: 0.8836 - recall: 0.8824 - f1: 0.8819 - val_loss: 0.6902 - val_accuracy: 0.8911 - val_precision: 0.8945 - val_recall: 0.8911 - val_f1: 0.8909
#
# Epoch 31/50 88/88 [==============================] - 15s 0.2s/step - loss: 0.7151 - accuracy: 0.8827 - precision: 0.8841 - recall: 0.8827 - f1: 0.8825 - val_loss: 0.6972 - val_accuracy: 0.8911 - val_precision: 0.8927 - val_recall: 0.8911 - val_f1: 0.8909
#
# Epoch 32/50 88/88 [==============================] - 15s 0.2s/step - loss: 0.7084 - accuracy: 0.8820 - precision: 0.8837 - recall: 0.8820 - f1: 0.8814 - val_loss: 0.6796 - val_accuracy: 0.8952 - val_precision: 0.8974 - val_recall: 0.8952 - val_f1: 0.8949
#
# Epoch 33/50 88/88 [==============================] - 16s 0.2s/step - loss: 0.7092 - accuracy: 0.8818 - precision: 0.8829 - recall: 0.8818 - f1: 0.8816 - val_loss: 0.6742 - val_accuracy: 0.9005 - val_precision: 0.9024 - val_recall: 0.9005 - val_f1: 0.9004
#
# Epoch 34/50 88/88 [==============================] - 15s 0.2s/step - loss: 0.7024 - accuracy: 0.8867 - precision: 0.8880 - recall: 0.8867 - f1: 0.8864 - val_loss: 0.6745 - val_accuracy: 0.8965 - val_precision: 0.8979 - val_recall: 0.8965 - val_f1: 0.8964
#
# Epoch 35/50 88/88 [==============================] - 15s 0.2s/step - loss: 0.7081 - accuracy: 0.8865 - precision: 0.8882 - recall: 0.8865 - f1: 0.8863 - val_loss: 0.6663 - val_accuracy: 0.8978 - val_precision: 0.8997 - val_recall: 0.8978 - val_f1: 0.8977
#
# Epoch 36/50 88/88 [==============================] - 16s 0.2s/step - loss: 0.6910 - accuracy: 0.8976 - precision: 0.8989 - recall: 0.8976 - f1: 0.8974 - val_loss: 0.6681 - val_accuracy: 0.8965 - val_precision: 0.8994 - val_recall: 0.8965 - val_f1: 0.8962
#
# Epoch 37/50 88/88 [==============================] - 16s 0.2s/step - loss: 0.6889 - accuracy: 0.8945 - precision: 0.8960 - recall: 0.8945 - f1: 0.8944 - val_loss: 0.6671 - val_accuracy: 0.9086 - val_precision: 0.9102 - val_recall: 0.9086 - val_f1: 0.9083
#
# Epoch 38/50 88/88 [==============================] - 15s 0.2s/step - loss: 0.6786 - accuracy: 0.9006 - precision: 0.9018 - recall: 0.9006 - f1: 0.9002 - val_loss: 0.6613 - val_accuracy: 0.9099 - val_precision: 0.9125 - val_recall: 0.9099 - val_f1: 0.9098
#
# Epoch 39/50 88/88 [==============================] - 15s 0.2s/step - loss: 0.6878 - accuracy: 0.8976 - precision: 0.8984 - recall: 0.8976 - f1: 0.8973 - val_loss: 0.6531 - val_accuracy: 0.9059 - val_precision: 0.9079 - val_recall: 0.9059 - val_f1: 0.9057
#
# Epoch 40/50 88/88 [==============================] - 16s 0.2s/step - loss: 0.6811 - accuracy: 0.8970 - precision: 0.8985 - recall: 0.8970 - f1: 0.8968 - val_loss: 0.6523 - val_accuracy: 0.9073 - val_precision: 0.9096 - val_recall: 0.9073 - val_f1: 0.9070
#
# Epoch 41/50 88/88 [==============================] - 16s 0.2s/step - loss: 0.6772 - accuracy: 0.8993 - precision: 0.9003 - recall: 0.8993 - f1: 0.8991 - val_loss: 0.6562 - val_accuracy: 0.9032 - val_precision: 0.9049 - val_recall: 0.9032 - val_f1: 0.9029
#
# Epoch 42/50 88/88 [==============================] - 16s 0.2s/step - loss: 0.6764 - accuracy: 0.9002 - precision: 0.9020 - recall: 0.9002 - f1: 0.9003 - val_loss: 0.6388 - val_accuracy: 0.9126 - val_precision: 0.9146 - val_recall: 0.9126 - val_f1: 0.9124
#
# Epoch 43/50 88/88 [==============================] - 18s 0.2s/step - loss: 0.6736 - accuracy: 0.8992 - precision: 0.9003 - recall: 0.8992 - f1: 0.8989 - val_loss: 0.6428 - val_accuracy: 0.9086 - val_precision: 0.9110 - val_recall: 0.9086 - val_f1: 0.9082
#
# Epoch 44/50 88/88 [==============================] - 17s 0.2s/step - loss: 0.6675 - accuracy: 0.9006 - precision: 0.9017 - recall: 0.9006 - f1: 0.9003 - val_loss: 0.6381 - val_accuracy: 0.9126 - val_precision: 0.9145 - val_recall: 0.9126 - val_f1: 0.9123
#
# Epoch 45/50 88/88 [==============================] - 16s 0.2s/step - loss: 0.6654 - accuracy: 0.9074 - precision: 0.9082 - recall: 0.9074 - f1: 0.9072 - val_loss: 0.6453 - val_accuracy: 0.9073 - val_precision: 0.9089 - val_recall: 0.9073 - val_f1: 0.9068
#
# Epoch 46/50 88/88 [==============================] - 16s 0.2s/step - loss: 0.6612 - accuracy: 0.9083 - precision: 0.9089 - recall: 0.9083 - f1: 0.9081 - val_loss: 0.6371 - val_accuracy: 0.9113 - val_precision: 0.9136 - val_recall: 0.9113 - val_f1: 0.9110
#
# Epoch 47/50 88/88 [==============================] - 17s 0.2s/step - loss: 0.6559 - accuracy: 0.9113 - precision: 0.9122 - recall: 0.9113 - f1: 0.9111 - val_loss: 0.6367 - val_accuracy: 0.9153 - val_precision: 0.9180 - val_recall: 0.9153 - val_f1: 0.9151
#
# Epoch 48/50 88/88 [==============================] - 15s 0.2s/step - loss: 0.6579 - accuracy: 0.9075 - precision: 0.9083 - recall: 0.9075 - f1: 0.9073 - val_loss: 0.6330 - val_accuracy: 0.9207 - val_precision: 0.9223 - val_recall: 0.9207 - val_f1: 0.9203
#
# Epoch 49/50 88/88 [==============================] - 16s 0.2s/step - loss: 0.6597 - accuracy: 0.9056 - precision: 0.9061 - recall: 0.9056 - f1: 0.9054 - val_loss: 0.6369 - val_accuracy: 0.9073 - val_precision: 0.9096 - val_recall: 0.9073 - val_f1: 0.9068
#
# Epoch 50/50 88/88 [==============================] - 16s 0.2s/step - loss: 0.6525 - accuracy: 0.9154 - precision: 0.9165 - recall: 0.9154 - f1: 0.9153 - val_loss: 0.6261 - val_accuracy: 0.9207 - val_precision: 0.9219 - val_recall: 0.9207 - val_f1: 0.9204
#
#
# ============================================================
#   TEST EVALUATION
# ============================================================
#   loss      : 0.6319
#   accuracy  : 0.9101
#   precision : 0.9116
#   recall    : 0.9101
#   f1_score  : 0.9101
# ============================================================
#
# Classification Report:
#                        precision    recall  f1-score   support
#
# bacterial_leaf_blight     0.8865    0.9259    0.9058       135
#            brown_spot     0.9552    0.8591    0.9046       149
#               healthy     0.8750    0.9256    0.8996       121
#            leaf_blast     0.8889    0.8889    0.8889       126
#            leaf_scald     0.9450    0.9279    0.9364       111
#     narrow_brown_spot     0.9159    0.9515    0.9333       103
#
#              accuracy                         0.9101       745
#             macro avg     0.9111    0.9131    0.9114       745
#          weighted avg     0.9116    0.9101    0.9101       745
#
#
#   ───────────────────────────────────────────────────────
#   MODEL PROFILE : InceptionV3
#   ───────────────────────────────────────────────────────
#   Total Params (M)      : 21.798
#   Trainable Params (M)  : 6.089
#   Disk Size (MB)        : 83.48
#   FLOPs (G)             : N/A
#   Inference (ms)        : 16.168
#   FPS                   : 61.85
#   ───────────────────────────────────────────────────────
#
#   Weights saved  ->  Model\InceptionV3\InceptionV3_weights.pth
#   History saved  ->  Model\InceptionV3\InceptionV3_history.json
#   Test metrics   ->  Model\InceptionV3\InceptionV3_test_metrics.json
#   Profile saved  ->  Model\InceptionV3\InceptionV3_profile.json
#
# InceptionV3 done.

# %%
# =============================================================================
#  TRAINING COMPLETE — all results saved under Model/<ModelName>/
# =============================================================================
import glob as _glob

print('=' * 70)
print('  ALL MODELS TRAINING COMPLETE')
print('=' * 70)
print()
print('Saved files:')
for p in sorted(_glob.glob(os.path.join(OUTPUT_DIR, '**', '*'), recursive=True)):
    if os.path.isfile(p):
        size_kb = os.path.getsize(p) / 1024
        print(f'  {p:<65}  ({size_kb:.1f} KB)')

print()
print('-- How to reload weights (example: ResNet50) --')
print("  model = build_resnet50(NUM_CLASSES)")
print("  model.load_state_dict(torch.load('Model/ResNet50/ResNet50_weights.pth', map_location=DEVICE))")
print("  model.to(DEVICE).eval()")
print()
print('-- How to reload history (example: ResNet50) --')
print("  with open('Model/ResNet50/ResNet50_history.json') as f:")
print("      h = json.load(f)")
print("  # h['val_accuracy'], h['val_f1'], h['loss'], ...")
# Out:
# ======================================================================
#   ALL MODELS TRAINING COMPLETE
# ======================================================================
#
# Saved files:
#   Model\InceptionV3\InceptionV3_history.json                         (7.5 KB)
#   Model\InceptionV3\InceptionV3_profile.json                         (0.2 KB)
#   Model\InceptionV3\InceptionV3_test_metrics.json                    (0.1 KB)
#   Model\InceptionV3\InceptionV3_weights.pth                          (85480.6 KB)
#   Model\MobileNetV2\MobileNetV2_history.json                         (7.5 KB)
#   Model\MobileNetV2\MobileNetV2_profile.json                         (0.2 KB)
#   Model\MobileNetV2\MobileNetV2_test_metrics.json                    (0.1 KB)
#   Model\MobileNetV2\MobileNetV2_weights.pth                          (8959.3 KB)
#   Model\ResNet50\ResNet50_history.json                               (7.5 KB)
#   Model\ResNet50\ResNet50_profile.json                               (0.2 KB)
#   Model\ResNet50\ResNet50_test_metrics.json                          (0.1 KB)
#   Model\ResNet50\ResNet50_weights.pth                                (92189.3 KB)
#   Model\VGG16\VGG16_history.json                                     (7.5 KB)
#   Model\VGG16\VGG16_profile.json                                     (0.2 KB)
#   Model\VGG16\VGG16_test_metrics.json                                (0.1 KB)
#   Model\VGG16\VGG16_weights.pth                                      (58528.1 KB)
#
# -- How to reload weights (example: ResNet50) --
#   model = build_resnet50(NUM_CLASSES)
#   model.load_state_dict(torch.load('Model/ResNet50/ResNet50_weights.pth', map_location=DEVICE))
#   model.to(DEVICE).eval()
#
# -- How to reload history (example: ResNet50) --
#   with open('Model/ResNet50/ResNet50_history.json') as f:
#       h = json.load(f)
#   # h['val_accuracy'], h['val_f1'], h['loss'], ...

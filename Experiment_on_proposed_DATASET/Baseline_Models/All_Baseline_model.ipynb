# %% [markdown]
# # All Baseline Models — PyTorch (Proposed Dataset)
#
# **Run all cells top-to-bottom.**
# Dataset: `TRAIN_DIR` + `VAL_DIR` split into train/val/test.
# All models train from scratch (`weights=None`, all layers trainable).
# Class weights applied to `CrossEntropyLoss` to handle imbalance.
#
# | Cell | Content |
# |------|---------|
# | 1 | Imports & Device Setup |
# | 2 | Configuration, Data Loading & Class Weights |
# | 3 | Shared Utilities |
# | 4 | **ResNet50** |
# | 5 | **VGG16** |
# | 6 | **MobileNetV2** |
# | 7 | **InceptionV3** |
# | 8 | Final Summary |

# %%
import os, copy, json, time, warnings
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader
from PIL import Image
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import (accuracy_score, precision_score,
                             recall_score, f1_score, classification_report)

warnings.filterwarnings('ignore')

DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
if DEVICE.type == 'cuda':
    torch.backends.cudnn.benchmark = True

print(f'PyTorch     : {torch.__version__}')
print(f'Torchvision : {torchvision.__version__}')
print(f'Device      : {DEVICE}')
if DEVICE.type == 'cuda':
    print(f'GPU         : {torch.cuda.get_device_name(0)}')
    print(f'CUDA        : {torch.version.cuda}')
    print(f'Total VRAM  : {torch.cuda.get_device_properties(0).total_memory / 1024**3:.2f} GB')
# Out:
# PyTorch     : 2.5.1+cu121
# Torchvision : 0.20.1+cu121
# Device      : cuda
# GPU         : NVIDIA RTX 5000 Ada Generation
# CUDA        : 12.1
# Total VRAM  : 31.99 GB

# %%
# ── Hyper-parameters ──────────────────────────────────────────
BATCH_SIZE  = 64
IMAGE_SIZE  = (224, 224)
EPOCHS      = 50
RANDOM_SEED = 42

TRAIN_DIR  = r'..\Proposed_Dataset\train'
VAL_DIR    = r'..\Proposed_Dataset\validation'
OUTPUT_DIR = 'Model'
os.makedirs(OUTPUT_DIR, exist_ok=True)

torch.manual_seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)

print(f'Output directory : {os.path.abspath(OUTPUT_DIR)}')

# ── Load images from TRAIN_DIR and VAL_DIR ────────────────────
def load_filepaths_labels(directory):
    filepaths, labels = [], []
    for cls in sorted(os.listdir(directory)):
        cls_dir = os.path.join(directory, cls)
        if not os.path.isdir(cls_dir):
            continue
        for f in os.listdir(cls_dir):
            if f.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp')):
                filepaths.append(os.path.join(cls_dir, f))
                labels.append(cls)
    return filepaths, labels

fp_train, lb_train = load_filepaths_labels(TRAIN_DIR)
fp_val,   lb_val   = load_filepaths_labels(VAL_DIR)

# TRAIN_DIR → training set
df_train = pd.DataFrame({'filepath': fp_train, 'label': lb_train})
df_train = df_train.drop_duplicates(subset='filepath').reset_index(drop=True)

# VAL_DIR → 50/50 split into val and test
val_full_df = pd.DataFrame({'filepath': fp_val, 'label': lb_val})
val_full_df = val_full_df.drop_duplicates(subset='filepath').reset_index(drop=True)

df_val, df_test = train_test_split(
    val_full_df, test_size=0.50, shuffle=True,
    stratify=val_full_df['label'], random_state=123
)

# Derive class metadata
all_labels   = sorted(set(df_train['label'].unique()) | set(val_full_df['label'].unique()))
classes      = all_labels
class_to_idx = {c: i for i, c in enumerate(classes)}
NUM_CLASSES  = len(classes)

print(f'Train images     : {len(df_train)}')
print(f'Val images       : {len(df_val)}')
print(f'Test images      : {len(df_test)}')
print(f'Number of classes: {NUM_CLASSES}')
print(f'Class names      : {classes}')
print()
print('Train label distribution:')
print(df_train['label'].value_counts())
print(f'\nTrain : {len(df_train)}  |  Val : {len(df_val)}  |  Test : {len(df_test)}')

# ── Class weights ─────────────────────────────────────────────
y_train_encoded  = df_train['label'].map(class_to_idx).values
class_weights    = compute_class_weight(
    class_weight='balanced',
    classes=np.arange(NUM_CLASSES),
    y=y_train_encoded
)
class_weights_tensor = torch.tensor(class_weights, dtype=torch.float32)

print('Class weights:')
for cls, w in zip(classes, class_weights):
    print(f'  {cls:<25} : {w:.4f}')
# Out:
# Output directory : c:\Users\km1612\Documents\riceMobileNet\RiceMobileNet_final\RiceMobileNEt Code\Experiment_on_proposed_DATASET\Baseline_Models\Model
# Train images     : 5603
# Val images       : 744
# Test images      : 745
# Number of classes: 6
# Class names      : ['bacterial_leaf_blight', 'brown_spot', 'healthy', 'leaf_blast', 'leaf_scald', 'narrow_brown_spot']
#
# Train label distribution:
# label
# brown_spot               1148
# leaf_blast               1016
# healthy                   972
# bacterial_leaf_blight     913
# leaf_scald                875
# narrow_brown_spot         679
# Name: count, dtype: int64
#
# Train : 5603  |  Val : 744  |  Test : 745
# Class weights:
#   bacterial_leaf_blight     : 1.0228
#   brown_spot                : 0.8134
#   healthy                   : 0.9607
#   leaf_blast                : 0.9191
#   leaf_scald                : 1.0672
#   narrow_brown_spot         : 1.3753

# %%
# =============================================================================
#  SHARED UTILITIES  (run once — used by every model below)
# =============================================================================

# ── Custom Dataset ────────────────────────────────────────────
class ImageDataFrameDataset(Dataset):
    def __init__(self, df, transform=None):
        self.df        = df.reset_index(drop=True)
        self.transform = transform
        self.encoded   = [class_to_idx[l] for l in self.df['label']]
    def __len__(self):
        return len(self.df)
    def __getitem__(self, idx):
        img = Image.open(self.df.iloc[idx]['filepath']).convert('RGB')
        if self.transform:
            img = self.transform(img)
        return img, self.encoded[idx]


# ── Normalization constants ───────────────────────────────────
IMAGENET_NORM = transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
MINUSONE_NORM = transforms.Normalize([0.5,   0.5,   0.5  ], [0.5,   0.5,   0.5  ])
IDENTITY_NORM = transforms.Normalize([0.0,   0.0,   0.0  ], [1.0,   1.0,   1.0  ])


# ── Early Stopping ────────────────────────────────────────────
class EarlyStopping:
    def __init__(self, patience=7):
        self.patience     = patience
        self.best_loss    = float('inf')
        self.counter      = 0
        self.best_weights = None
    def __call__(self, val_loss, model):
        if val_loss < self.best_loss:
            self.best_loss    = val_loss
            self.counter      = 0
            self.best_weights = copy.deepcopy(model.state_dict())
            return False
        self.counter += 1
        return self.counter >= self.patience
    def restore(self, model):
        if self.best_weights is not None:
            model.load_state_dict(self.best_weights)


# ── DataLoader factory ────────────────────────────────────────
def make_loaders(train_t, val_t, batch_size=BATCH_SIZE):
    pin = (DEVICE.type == 'cuda')
    train_loader = DataLoader(
        ImageDataFrameDataset(df_train, train_t),
        batch_size=batch_size, shuffle=True,  num_workers=0, pin_memory=pin)
    val_loader = DataLoader(
        ImageDataFrameDataset(df_val, val_t),
        batch_size=batch_size, shuffle=False, num_workers=0, pin_memory=pin)
    test_loader = DataLoader(
        ImageDataFrameDataset(df_test, val_t),
        batch_size=batch_size, shuffle=False, num_workers=0, pin_memory=pin)
    return train_loader, val_loader, test_loader


# ── Keras-style progress bar ──────────────────────────────────
def _bar(current, total, width=30):
    filled = int(width * current / total)
    return '=' * filled + '-' * (width - filled)


# ── Training Engine ───────────────────────────────────────────
def train_model(model, model_name, train_loader, val_loader):
    criterion = nn.CrossEntropyLoss(weight=class_weights_tensor.to(DEVICE), label_smoothing=0.1)
    optimizer = torch.optim.Adam(
        filter(lambda p: p.requires_grad, model.parameters()), lr=1e-5
    )
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, mode='min', patience=3, factor=0.5
    )
    scaler = torch.cuda.amp.GradScaler(enabled=(DEVICE.type == 'cuda'))
    es     = EarlyStopping(patience=7)

    history = {k: [] for k in [
        'loss', 'accuracy', 'precision', 'recall', 'f1',
        'val_loss', 'val_accuracy', 'val_precision', 'val_recall', 'val_f1'
    ]}

    n_batches = len(train_loader)

    print(f'\nModel  : {model_name}')
    print(f'Train batches : {n_batches}  |  Val batches : {len(val_loader)}')
    print(f'Device : {DEVICE}' + (
        f'  ({torch.cuda.get_device_name(0)})' if DEVICE.type == 'cuda' else ''))
    print('-' * 110)

    for epoch in range(1, EPOCHS + 1):
        # ── Train ──
        model.train()
        t0 = time.time()
        ep_loss = 0.0
        ep_preds, ep_labels = [], []

        for bi, (imgs, labels) in enumerate(train_loader, 1):
            imgs   = imgs.to(DEVICE,   non_blocking=True)
            labels = labels.to(DEVICE, non_blocking=True)

            optimizer.zero_grad(set_to_none=True)

            with torch.cuda.amp.autocast(enabled=(DEVICE.type == 'cuda')):
                out = model(imgs)
                if isinstance(out, torchvision.models.inception.InceptionOutputs):
                    out = out.logits
                loss = criterion(out, labels)

            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()

            ep_loss += loss.item() * imgs.size(0)
            ep_preds.extend(out.argmax(1).detach().cpu().numpy())
            ep_labels.extend(labels.detach().cpu().numpy())

            print(f'\rEpoch {epoch}/{EPOCHS} {bi}/{n_batches} [{_bar(bi, n_batches)}]',
                  end='', flush=True)

        # ── Train metrics ──
        tr_loss = ep_loss / len(train_loader.dataset)
        tr_acc  = accuracy_score(ep_labels, ep_preds)
        tr_prec = precision_score(ep_labels, ep_preds, average='weighted', zero_division=0)
        tr_rec  = recall_score(ep_labels,   ep_preds, average='weighted', zero_division=0)
        tr_f1   = f1_score(ep_labels,       ep_preds, average='weighted', zero_division=0)

        # ── Validate ──
        model.eval()
        vl_loss = 0.0
        vl_preds, vl_labels = [], []

        with torch.no_grad():
            for imgs, labels in val_loader:
                imgs   = imgs.to(DEVICE,   non_blocking=True)
                labels = labels.to(DEVICE, non_blocking=True)
                with torch.cuda.amp.autocast(enabled=(DEVICE.type == 'cuda')):
                    out = model(imgs)
                    if isinstance(out, torchvision.models.inception.InceptionOutputs):
                        out = out.logits
                    loss = criterion(out, labels)
                vl_loss += loss.item() * imgs.size(0)
                vl_preds.extend(out.argmax(1).cpu().numpy())
                vl_labels.extend(labels.cpu().numpy())

        vl_loss /= len(val_loader.dataset)
        vl_acc   = accuracy_score(vl_labels, vl_preds)
        vl_prec  = precision_score(vl_labels, vl_preds, average='weighted', zero_division=0)
        vl_rec   = recall_score(vl_labels,   vl_preds, average='weighted', zero_division=0)
        vl_f1    = f1_score(vl_labels,       vl_preds, average='weighted', zero_division=0)

        elapsed   = time.time() - t0
        step_time = elapsed / n_batches

        print(
            f'\rEpoch {epoch}/{EPOCHS} {n_batches}/{n_batches} [{"=" * 30}] - '
            f'{elapsed:.0f}s {step_time:.1f}s/step - '
            f'loss: {tr_loss:.4f} - accuracy: {tr_acc:.4f} - '
            f'precision: {tr_prec:.4f} - recall: {tr_rec:.4f} - f1: {tr_f1:.4f} - '
            f'val_loss: {vl_loss:.4f} - val_accuracy: {vl_acc:.4f} - '
            f'val_precision: {vl_prec:.4f} - val_recall: {vl_rec:.4f} - val_f1: {vl_f1:.4f}',
            flush=True
        )
        print()

        for key, val in [
            ('loss',          tr_loss), ('accuracy',      tr_acc),
            ('precision',     tr_prec), ('recall',        tr_rec),  ('f1',      tr_f1),
            ('val_loss',      vl_loss), ('val_accuracy',  vl_acc),
            ('val_precision', vl_prec), ('val_recall',    vl_rec),  ('val_f1',  vl_f1),
        ]:
            history[key].append(round(float(val), 6))

        scheduler.step(vl_loss)

        if es(vl_loss, model):
            print(f'  >> Early stopping at epoch {epoch}. '
                  f'Best val_loss = {es.best_loss:.4f}')
            break

    es.restore(model)
    return history


# ── Test Evaluation ───────────────────────────────────────────
def evaluate_on_test(model, test_loader):
    criterion = nn.CrossEntropyLoss(weight=class_weights_tensor.to(DEVICE), label_smoothing=0.1)
    model.eval()
    tl, tp, tg = 0.0, [], []
    with torch.no_grad():
        for imgs, labels in test_loader:
            imgs   = imgs.to(DEVICE,   non_blocking=True)
            labels = labels.to(DEVICE, non_blocking=True)
            with torch.cuda.amp.autocast(enabled=(DEVICE.type == 'cuda')):
                out = model(imgs)
                if isinstance(out, torchvision.models.inception.InceptionOutputs):
                    out = out.logits
                loss = criterion(out, labels)
            tl += loss.item() * imgs.size(0)
            tp.extend(out.argmax(1).cpu().numpy())
            tg.extend(labels.cpu().numpy())
    tl   /= len(test_loader.dataset)
    acc   = accuracy_score(tg, tp)
    prec  = precision_score(tg, tp, average='weighted', zero_division=0)
    rec   = recall_score(tg,   tp, average='weighted', zero_division=0)
    f1    = f1_score(tg,       tp, average='weighted', zero_division=0)
    print(f'\n{"=" * 60}')
    print('  TEST EVALUATION')
    print(f'{"=" * 60}')
    print(f'  loss      : {tl:.4f}')
    print(f'  accuracy  : {acc:.4f}')
    print(f'  precision : {prec:.4f}')
    print(f'  recall    : {rec:.4f}')
    print(f'  f1_score  : {f1:.4f}')
    print(f'{"=" * 60}')
    print()
    print('Classification Report:')
    print(classification_report(tg, tp, target_names=classes, digits=4))
    return tp, tg


print('All shared utilities ready.')

# ── Model Statistics Helper ──────────────────────────────────────────────────
def compute_model_stats(model, model_name, input_size=(1, 3, 224, 224), n_runs=100):
    """
    Returns a dict with:
      total_params_M      : total parameters (millions)
      trainable_params_M  : trainable parameters (millions)
      disk_size_mb        : .pth file size on disk (MB) — estimated from param bytes
      flops_g             : FLOPs (GFLOPs) via torch.profiler
      inference_ms        : mean single-image inference time (ms)
      fps                 : frames per second
    """
    import os, tempfile, time
    # ── Param counts ──────────────────────────────────────────
    total_p     = sum(p.numel() for p in model.parameters())
    trainable_p = sum(p.numel() for p in model.parameters() if p.requires_grad)

    # ── Disk size: save state_dict to a temp file, measure bytes ──
    tmp = tempfile.NamedTemporaryFile(suffix='.pth', delete=False)
    tmp.close()
    torch.save(model.state_dict(), tmp.name)
    disk_mb = os.path.getsize(tmp.name) / 1024**2
    os.unlink(tmp.name)

    # ── FLOPs via torch.profiler CPU-op counting ──────────────
    flops_g = None
    try:
        from torch.profiler import profile, ProfilerActivity, record_function
        dummy = torch.randn(*input_size).to(DEVICE)
        model.eval()
        with torch.no_grad():
            with profile(activities=[ProfilerActivity.CPU],
                         record_shapes=True,
                         with_flops=True) as prof:
                with record_function("model_inference"):
                    out = model(dummy)
        total_flops = sum(e.flops for e in prof.key_averages() if e.flops > 0)
        flops_g = total_flops / 1e9
    except Exception:
        flops_g = float('nan')

    # ── Inference latency ─────────────────────────────────────
    model.eval()
    dummy = torch.randn(*input_size).to(DEVICE)
    # warm-up
    with torch.no_grad():
        for _ in range(10):
            _ = model(dummy)
    if DEVICE.type == 'cuda':
        torch.cuda.synchronize()
    times = []
    with torch.no_grad():
        for _ in range(n_runs):
            t0 = time.perf_counter()
            _ = model(dummy)
            if DEVICE.type == 'cuda':
                torch.cuda.synchronize()
            times.append(time.perf_counter() - t0)
    inf_ms = (sum(times) / len(times)) * 1000
    fps    = 1000.0 / inf_ms

    stats = {
        'model'               : model_name,
        'total_params_M'      : round(total_p     / 1e6, 4),
        'trainable_params_M'  : round(trainable_p / 1e6, 4),
        'disk_size_mb'        : round(disk_mb,            4),
        'flops_g'             : round(flops_g,            4) if flops_g == flops_g else None,
        'inference_ms'        : round(inf_ms,             4),
        'fps'                 : round(fps,                2),
    }

    print(f'\n  ── Model Statistics: {model_name} ──')
    print(f'  Total Params (M)      : {stats["total_params_M"]}')
    print(f'  Trainable Params (M)  : {stats["trainable_params_M"]}')
    print(f'  Disk Size (MB)        : {stats["disk_size_mb"]}')
    print(f'  FLOPs (G)             : {stats["flops_g"]}')
    print(f'  Inference (ms)        : {stats["inference_ms"]}')
    print(f'  FPS                   : {stats["fps"]}')
    return stats



# ── Save all results to model-specific subfolder ─────────────────────────────
def save_all_results(model, model_name, history, model_stats,
                     test_preds, test_labels, input_size=(1, 3, 224, 224)):
    """
    Saves everything for one model into OUTPUT_DIR/<model_name>/:
      <model_name>_weights.pth
      <model_name>_history.json
      <model_name>_stats.json          (params, disk size, FLOPs, latency, FPS)
      <model_name>_test_metrics.json   (loss, acc, prec, rec, f1)
      <model_name>_classification_report.txt
    """
    import os
    folder = os.path.join(OUTPUT_DIR, model_name)
    os.makedirs(folder, exist_ok=True)

    # weights
    w_path = os.path.join(folder, f'{model_name}_weights.pth')
    torch.save(model.state_dict(), w_path)

    # history
    h_path = os.path.join(folder, f'{model_name}_history.json')
    with open(h_path, 'w') as f:
        json.dump(history, f, indent=2)

    # model stats
    s_path = os.path.join(folder, f'{model_name}_stats.json')
    with open(s_path, 'w') as f:
        json.dump(model_stats, f, indent=2)

    # test metrics
    from sklearn.metrics import (accuracy_score, precision_score,
                                  recall_score, f1_score, classification_report)
    test_metrics = {
        'accuracy' : round(accuracy_score(test_labels, test_preds),  6),
        'precision': round(precision_score(test_labels, test_preds,
                                           average='weighted', zero_division=0), 6),
        'recall'   : round(recall_score(test_labels, test_preds,
                                        average='weighted', zero_division=0), 6),
        'f1'       : round(f1_score(test_labels, test_preds,
                                    average='weighted', zero_division=0), 6),
    }
    tm_path = os.path.join(folder, f'{model_name}_test_metrics.json')
    with open(tm_path, 'w') as f:
        json.dump(test_metrics, f, indent=2)

    # classification report
    cr = classification_report(test_labels, test_preds,
                                target_names=classes, digits=4)
    cr_path = os.path.join(folder, f'{model_name}_classification_report.txt')
    with open(cr_path, 'w') as f:
        f.write(cr)

    print(f'  All results saved -> {folder}/')
    print(f'    {os.path.basename(w_path)}')
    print(f'    {os.path.basename(h_path)}')
    print(f'    {os.path.basename(s_path)}')
    print(f'    {os.path.basename(tm_path)}')
    print(f'    {os.path.basename(cr_path)}')


print('All shared utilities ready.')
# Out:
# All shared utilities ready.
# All shared utilities ready.

# %%
# =============================================================================
#  MODEL 1 : ResNet50
# =============================================================================
print('=' * 70)
print('  MODEL: ResNet50')
print('=' * 70)

# ── Transforms ────────────────────────────────────────────────
resnet_train_t = transforms.Compose([
    transforms.Resize(IMAGE_SIZE),
    transforms.RandomRotation(25),
    transforms.RandomAffine(degrees=0, translate=(0.15, 0.15), shear=5.7),
    transforms.ToTensor(),
    IMAGENET_NORM,
])
resnet_val_t = transforms.Compose([
    transforms.Resize(IMAGE_SIZE),
    transforms.ToTensor(),
    IMAGENET_NORM,
])

resnet_train_loader, resnet_val_loader, resnet_test_loader = make_loaders(resnet_train_t, resnet_val_t)

# ── Architecture ──────────────────────────────────────────────
# weights=None  → random initialisation, train from scratch
# base_model.trainable = True  → all layers are trainable (PyTorch default)
def build_resnet50(num_classes=NUM_CLASSES):
    model = torchvision.models.resnet50(weights=None)  # no ImageNet weights
    for p in model.parameters():                       # all layers trainable
        p.requires_grad = True
    model.fc = nn.Linear(model.fc.in_features, num_classes)
    return model

resnet_model = build_resnet50(NUM_CLASSES).to(DEVICE)
print(f'Trainable params : {sum(p.numel() for p in resnet_model.parameters() if p.requires_grad):,}')

resnet_history = train_model(resnet_model, 'ResNet50', resnet_train_loader, resnet_val_loader)
resnet_test_preds, resnet_test_labels = evaluate_on_test(resnet_model, resnet_test_loader)
resnet_stats = compute_model_stats(resnet_model, 'ResNet50')
save_all_results(resnet_model, 'ResNet50', resnet_history, resnet_stats,
                 resnet_test_preds, resnet_test_labels)

del resnet_model, resnet_train_loader, resnet_val_loader, resnet_test_loader
if DEVICE.type == 'cuda': torch.cuda.empty_cache()
print('\nResNet50 done.\n')
# Out:
# ======================================================================
#   MODEL: ResNet50
# ======================================================================
# Trainable params : 23,520,326
#
# Model  : ResNet50
# Train batches : 88  |  Val batches : 12
# Device : cuda  (NVIDIA RTX 5000 Ada Generation)
# --------------------------------------------------------------------------------------------------------------
# Epoch 1/50 88/88 [==============================] - 77s 0.9s/step - loss: 1.7417 - accuracy: 0.3093 - precision: 0.3009 - recall: 0.3093 - f1: 0.2735 - val_loss: 1.6975 - val_accuracy: 0.2863 - val_precision: 0.2374 - val_recall: 0.2863 - val_f1: 0.2335
#
# Epoch 2/50 88/88 [==============================] - 40s 0.5s/step - loss: 1.6075 - accuracy: 0.3937 - precision: 0.3727 - recall: 0.3937 - f1: 0.3663 - val_loss: 1.5870 - val_accuracy: 0.3548 - val_precision: 0.3582 - val_recall: 0.3548 - val_f1: 0.3056
#
# Epoch 3/50 88/88 [==============================] - 43s 0.5s/step - loss: 1.4856 - accuracy: 0.4596 - precision: 0.4592 - recall: 0.4596 - f1: 0.4518 - val_loss: 1.5500 - val_accuracy: 0.4435 - val_precision: 0.4548 - val_recall: 0.4435 - val_f1: 0.4084
#
# Epoch 4/50 88/88 [==============================] - 44s 0.5s/step - loss: 1.3797 - accuracy: 0.5142 - precision: 0.5211 - recall: 0.5142 - f1: 0.5085 - val_loss: 1.4852 - val_accuracy: 0.5081 - val_precision: 0.5106 - val_recall: 0.5081 - val_f1: 0.4939
#
# Epoch 5/50 88/88 [==============================] - 42s 0.5s/step - loss: 1.3093 - accuracy: 0.5490 - precision: 0.5569 - recall: 0.5490 - f1: 0.5458 - val_loss: 1.4833 - val_accuracy: 0.5121 - val_precision: 0.5392 - val_recall: 0.5121 - val_f1: 0.4941
#
# Epoch 6/50 88/88 [==============================] - 43s 0.5s/step - loss: 1.2629 - accuracy: 0.5777 - precision: 0.5807 - recall: 0.5777 - f1: 0.5721 - val_loss: 1.4295 - val_accuracy: 0.5672 - val_precision: 0.6101 - val_recall: 0.5672 - val_f1: 0.5574
#
# Epoch 7/50 88/88 [==============================] - 44s 0.5s/step - loss: 1.2190 - accuracy: 0.6091 - precision: 0.6150 - recall: 0.6091 - f1: 0.6043 - val_loss: 1.4104 - val_accuracy: 0.6183 - val_precision: 0.6515 - val_recall: 0.6183 - val_f1: 0.6088
#
# Epoch 8/50 88/88 [==============================] - 43s 0.5s/step - loss: 1.1667 - accuracy: 0.6395 - precision: 0.6440 - recall: 0.6395 - f1: 0.6362 - val_loss: 1.5560 - val_accuracy: 0.6331 - val_precision: 0.6595 - val_recall: 0.6331 - val_f1: 0.6328
#
# Epoch 9/50 88/88 [==============================] - 41s 0.5s/step - loss: 1.1346 - accuracy: 0.6557 - precision: 0.6614 - recall: 0.6557 - f1: 0.6523 - val_loss: 1.6670 - val_accuracy: 0.6263 - val_precision: 0.6564 - val_recall: 0.6263 - val_f1: 0.6276
#
# Epoch 10/50 88/88 [==============================] - 44s 0.5s/step - loss: 1.1024 - accuracy: 0.6743 - precision: 0.6812 - recall: 0.6743 - f1: 0.6719 - val_loss: 1.4427 - val_accuracy: 0.6640 - val_precision: 0.6948 - val_recall: 0.6640 - val_f1: 0.6610
#
# Epoch 11/50 88/88 [==============================] - 41s 0.5s/step - loss: 1.0680 - accuracy: 0.6911 - precision: 0.6975 - recall: 0.6911 - f1: 0.6882 - val_loss: 1.4523 - val_accuracy: 0.6815 - val_precision: 0.7040 - val_recall: 0.6815 - val_f1: 0.6794
#
# Epoch 12/50 88/88 [==============================] - 44s 0.5s/step - loss: 1.0383 - accuracy: 0.7114 - precision: 0.7177 - recall: 0.7114 - f1: 0.7087 - val_loss: 1.4558 - val_accuracy: 0.6868 - val_precision: 0.7188 - val_recall: 0.6868 - val_f1: 0.6892
#
# Epoch 13/50 88/88 [==============================] - 42s 0.5s/step - loss: 1.0245 - accuracy: 0.7207 - precision: 0.7267 - recall: 0.7207 - f1: 0.7177 - val_loss: 1.5505 - val_accuracy: 0.6895 - val_precision: 0.7166 - val_recall: 0.6895 - val_f1: 0.6905
#
# Epoch 14/50 88/88 [==============================] - 43s 0.5s/step - loss: 1.0145 - accuracy: 0.7194 - precision: 0.7281 - recall: 0.7194 - f1: 0.7176 - val_loss: 1.3473 - val_accuracy: 0.7110 - val_precision: 0.7446 - val_recall: 0.7110 - val_f1: 0.7130
#
# Epoch 15/50 88/88 [==============================] - 41s 0.5s/step - loss: 0.9900 - accuracy: 0.7414 - precision: 0.7471 - recall: 0.7414 - f1: 0.7387 - val_loss: 1.3258 - val_accuracy: 0.7218 - val_precision: 0.7559 - val_recall: 0.7218 - val_f1: 0.7261
#
# Epoch 16/50 88/88 [==============================] - 43s 0.5s/step - loss: 0.9921 - accuracy: 0.7318 - precision: 0.7371 - recall: 0.7318 - f1: 0.7297 - val_loss: 1.2807 - val_accuracy: 0.7231 - val_precision: 0.7456 - val_recall: 0.7231 - val_f1: 0.7252
#
# Epoch 17/50 88/88 [==============================] - 42s 0.5s/step - loss: 0.9736 - accuracy: 0.7453 - precision: 0.7520 - recall: 0.7453 - f1: 0.7429 - val_loss: 1.4863 - val_accuracy: 0.7003 - val_precision: 0.7310 - val_recall: 0.7003 - val_f1: 0.7016
#
# Epoch 18/50 88/88 [==============================] - 42s 0.5s/step - loss: 0.9645 - accuracy: 0.7426 - precision: 0.7493 - recall: 0.7426 - f1: 0.7408 - val_loss: 1.3462 - val_accuracy: 0.7124 - val_precision: 0.7405 - val_recall: 0.7124 - val_f1: 0.7135
#
# Epoch 19/50 88/88 [==============================] - 43s 0.5s/step - loss: 0.9630 - accuracy: 0.7498 - precision: 0.7560 - recall: 0.7498 - f1: 0.7483 - val_loss: 1.1517 - val_accuracy: 0.7379 - val_precision: 0.7610 - val_recall: 0.7379 - val_f1: 0.7394
#
# Epoch 20/50 88/88 [==============================] - 43s 0.5s/step - loss: 0.9477 - accuracy: 0.7567 - precision: 0.7630 - recall: 0.7567 - f1: 0.7550 - val_loss: 1.2375 - val_accuracy: 0.7419 - val_precision: 0.7686 - val_recall: 0.7419 - val_f1: 0.7428
#
# Epoch 21/50 88/88 [==============================] - 42s 0.5s/step - loss: 0.9288 - accuracy: 0.7637 - precision: 0.7693 - recall: 0.7637 - f1: 0.7619 - val_loss: 1.2353 - val_accuracy: 0.7634 - val_precision: 0.7949 - val_recall: 0.7634 - val_f1: 0.7652
#
# Epoch 22/50 88/88 [==============================] - 43s 0.5s/step - loss: 0.9233 - accuracy: 0.7701 - precision: 0.7755 - recall: 0.7701 - f1: 0.7680 - val_loss: 1.0884 - val_accuracy: 0.7688 - val_precision: 0.7886 - val_recall: 0.7688 - val_f1: 0.7690
#
# Epoch 23/50 88/88 [==============================] - 43s 0.5s/step - loss: 0.9161 - accuracy: 0.7723 - precision: 0.7789 - recall: 0.7723 - f1: 0.7705 - val_loss: 1.0816 - val_accuracy: 0.7540 - val_precision: 0.7778 - val_recall: 0.7540 - val_f1: 0.7549
#
# Epoch 24/50 88/88 [==============================] - 43s 0.5s/step - loss: 0.9003 - accuracy: 0.7783 - precision: 0.7849 - recall: 0.7783 - f1: 0.7770 - val_loss: 1.2417 - val_accuracy: 0.7513 - val_precision: 0.7830 - val_recall: 0.7513 - val_f1: 0.7524
#
# Epoch 25/50 88/88 [==============================] - 44s 0.5s/step - loss: 0.8842 - accuracy: 0.7898 - precision: 0.7949 - recall: 0.7898 - f1: 0.7883 - val_loss: 1.0464 - val_accuracy: 0.7755 - val_precision: 0.7988 - val_recall: 0.7755 - val_f1: 0.7761
#
# Epoch 26/50 88/88 [==============================] - 42s 0.5s/step - loss: 0.8872 - accuracy: 0.7905 - precision: 0.7958 - recall: 0.7905 - f1: 0.7888 - val_loss: 1.0938 - val_accuracy: 0.7675 - val_precision: 0.7918 - val_recall: 0.7675 - val_f1: 0.7682
#
# Epoch 27/50 88/88 [==============================] - 42s 0.5s/step - loss: 0.8815 - accuracy: 0.7864 - precision: 0.7913 - recall: 0.7864 - f1: 0.7848 - val_loss: 1.1593 - val_accuracy: 0.7500 - val_precision: 0.7788 - val_recall: 0.7500 - val_f1: 0.7511
#
# Epoch 28/50 88/88 [==============================] - 42s 0.5s/step - loss: 0.8653 - accuracy: 0.8021 - precision: 0.8075 - recall: 0.8021 - f1: 0.8009 - val_loss: 0.9828 - val_accuracy: 0.7782 - val_precision: 0.7977 - val_recall: 0.7782 - val_f1: 0.7766
#
# Epoch 29/50 88/88 [==============================] - 43s 0.5s/step - loss: 0.8633 - accuracy: 0.8040 - precision: 0.8094 - recall: 0.8040 - f1: 0.8025 - val_loss: 1.0755 - val_accuracy: 0.7769 - val_precision: 0.8036 - val_recall: 0.7769 - val_f1: 0.7787
#
# Epoch 30/50 88/88 [==============================] - 42s 0.5s/step - loss: 0.8601 - accuracy: 0.8006 - precision: 0.8042 - recall: 0.8006 - f1: 0.7993 - val_loss: 0.9669 - val_accuracy: 0.8011 - val_precision: 0.8210 - val_recall: 0.8011 - val_f1: 0.8015
#
# Epoch 31/50 88/88 [==============================] - 43s 0.5s/step - loss: 0.8553 - accuracy: 0.8044 - precision: 0.8089 - recall: 0.8044 - f1: 0.8034 - val_loss: 1.0072 - val_accuracy: 0.7930 - val_precision: 0.8178 - val_recall: 0.7930 - val_f1: 0.7942
#
# Epoch 32/50 88/88 [==============================] - 42s 0.5s/step - loss: 0.8484 - accuracy: 0.8151 - precision: 0.8204 - recall: 0.8151 - f1: 0.8140 - val_loss: 1.0927 - val_accuracy: 0.7903 - val_precision: 0.8198 - val_recall: 0.7903 - val_f1: 0.7912
#
# Epoch 33/50 88/88 [==============================] - 44s 0.5s/step - loss: 0.8299 - accuracy: 0.8196 - precision: 0.8238 - recall: 0.8196 - f1: 0.8183 - val_loss: 0.9585 - val_accuracy: 0.7930 - val_precision: 0.8107 - val_recall: 0.7930 - val_f1: 0.7939
#
# Epoch 34/50 88/88 [==============================] - 45s 0.5s/step - loss: 0.8236 - accuracy: 0.8188 - precision: 0.8234 - recall: 0.8188 - f1: 0.8172 - val_loss: 0.9365 - val_accuracy: 0.8118 - val_precision: 0.8287 - val_recall: 0.8118 - val_f1: 0.8114
#
# Epoch 35/50 88/88 [==============================] - 43s 0.5s/step - loss: 0.8255 - accuracy: 0.8231 - precision: 0.8272 - recall: 0.8231 - f1: 0.8221 - val_loss: 0.9819 - val_accuracy: 0.7930 - val_precision: 0.8138 - val_recall: 0.7930 - val_f1: 0.7940
#
# Epoch 36/50 88/88 [==============================] - 44s 0.5s/step - loss: 0.8121 - accuracy: 0.8271 - precision: 0.8307 - recall: 0.8271 - f1: 0.8263 - val_loss: 0.9611 - val_accuracy: 0.8091 - val_precision: 0.8318 - val_recall: 0.8091 - val_f1: 0.8094
#
# Epoch 37/50 88/88 [==============================] - 45s 0.5s/step - loss: 0.8127 - accuracy: 0.8271 - precision: 0.8304 - recall: 0.8271 - f1: 0.8259 - val_loss: 0.9645 - val_accuracy: 0.8132 - val_precision: 0.8345 - val_recall: 0.8132 - val_f1: 0.8131
#
# Epoch 38/50 88/88 [==============================] - 43s 0.5s/step - loss: 0.8078 - accuracy: 0.8324 - precision: 0.8360 - recall: 0.8324 - f1: 0.8317 - val_loss: 1.0568 - val_accuracy: 0.7997 - val_precision: 0.8316 - val_recall: 0.7997 - val_f1: 0.8015
#
# Epoch 39/50 88/88 [==============================] - 44s 0.5s/step - loss: 0.7966 - accuracy: 0.8356 - precision: 0.8397 - recall: 0.8356 - f1: 0.8350 - val_loss: 1.0262 - val_accuracy: 0.8038 - val_precision: 0.8349 - val_recall: 0.8038 - val_f1: 0.8057
#
# Epoch 40/50 88/88 [==============================] - 44s 0.5s/step - loss: 0.7838 - accuracy: 0.8412 - precision: 0.8446 - recall: 0.8412 - f1: 0.8405 - val_loss: 1.0163 - val_accuracy: 0.7970 - val_precision: 0.8267 - val_recall: 0.7970 - val_f1: 0.7991
#
# Epoch 41/50 88/88 [==============================] - 46s 0.5s/step - loss: 0.7921 - accuracy: 0.8408 - precision: 0.8446 - recall: 0.8408 - f1: 0.8402 - val_loss: 0.9518 - val_accuracy: 0.8091 - val_precision: 0.8395 - val_recall: 0.8091 - val_f1: 0.8117
#
#   >> Early stopping at epoch 41. Best val_loss = 0.9365
#
# ============================================================
#   TEST EVALUATION
# ============================================================
#   loss      : 0.8863
#   accuracy  : 0.8268
#   precision : 0.8453
#   recall    : 0.8268
#   f1_score  : 0.8288
# ============================================================
#
# Classification Report:
#                        precision    recall  f1-score   support
#
# bacterial_leaf_blight     0.9273    0.7556    0.8327       135
#            brown_spot     0.9308    0.8121    0.8674       149
#               healthy     0.7267    0.9008    0.8044       121
#            leaf_blast     0.8584    0.7698    0.8117       126
#            leaf_scald     0.6913    0.9279    0.7923       111
#     narrow_brown_spot     0.9032    0.8155    0.8571       103
#
#              accuracy                         0.8268       745
#             macro avg     0.8396    0.8303    0.8276       745
#          weighted avg     0.8453    0.8268    0.8288       745
#
#
#   ── Model Statistics: ResNet50 ──
#   Total Params (M)      : 23.5203
#   Trainable Params (M)  : 23.5203
#   Disk Size (MB)        : 90.027
#   FLOPs (G)             : 8.1743
#   Inference (ms)        : 17.0111
#   FPS                   : 58.79
#   All results saved -> Model\ResNet50/
#     ResNet50_weights.pth
#     ResNet50_history.json
#     ResNet50_stats.json
#     ResNet50_test_metrics.json
#     ResNet50_classification_report.txt
#
# ResNet50 done.

# %%
# =============================================================================
#  MODEL 2 : VGG16
# =============================================================================
print('=' * 70)
print('  MODEL: VGG16')
print('=' * 70)

# ── Transforms ────────────────────────────────────────────────
vgg_train_t = transforms.Compose([
    transforms.Resize(IMAGE_SIZE),
    transforms.RandomRotation(25),
    transforms.RandomAffine(degrees=0, translate=(0.15, 0.15), shear=5.7),
    transforms.ToTensor(),
    IMAGENET_NORM,
])
vgg_val_t = transforms.Compose([
    transforms.Resize(IMAGE_SIZE),
    transforms.ToTensor(),
    IMAGENET_NORM,
])

vgg_train_loader, vgg_val_loader, vgg_test_loader = make_loaders(vgg_train_t, vgg_val_t)

# ── Architecture ──────────────────────────────────────────────
# weights=None  → random initialisation, train from scratch
# base_model.trainable = True  → all layers are trainable (PyTorch default)
# VGG16 features output: 512ch x 7x7 for 224x224 input
# AdaptiveAvgPool2d(1) = GlobalAveragePooling2D → 512-dim vector
def build_vgg16(num_classes=NUM_CLASSES):
    model = torchvision.models.vgg16(weights=None)  # no ImageNet weights
    for p in model.parameters():                    # all layers trainable
        p.requires_grad = True
    model.avgpool    = nn.AdaptiveAvgPool2d(1)
    model.classifier = nn.Sequential(
        nn.Flatten(),
        nn.Linear(512, 512),
        nn.ReLU(inplace=True),
        nn.Dropout(0.5),
        nn.Linear(512, num_classes),
    )
    return model

vgg_model = build_vgg16(NUM_CLASSES).to(DEVICE)
print(f'Trainable params : {sum(p.numel() for p in vgg_model.parameters() if p.requires_grad):,}')

vgg_history = train_model(vgg_model, 'VGG16', vgg_train_loader, vgg_val_loader)
vgg_test_preds, vgg_test_labels = evaluate_on_test(vgg_model, vgg_test_loader)
vgg_stats = compute_model_stats(vgg_model, 'VGG16')
save_all_results(vgg_model, 'VGG16', vgg_history, vgg_stats,
                 vgg_test_preds, vgg_test_labels)

del vgg_model, vgg_train_loader, vgg_val_loader, vgg_test_loader
if DEVICE.type == 'cuda': torch.cuda.empty_cache()
print('\nVGG16 done.\n')
# Out:
# ======================================================================
#   MODEL: VGG16
# ======================================================================
# Trainable params : 14,980,422
#
# Model  : VGG16
# Train batches : 88  |  Val batches : 12
# Device : cuda  (NVIDIA RTX 5000 Ada Generation)
# --------------------------------------------------------------------------------------------------------------
# Epoch 1/50 88/88 [==============================] - 78s 0.9s/step - loss: 1.7718 - accuracy: 0.2076 - precision: 0.2458 - recall: 0.2076 - f1: 0.1643 - val_loss: 1.7325 - val_accuracy: 0.2285 - val_precision: 0.2227 - val_recall: 0.2285 - val_f1: 0.1551
#
# Epoch 2/50 88/88 [==============================] - 65s 0.7s/step - loss: 1.6677 - accuracy: 0.3114 - precision: 0.3605 - recall: 0.3114 - f1: 0.3101 - val_loss: 1.6316 - val_accuracy: 0.3374 - val_precision: 0.3495 - val_recall: 0.3374 - val_f1: 0.3164
#
# Epoch 3/50 88/88 [==============================] - 65s 0.7s/step - loss: 1.5548 - accuracy: 0.3985 - precision: 0.4310 - recall: 0.3985 - f1: 0.4023 - val_loss: 1.5381 - val_accuracy: 0.3817 - val_precision: 0.4249 - val_recall: 0.3817 - val_f1: 0.3715
#
# Epoch 4/50 88/88 [==============================] - 65s 0.7s/step - loss: 1.4748 - accuracy: 0.4490 - precision: 0.4721 - recall: 0.4490 - f1: 0.4461 - val_loss: 1.4471 - val_accuracy: 0.4772 - val_precision: 0.5527 - val_recall: 0.4772 - val_f1: 0.4641
#
# Epoch 5/50 88/88 [==============================] - 65s 0.7s/step - loss: 1.3851 - accuracy: 0.5144 - precision: 0.5268 - recall: 0.5144 - f1: 0.5081 - val_loss: 1.4885 - val_accuracy: 0.4919 - val_precision: 0.4949 - val_recall: 0.4919 - val_f1: 0.4750
#
# Epoch 6/50 88/88 [==============================] - 65s 0.7s/step - loss: 1.3154 - accuracy: 0.5510 - precision: 0.5648 - recall: 0.5510 - f1: 0.5443 - val_loss: 1.2885 - val_accuracy: 0.5753 - val_precision: 0.5923 - val_recall: 0.5753 - val_f1: 0.5499
#
# Epoch 7/50 88/88 [==============================] - 68s 0.8s/step - loss: 1.2418 - accuracy: 0.5895 - precision: 0.5995 - recall: 0.5895 - f1: 0.5846 - val_loss: 1.2395 - val_accuracy: 0.6022 - val_precision: 0.6143 - val_recall: 0.6022 - val_f1: 0.5866
#
# Epoch 8/50 88/88 [==============================] - 69s 0.8s/step - loss: 1.1673 - accuracy: 0.6345 - precision: 0.6415 - recall: 0.6345 - f1: 0.6296 - val_loss: 1.1936 - val_accuracy: 0.6048 - val_precision: 0.6219 - val_recall: 0.6048 - val_f1: 0.6005
#
# Epoch 9/50 88/88 [==============================] - 69s 0.8s/step - loss: 1.1274 - accuracy: 0.6546 - precision: 0.6592 - recall: 0.6546 - f1: 0.6506 - val_loss: 1.0940 - val_accuracy: 0.6841 - val_precision: 0.7067 - val_recall: 0.6841 - val_f1: 0.6766
#
# Epoch 10/50 88/88 [==============================] - 70s 0.8s/step - loss: 1.0639 - accuracy: 0.6911 - precision: 0.6960 - recall: 0.6911 - f1: 0.6869 - val_loss: 1.0588 - val_accuracy: 0.6868 - val_precision: 0.6958 - val_recall: 0.6868 - val_f1: 0.6773
#
# Epoch 11/50 88/88 [==============================] - 69s 0.8s/step - loss: 1.0278 - accuracy: 0.7078 - precision: 0.7121 - recall: 0.7078 - f1: 0.7039 - val_loss: 1.0505 - val_accuracy: 0.6935 - val_precision: 0.7050 - val_recall: 0.6935 - val_f1: 0.6851
#
# Epoch 12/50 88/88 [==============================] - 69s 0.8s/step - loss: 0.9900 - accuracy: 0.7301 - precision: 0.7336 - recall: 0.7301 - f1: 0.7272 - val_loss: 0.9920 - val_accuracy: 0.7339 - val_precision: 0.7441 - val_recall: 0.7339 - val_f1: 0.7257
#
# Epoch 13/50 88/88 [==============================] - 69s 0.8s/step - loss: 0.9787 - accuracy: 0.7309 - precision: 0.7329 - recall: 0.7309 - f1: 0.7269 - val_loss: 1.1066 - val_accuracy: 0.6761 - val_precision: 0.6945 - val_recall: 0.6761 - val_f1: 0.6658
#
# Epoch 14/50 88/88 [==============================] - 68s 0.8s/step - loss: 0.9491 - accuracy: 0.7501 - precision: 0.7505 - recall: 0.7501 - f1: 0.7462 - val_loss: 0.9453 - val_accuracy: 0.7540 - val_precision: 0.7792 - val_recall: 0.7540 - val_f1: 0.7484
#
# Epoch 15/50 88/88 [==============================] - 69s 0.8s/step - loss: 0.9041 - accuracy: 0.7764 - precision: 0.7784 - recall: 0.7764 - f1: 0.7727 - val_loss: 0.9241 - val_accuracy: 0.7608 - val_precision: 0.7752 - val_recall: 0.7608 - val_f1: 0.7572
#
# Epoch 16/50 88/88 [==============================] - 70s 0.8s/step - loss: 0.8944 - accuracy: 0.7830 - precision: 0.7838 - recall: 0.7830 - f1: 0.7799 - val_loss: 0.9219 - val_accuracy: 0.7715 - val_precision: 0.7939 - val_recall: 0.7715 - val_f1: 0.7627
#
# Epoch 17/50 88/88 [==============================] - 69s 0.8s/step - loss: 0.8621 - accuracy: 0.8014 - precision: 0.8023 - recall: 0.8014 - f1: 0.7989 - val_loss: 0.8742 - val_accuracy: 0.7944 - val_precision: 0.8089 - val_recall: 0.7944 - val_f1: 0.7894
#
# Epoch 18/50 88/88 [==============================] - 68s 0.8s/step - loss: 0.8508 - accuracy: 0.8055 - precision: 0.8062 - recall: 0.8055 - f1: 0.8030 - val_loss: 0.8315 - val_accuracy: 0.7957 - val_precision: 0.8057 - val_recall: 0.7957 - val_f1: 0.7898
#
# Epoch 19/50 88/88 [==============================] - 68s 0.8s/step - loss: 0.8218 - accuracy: 0.8219 - precision: 0.8223 - recall: 0.8219 - f1: 0.8197 - val_loss: 0.7962 - val_accuracy: 0.8253 - val_precision: 0.8259 - val_recall: 0.8253 - val_f1: 0.8225
#
# Epoch 20/50 88/88 [==============================] - 71s 0.8s/step - loss: 0.8234 - accuracy: 0.8138 - precision: 0.8137 - recall: 0.8138 - f1: 0.8117 - val_loss: 0.8341 - val_accuracy: 0.8065 - val_precision: 0.8249 - val_recall: 0.8065 - val_f1: 0.8027
#
# Epoch 21/50 88/88 [==============================] - 61s 0.7s/step - loss: 0.8087 - accuracy: 0.8246 - precision: 0.8244 - recall: 0.8246 - f1: 0.8227 - val_loss: 0.8094 - val_accuracy: 0.8105 - val_precision: 0.8246 - val_recall: 0.8105 - val_f1: 0.8073
#
# Epoch 22/50 88/88 [==============================] - 58s 0.7s/step - loss: 0.7882 - accuracy: 0.8356 - precision: 0.8363 - recall: 0.8356 - f1: 0.8343 - val_loss: 0.7491 - val_accuracy: 0.8414 - val_precision: 0.8443 - val_recall: 0.8414 - val_f1: 0.8382
#
# Epoch 23/50 88/88 [==============================] - 60s 0.7s/step - loss: 0.7681 - accuracy: 0.8444 - precision: 0.8447 - recall: 0.8444 - f1: 0.8431 - val_loss: 0.7465 - val_accuracy: 0.8481 - val_precision: 0.8550 - val_recall: 0.8481 - val_f1: 0.8444
#
# Epoch 24/50 88/88 [==============================] - 58s 0.7s/step - loss: 0.7631 - accuracy: 0.8488 - precision: 0.8489 - recall: 0.8488 - f1: 0.8474 - val_loss: 0.7712 - val_accuracy: 0.8306 - val_precision: 0.8391 - val_recall: 0.8306 - val_f1: 0.8263
#
# Epoch 25/50 88/88 [==============================] - 58s 0.7s/step - loss: 0.7590 - accuracy: 0.8561 - precision: 0.8561 - recall: 0.8561 - f1: 0.8551 - val_loss: 0.7350 - val_accuracy: 0.8481 - val_precision: 0.8565 - val_recall: 0.8481 - val_f1: 0.8434
#
# Epoch 26/50 88/88 [==============================] - 60s 0.7s/step - loss: 0.7424 - accuracy: 0.8595 - precision: 0.8593 - recall: 0.8595 - f1: 0.8583 - val_loss: 0.7304 - val_accuracy: 0.8683 - val_precision: 0.8748 - val_recall: 0.8683 - val_f1: 0.8673
#
# Epoch 27/50 88/88 [==============================] - 57s 0.6s/step - loss: 0.7352 - accuracy: 0.8653 - precision: 0.8647 - recall: 0.8653 - f1: 0.8643 - val_loss: 0.7340 - val_accuracy: 0.8508 - val_precision: 0.8606 - val_recall: 0.8508 - val_f1: 0.8472
#
# Epoch 28/50 88/88 [==============================] - 56s 0.6s/step - loss: 0.7338 - accuracy: 0.8640 - precision: 0.8642 - recall: 0.8640 - f1: 0.8629 - val_loss: 0.7656 - val_accuracy: 0.8495 - val_precision: 0.8620 - val_recall: 0.8495 - val_f1: 0.8472
#
# Epoch 29/50 88/88 [==============================] - 61s 0.7s/step - loss: 0.7274 - accuracy: 0.8724 - precision: 0.8723 - recall: 0.8724 - f1: 0.8715 - val_loss: 0.7081 - val_accuracy: 0.8696 - val_precision: 0.8765 - val_recall: 0.8696 - val_f1: 0.8666
#
# Epoch 30/50 88/88 [==============================] - 59s 0.7s/step - loss: 0.7107 - accuracy: 0.8788 - precision: 0.8790 - recall: 0.8788 - f1: 0.8781 - val_loss: 0.6902 - val_accuracy: 0.8750 - val_precision: 0.8830 - val_recall: 0.8750 - val_f1: 0.8734
#
# Epoch 31/50 88/88 [==============================] - 58s 0.7s/step - loss: 0.7037 - accuracy: 0.8840 - precision: 0.8842 - recall: 0.8840 - f1: 0.8835 - val_loss: 0.6787 - val_accuracy: 0.8952 - val_precision: 0.8995 - val_recall: 0.8952 - val_f1: 0.8938
#
# Epoch 32/50 88/88 [==============================] - 59s 0.7s/step - loss: 0.6921 - accuracy: 0.8876 - precision: 0.8877 - recall: 0.8876 - f1: 0.8869 - val_loss: 0.7036 - val_accuracy: 0.8750 - val_precision: 0.8796 - val_recall: 0.8750 - val_f1: 0.8723
#
# Epoch 33/50 88/88 [==============================] - 58s 0.7s/step - loss: 0.6871 - accuracy: 0.8895 - precision: 0.8895 - recall: 0.8895 - f1: 0.8889 - val_loss: 0.6866 - val_accuracy: 0.8750 - val_precision: 0.8828 - val_recall: 0.8750 - val_f1: 0.8742
#
# Epoch 34/50 88/88 [==============================] - 62s 0.7s/step - loss: 0.6832 - accuracy: 0.8915 - precision: 0.8915 - recall: 0.8915 - f1: 0.8910 - val_loss: 0.6857 - val_accuracy: 0.8817 - val_precision: 0.8865 - val_recall: 0.8817 - val_f1: 0.8789
#
# Epoch 35/50 88/88 [==============================] - 61s 0.7s/step - loss: 0.6768 - accuracy: 0.8993 - precision: 0.8995 - recall: 0.8993 - f1: 0.8989 - val_loss: 0.6598 - val_accuracy: 0.9046 - val_precision: 0.9073 - val_recall: 0.9046 - val_f1: 0.9033
#
# Epoch 36/50 88/88 [==============================] - 58s 0.7s/step - loss: 0.6793 - accuracy: 0.8981 - precision: 0.8982 - recall: 0.8981 - f1: 0.8977 - val_loss: 0.7177 - val_accuracy: 0.8656 - val_precision: 0.8706 - val_recall: 0.8656 - val_f1: 0.8655
#
# Epoch 37/50 88/88 [==============================] - 56s 0.6s/step - loss: 0.6756 - accuracy: 0.9031 - precision: 0.9032 - recall: 0.9031 - f1: 0.9027 - val_loss: 0.6520 - val_accuracy: 0.8965 - val_precision: 0.9033 - val_recall: 0.8965 - val_f1: 0.8945
#
# Epoch 38/50 88/88 [==============================] - 57s 0.6s/step - loss: 0.6651 - accuracy: 0.9040 - precision: 0.9041 - recall: 0.9040 - f1: 0.9037 - val_loss: 0.6392 - val_accuracy: 0.9194 - val_precision: 0.9208 - val_recall: 0.9194 - val_f1: 0.9190
#
# Epoch 39/50 88/88 [==============================] - 55s 0.6s/step - loss: 0.6586 - accuracy: 0.9083 - precision: 0.9083 - recall: 0.9083 - f1: 0.9078 - val_loss: 0.6382 - val_accuracy: 0.9086 - val_precision: 0.9107 - val_recall: 0.9086 - val_f1: 0.9076
#
# Epoch 40/50 88/88 [==============================] - 55s 0.6s/step - loss: 0.6469 - accuracy: 0.9170 - precision: 0.9172 - recall: 0.9170 - f1: 0.9168 - val_loss: 0.6613 - val_accuracy: 0.8992 - val_precision: 0.9066 - val_recall: 0.8992 - val_f1: 0.8983
#
# Epoch 41/50 88/88 [==============================] - 56s 0.6s/step - loss: 0.6456 - accuracy: 0.9168 - precision: 0.9171 - recall: 0.9168 - f1: 0.9167 - val_loss: 0.6263 - val_accuracy: 0.9234 - val_precision: 0.9250 - val_recall: 0.9234 - val_f1: 0.9225
#
# Epoch 42/50 88/88 [==============================] - 55s 0.6s/step - loss: 0.6430 - accuracy: 0.9177 - precision: 0.9180 - recall: 0.9177 - f1: 0.9175 - val_loss: 0.6146 - val_accuracy: 0.9315 - val_precision: 0.9335 - val_recall: 0.9315 - val_f1: 0.9311
#
# Epoch 43/50 88/88 [==============================] - 56s 0.6s/step - loss: 0.6365 - accuracy: 0.9200 - precision: 0.9200 - recall: 0.9200 - f1: 0.9198 - val_loss: 0.6351 - val_accuracy: 0.9234 - val_precision: 0.9244 - val_recall: 0.9234 - val_f1: 0.9221
#
# Epoch 44/50 88/88 [==============================] - 55s 0.6s/step - loss: 0.6315 - accuracy: 0.9275 - precision: 0.9278 - recall: 0.9275 - f1: 0.9274 - val_loss: 0.6393 - val_accuracy: 0.9207 - val_precision: 0.9260 - val_recall: 0.9207 - val_f1: 0.9210
#
# Epoch 45/50 88/88 [==============================] - 57s 0.6s/step - loss: 0.6237 - accuracy: 0.9302 - precision: 0.9302 - recall: 0.9302 - f1: 0.9300 - val_loss: 0.6253 - val_accuracy: 0.9180 - val_precision: 0.9196 - val_recall: 0.9180 - val_f1: 0.9176
#
# Epoch 46/50 88/88 [==============================] - 54s 0.6s/step - loss: 0.6177 - accuracy: 0.9363 - precision: 0.9364 - recall: 0.9363 - f1: 0.9361 - val_loss: 0.6191 - val_accuracy: 0.9073 - val_precision: 0.9098 - val_recall: 0.9073 - val_f1: 0.9066
#
# Epoch 47/50 88/88 [==============================] - 59s 0.7s/step - loss: 0.6120 - accuracy: 0.9311 - precision: 0.9312 - recall: 0.9311 - f1: 0.9309 - val_loss: 0.5905 - val_accuracy: 0.9355 - val_precision: 0.9359 - val_recall: 0.9355 - val_f1: 0.9350
#
# Epoch 48/50 88/88 [==============================] - 55s 0.6s/step - loss: 0.6010 - accuracy: 0.9415 - precision: 0.9416 - recall: 0.9415 - f1: 0.9413 - val_loss: 0.5969 - val_accuracy: 0.9274 - val_precision: 0.9315 - val_recall: 0.9274 - val_f1: 0.9272
#
# Epoch 49/50 88/88 [==============================] - 55s 0.6s/step - loss: 0.6034 - accuracy: 0.9381 - precision: 0.9381 - recall: 0.9381 - f1: 0.9379 - val_loss: 0.5850 - val_accuracy: 0.9435 - val_precision: 0.9440 - val_recall: 0.9435 - val_f1: 0.9431
#
# Epoch 50/50 88/88 [==============================] - 57s 0.7s/step - loss: 0.5950 - accuracy: 0.9429 - precision: 0.9430 - recall: 0.9429 - f1: 0.9428 - val_loss: 0.6002 - val_accuracy: 0.9422 - val_precision: 0.9436 - val_recall: 0.9422 - val_f1: 0.9417
#
#
# ============================================================
#   TEST EVALUATION
# ============================================================
#   loss      : 0.5602
#   accuracy  : 0.9557
#   precision : 0.9560
#   recall    : 0.9557
#   f1_score  : 0.9556
# ============================================================
#
# Classification Report:
#                        precision    recall  f1-score   support
#
# bacterial_leaf_blight     0.9416    0.9556    0.9485       135
#            brown_spot     0.9724    0.9463    0.9592       149
#               healthy     0.9737    0.9174    0.9447       121
#            leaf_blast     0.9291    0.9365    0.9328       126
#            leaf_scald     0.9569    1.0000    0.9780       111
#     narrow_brown_spot     0.9623    0.9903    0.9761       103
#
#              accuracy                         0.9557       745
#             macro avg     0.9560    0.9577    0.9565       745
#          weighted avg     0.9560    0.9557    0.9556       745
#
#
#   ── Model Statistics: VGG16 ──
#   Total Params (M)      : 14.9804
#   Trainable Params (M)  : 14.9804
#   Disk Size (MB)        : 57.1563
#   FLOPs (G)             : 30.6938
#   Inference (ms)        : 4.3028
#   FPS                   : 232.41
#   All results saved -> Model\VGG16/
#     VGG16_weights.pth
#     VGG16_history.json
#     VGG16_stats.json
#     VGG16_test_metrics.json
#     VGG16_classification_report.txt
#
# VGG16 done.

# %%
# =============================================================================
#  MODEL 3 : MobileNetV2
# =============================================================================
print('=' * 70)
print('  MODEL: MobileNetV2')
print('=' * 70)

# ── Transforms ────────────────────────────────────────────────
mobilenet_train_t = transforms.Compose([
    transforms.Resize(IMAGE_SIZE),
    transforms.RandomRotation(25),
    transforms.RandomAffine(degrees=0, translate=(0.15, 0.15), shear=5.7),
    transforms.ToTensor(),
    MINUSONE_NORM,
])
mobilenet_val_t = transforms.Compose([
    transforms.Resize(IMAGE_SIZE),
    transforms.ToTensor(),
    MINUSONE_NORM,
])

mobilenet_train_loader, mobilenet_val_loader, mobilenet_test_loader = make_loaders(
    mobilenet_train_t, mobilenet_val_t
)

# ── Architecture ──────────────────────────────────────────────
# weights=None  → random initialisation, train from scratch
# base_model.trainable = True  → all layers are trainable (PyTorch default)
# torchvision MobileNetV2: features output 1280ch; built-in AdaptiveAvgPool2d(1)
def build_mobilenetv2(num_classes=NUM_CLASSES):
    model = torchvision.models.mobilenet_v2(weights=None)  # no ImageNet weights
    for p in model.parameters():                           # all layers trainable
        p.requires_grad = True
    model.classifier = nn.Sequential(
        nn.Dropout(0.3),
        nn.Linear(1280, num_classes),
    )
    return model

mobilenet_model = build_mobilenetv2(NUM_CLASSES).to(DEVICE)
print(f'Trainable params : {sum(p.numel() for p in mobilenet_model.parameters() if p.requires_grad):,}')

mobilenet_history = train_model(
    mobilenet_model, 'MobileNetV2', mobilenet_train_loader, mobilenet_val_loader
)
mobilenet_test_preds, mobilenet_test_labels = evaluate_on_test(mobilenet_model, mobilenet_test_loader)
mobilenet_stats = compute_model_stats(mobilenet_model, 'MobileNetV2')
save_all_results(mobilenet_model, 'MobileNetV2', mobilenet_history, mobilenet_stats,
                 mobilenet_test_preds, mobilenet_test_labels)

del mobilenet_model, mobilenet_train_loader, mobilenet_val_loader, mobilenet_test_loader
if DEVICE.type == 'cuda': torch.cuda.empty_cache()
print('\nMobileNetV2 done.\n')
# Out:
# ======================================================================
#   MODEL: MobileNetV2
# ======================================================================
# Trainable params : 2,231,558
#
# Model  : MobileNetV2
# Train batches : 88  |  Val batches : 12
# Device : cuda  (NVIDIA RTX 5000 Ada Generation)
# --------------------------------------------------------------------------------------------------------------
# Epoch 1/50 88/88 [==============================] - 40s 0.5s/step - loss: 1.7825 - accuracy: 0.2079 - precision: 0.2438 - recall: 0.2079 - f1: 0.2063 - val_loss: 1.7789 - val_accuracy: 0.2312 - val_precision: 0.1933 - val_recall: 0.2312 - val_f1: 0.1309
#
# Epoch 2/50 88/88 [==============================] - 24s 0.3s/step - loss: 1.7341 - accuracy: 0.2827 - precision: 0.2664 - recall: 0.2827 - f1: 0.2638 - val_loss: 1.7168 - val_accuracy: 0.3065 - val_precision: 0.2729 - val_recall: 0.3065 - val_f1: 0.2455
#
# Epoch 3/50 88/88 [==============================] - 24s 0.3s/step - loss: 1.7043 - accuracy: 0.3295 - precision: 0.3133 - recall: 0.3295 - f1: 0.3111 - val_loss: 1.6964 - val_accuracy: 0.3212 - val_precision: 0.2596 - val_recall: 0.3212 - val_f1: 0.2473
#
# Epoch 4/50 88/88 [==============================] - 25s 0.3s/step - loss: 1.6730 - accuracy: 0.3273 - precision: 0.3083 - recall: 0.3273 - f1: 0.3097 - val_loss: 1.6740 - val_accuracy: 0.3387 - val_precision: 0.3100 - val_recall: 0.3387 - val_f1: 0.2945
#
# Epoch 5/50 88/88 [==============================] - 25s 0.3s/step - loss: 1.6463 - accuracy: 0.3432 - precision: 0.3317 - recall: 0.3432 - f1: 0.3310 - val_loss: 1.6497 - val_accuracy: 0.3481 - val_precision: 0.3434 - val_recall: 0.3481 - val_f1: 0.3077
#
# Epoch 6/50 88/88 [==============================] - 24s 0.3s/step - loss: 1.6214 - accuracy: 0.3636 - precision: 0.3549 - recall: 0.3636 - f1: 0.3520 - val_loss: 1.6287 - val_accuracy: 0.3817 - val_precision: 0.4151 - val_recall: 0.3817 - val_f1: 0.3551
#
# Epoch 7/50 88/88 [==============================] - 25s 0.3s/step - loss: 1.5868 - accuracy: 0.3982 - precision: 0.3928 - recall: 0.3982 - f1: 0.3914 - val_loss: 1.5950 - val_accuracy: 0.4059 - val_precision: 0.4294 - val_recall: 0.4059 - val_f1: 0.3908
#
# Epoch 8/50 88/88 [==============================] - 25s 0.3s/step - loss: 1.5528 - accuracy: 0.4187 - precision: 0.4161 - recall: 0.4187 - f1: 0.4158 - val_loss: 1.5669 - val_accuracy: 0.4032 - val_precision: 0.4149 - val_recall: 0.4032 - val_f1: 0.3878
#
# Epoch 9/50 88/88 [==============================] - 25s 0.3s/step - loss: 1.5176 - accuracy: 0.4299 - precision: 0.4331 - recall: 0.4299 - f1: 0.4298 - val_loss: 1.5533 - val_accuracy: 0.4140 - val_precision: 0.4307 - val_recall: 0.4140 - val_f1: 0.3994
#
# Epoch 10/50 88/88 [==============================] - 25s 0.3s/step - loss: 1.4754 - accuracy: 0.4514 - precision: 0.4577 - recall: 0.4514 - f1: 0.4524 - val_loss: 1.5134 - val_accuracy: 0.4247 - val_precision: 0.4564 - val_recall: 0.4247 - val_f1: 0.4118
#
# Epoch 11/50 88/88 [==============================] - 25s 0.3s/step - loss: 1.4501 - accuracy: 0.4587 - precision: 0.4696 - recall: 0.4587 - f1: 0.4602 - val_loss: 1.4885 - val_accuracy: 0.4261 - val_precision: 0.4574 - val_recall: 0.4261 - val_f1: 0.4123
#
# Epoch 12/50 88/88 [==============================] - 25s 0.3s/step - loss: 1.4261 - accuracy: 0.4765 - precision: 0.4874 - recall: 0.4765 - f1: 0.4763 - val_loss: 1.4491 - val_accuracy: 0.4610 - val_precision: 0.4945 - val_recall: 0.4610 - val_f1: 0.4467
#
# Epoch 13/50 88/88 [==============================] - 25s 0.3s/step - loss: 1.3993 - accuracy: 0.4885 - precision: 0.5032 - recall: 0.4885 - f1: 0.4882 - val_loss: 1.4262 - val_accuracy: 0.4919 - val_precision: 0.5194 - val_recall: 0.4919 - val_f1: 0.4753
#
# Epoch 14/50 88/88 [==============================] - 24s 0.3s/step - loss: 1.3623 - accuracy: 0.5163 - precision: 0.5304 - recall: 0.5163 - f1: 0.5142 - val_loss: 1.4094 - val_accuracy: 0.4973 - val_precision: 0.5199 - val_recall: 0.4973 - val_f1: 0.4812
#
# Epoch 15/50 88/88 [==============================] - 24s 0.3s/step - loss: 1.3441 - accuracy: 0.5245 - precision: 0.5360 - recall: 0.5245 - f1: 0.5201 - val_loss: 1.4164 - val_accuracy: 0.5000 - val_precision: 0.5224 - val_recall: 0.5000 - val_f1: 0.4845
#
# Epoch 16/50 88/88 [==============================] - 25s 0.3s/step - loss: 1.3245 - accuracy: 0.5311 - precision: 0.5433 - recall: 0.5311 - f1: 0.5278 - val_loss: 1.4188 - val_accuracy: 0.5094 - val_precision: 0.5263 - val_recall: 0.5094 - val_f1: 0.4963
#
# Epoch 17/50 88/88 [==============================] - 25s 0.3s/step - loss: 1.3058 - accuracy: 0.5477 - precision: 0.5615 - recall: 0.5477 - f1: 0.5447 - val_loss: 1.3755 - val_accuracy: 0.5390 - val_precision: 0.5581 - val_recall: 0.5390 - val_f1: 0.5269
#
# Epoch 18/50 88/88 [==============================] - 25s 0.3s/step - loss: 1.2933 - accuracy: 0.5485 - precision: 0.5576 - recall: 0.5485 - f1: 0.5461 - val_loss: 1.3851 - val_accuracy: 0.5444 - val_precision: 0.5597 - val_recall: 0.5444 - val_f1: 0.5335
#
# Epoch 19/50 88/88 [==============================] - 25s 0.3s/step - loss: 1.2951 - accuracy: 0.5456 - precision: 0.5593 - recall: 0.5456 - f1: 0.5437 - val_loss: 1.3765 - val_accuracy: 0.5417 - val_precision: 0.5607 - val_recall: 0.5417 - val_f1: 0.5326
#
# Epoch 20/50 88/88 [==============================] - 25s 0.3s/step - loss: 1.2775 - accuracy: 0.5663 - precision: 0.5787 - recall: 0.5663 - f1: 0.5643 - val_loss: 1.3630 - val_accuracy: 0.5605 - val_precision: 0.5691 - val_recall: 0.5605 - val_f1: 0.5517
#
# Epoch 21/50 88/88 [==============================] - 25s 0.3s/step - loss: 1.2602 - accuracy: 0.5658 - precision: 0.5778 - recall: 0.5658 - f1: 0.5620 - val_loss: 1.3622 - val_accuracy: 0.5739 - val_precision: 0.5924 - val_recall: 0.5739 - val_f1: 0.5676
#
# Epoch 22/50 88/88 [==============================] - 23s 0.3s/step - loss: 1.2472 - accuracy: 0.5731 - precision: 0.5843 - recall: 0.5731 - f1: 0.5703 - val_loss: 1.3704 - val_accuracy: 0.5645 - val_precision: 0.5776 - val_recall: 0.5645 - val_f1: 0.5556
#
# Epoch 23/50 88/88 [==============================] - 25s 0.3s/step - loss: 1.2385 - accuracy: 0.5784 - precision: 0.5905 - recall: 0.5784 - f1: 0.5772 - val_loss: 1.3273 - val_accuracy: 0.5820 - val_precision: 0.5931 - val_recall: 0.5820 - val_f1: 0.5753
#
# Epoch 24/50 88/88 [==============================] - 26s 0.3s/step - loss: 1.2244 - accuracy: 0.5863 - precision: 0.5983 - recall: 0.5863 - f1: 0.5834 - val_loss: 1.3126 - val_accuracy: 0.5860 - val_precision: 0.5914 - val_recall: 0.5860 - val_f1: 0.5805
#
# Epoch 25/50 88/88 [==============================] - 24s 0.3s/step - loss: 1.2144 - accuracy: 0.5991 - precision: 0.6101 - recall: 0.5991 - f1: 0.5967 - val_loss: 1.3171 - val_accuracy: 0.5995 - val_precision: 0.6107 - val_recall: 0.5995 - val_f1: 0.5957
#
# Epoch 26/50 88/88 [==============================] - 24s 0.3s/step - loss: 1.2041 - accuracy: 0.6020 - precision: 0.6138 - recall: 0.6020 - f1: 0.5998 - val_loss: 1.3797 - val_accuracy: 0.5726 - val_precision: 0.5924 - val_recall: 0.5726 - val_f1: 0.5645
#
# Epoch 27/50 88/88 [==============================] - 25s 0.3s/step - loss: 1.1985 - accuracy: 0.6165 - precision: 0.6271 - recall: 0.6165 - f1: 0.6144 - val_loss: 1.2996 - val_accuracy: 0.6183 - val_precision: 0.6271 - val_recall: 0.6183 - val_f1: 0.6161
#
# Epoch 28/50 88/88 [==============================] - 25s 0.3s/step - loss: 1.1860 - accuracy: 0.6147 - precision: 0.6247 - recall: 0.6147 - f1: 0.6127 - val_loss: 1.2733 - val_accuracy: 0.6102 - val_precision: 0.6141 - val_recall: 0.6102 - val_f1: 0.6057
#
# Epoch 29/50 88/88 [==============================] - 25s 0.3s/step - loss: 1.1862 - accuracy: 0.6165 - precision: 0.6271 - recall: 0.6165 - f1: 0.6146 - val_loss: 1.2615 - val_accuracy: 0.6223 - val_precision: 0.6356 - val_recall: 0.6223 - val_f1: 0.6195
#
# Epoch 30/50 88/88 [==============================] - 24s 0.3s/step - loss: 1.1679 - accuracy: 0.6356 - precision: 0.6460 - recall: 0.6356 - f1: 0.6328 - val_loss: 1.2635 - val_accuracy: 0.6183 - val_precision: 0.6281 - val_recall: 0.6183 - val_f1: 0.6164
#
# Epoch 31/50 88/88 [==============================] - 24s 0.3s/step - loss: 1.1682 - accuracy: 0.6220 - precision: 0.6336 - recall: 0.6220 - f1: 0.6207 - val_loss: 1.2562 - val_accuracy: 0.6304 - val_precision: 0.6522 - val_recall: 0.6304 - val_f1: 0.6300
#
# Epoch 32/50 88/88 [==============================] - 26s 0.3s/step - loss: 1.1434 - accuracy: 0.6452 - precision: 0.6549 - recall: 0.6452 - f1: 0.6438 - val_loss: 1.2641 - val_accuracy: 0.6169 - val_precision: 0.6341 - val_recall: 0.6169 - val_f1: 0.6153
#
# Epoch 33/50 88/88 [==============================] - 22s 0.2s/step - loss: 1.1476 - accuracy: 0.6391 - precision: 0.6498 - recall: 0.6391 - f1: 0.6373 - val_loss: 1.1971 - val_accuracy: 0.6492 - val_precision: 0.6595 - val_recall: 0.6492 - val_f1: 0.6478
#
# Epoch 34/50 88/88 [==============================] - 22s 0.3s/step - loss: 1.1369 - accuracy: 0.6423 - precision: 0.6492 - recall: 0.6423 - f1: 0.6398 - val_loss: 1.2489 - val_accuracy: 0.6304 - val_precision: 0.6552 - val_recall: 0.6304 - val_f1: 0.6297
#
# Epoch 35/50 88/88 [==============================] - 22s 0.2s/step - loss: 1.1292 - accuracy: 0.6473 - precision: 0.6560 - recall: 0.6473 - f1: 0.6454 - val_loss: 1.1840 - val_accuracy: 0.6559 - val_precision: 0.6664 - val_recall: 0.6559 - val_f1: 0.6547
#
# Epoch 36/50 88/88 [==============================] - 22s 0.3s/step - loss: 1.1220 - accuracy: 0.6464 - precision: 0.6572 - recall: 0.6464 - f1: 0.6450 - val_loss: 1.1892 - val_accuracy: 0.6546 - val_precision: 0.6669 - val_recall: 0.6546 - val_f1: 0.6544
#
# Epoch 37/50 88/88 [==============================] - 22s 0.2s/step - loss: 1.1121 - accuracy: 0.6648 - precision: 0.6734 - recall: 0.6648 - f1: 0.6633 - val_loss: 1.1987 - val_accuracy: 0.6626 - val_precision: 0.6838 - val_recall: 0.6626 - val_f1: 0.6649
#
# Epoch 38/50 88/88 [==============================] - 21s 0.2s/step - loss: 1.1114 - accuracy: 0.6523 - precision: 0.6595 - recall: 0.6523 - f1: 0.6498 - val_loss: 1.1880 - val_accuracy: 0.6573 - val_precision: 0.6741 - val_recall: 0.6573 - val_f1: 0.6577
#
# Epoch 39/50 88/88 [==============================] - 22s 0.3s/step - loss: 1.1015 - accuracy: 0.6654 - precision: 0.6734 - recall: 0.6654 - f1: 0.6636 - val_loss: 1.1496 - val_accuracy: 0.6707 - val_precision: 0.6879 - val_recall: 0.6707 - val_f1: 0.6710
#
# Epoch 40/50 88/88 [==============================] - 22s 0.2s/step - loss: 1.0875 - accuracy: 0.6689 - precision: 0.6787 - recall: 0.6689 - f1: 0.6668 - val_loss: 1.1376 - val_accuracy: 0.6734 - val_precision: 0.6846 - val_recall: 0.6734 - val_f1: 0.6732
#
# Epoch 41/50 88/88 [==============================] - 22s 0.2s/step - loss: 1.0847 - accuracy: 0.6663 - precision: 0.6719 - recall: 0.6663 - f1: 0.6642 - val_loss: 1.1175 - val_accuracy: 0.6801 - val_precision: 0.6967 - val_recall: 0.6801 - val_f1: 0.6823
#
# Epoch 42/50 88/88 [==============================] - 22s 0.3s/step - loss: 1.0774 - accuracy: 0.6766 - precision: 0.6842 - recall: 0.6766 - f1: 0.6750 - val_loss: 1.1224 - val_accuracy: 0.6909 - val_precision: 0.7136 - val_recall: 0.6909 - val_f1: 0.6929
#
# Epoch 43/50 88/88 [==============================] - 22s 0.2s/step - loss: 1.0714 - accuracy: 0.6700 - precision: 0.6797 - recall: 0.6700 - f1: 0.6680 - val_loss: 1.0946 - val_accuracy: 0.6882 - val_precision: 0.7046 - val_recall: 0.6882 - val_f1: 0.6888
#
# Epoch 44/50 88/88 [==============================] - 22s 0.2s/step - loss: 1.0606 - accuracy: 0.6816 - precision: 0.6893 - recall: 0.6816 - f1: 0.6802 - val_loss: 1.1112 - val_accuracy: 0.6841 - val_precision: 0.7020 - val_recall: 0.6841 - val_f1: 0.6858
#
# Epoch 45/50 88/88 [==============================] - 22s 0.2s/step - loss: 1.0535 - accuracy: 0.6834 - precision: 0.6900 - recall: 0.6834 - f1: 0.6809 - val_loss: 1.0718 - val_accuracy: 0.6909 - val_precision: 0.7052 - val_recall: 0.6909 - val_f1: 0.6925
#
# Epoch 46/50 88/88 [==============================] - 22s 0.3s/step - loss: 1.0484 - accuracy: 0.6916 - precision: 0.6990 - recall: 0.6916 - f1: 0.6899 - val_loss: 1.0676 - val_accuracy: 0.6935 - val_precision: 0.7122 - val_recall: 0.6935 - val_f1: 0.6946
#
# Epoch 47/50 88/88 [==============================] - 22s 0.3s/step - loss: 1.0343 - accuracy: 0.6914 - precision: 0.7006 - recall: 0.6914 - f1: 0.6897 - val_loss: 1.0524 - val_accuracy: 0.6895 - val_precision: 0.7086 - val_recall: 0.6895 - val_f1: 0.6887
#
# Epoch 48/50 88/88 [==============================] - 22s 0.2s/step - loss: 1.0347 - accuracy: 0.7012 - precision: 0.7090 - recall: 0.7012 - f1: 0.6993 - val_loss: 1.0585 - val_accuracy: 0.6989 - val_precision: 0.7203 - val_recall: 0.6989 - val_f1: 0.6998
#
# Epoch 49/50 88/88 [==============================] - 22s 0.3s/step - loss: 1.0265 - accuracy: 0.7016 - precision: 0.7081 - recall: 0.7016 - f1: 0.6996 - val_loss: 1.0559 - val_accuracy: 0.6909 - val_precision: 0.7186 - val_recall: 0.6909 - val_f1: 0.6938
#
# Epoch 50/50 88/88 [==============================] - 22s 0.2s/step - loss: 1.0145 - accuracy: 0.7087 - precision: 0.7154 - recall: 0.7087 - f1: 0.7070 - val_loss: 1.0234 - val_accuracy: 0.7070 - val_precision: 0.7222 - val_recall: 0.7070 - val_f1: 0.7084
#
#
# ============================================================
#   TEST EVALUATION
# ============================================================
#   loss      : 0.9946
#   accuracy  : 0.7221
#   precision : 0.7368
#   recall    : 0.7221
#   f1_score  : 0.7237
# ============================================================
#
# Classification Report:
#                        precision    recall  f1-score   support
#
# bacterial_leaf_blight     0.8020    0.6000    0.6864       135
#            brown_spot     0.9048    0.7651    0.8291       149
#               healthy     0.6382    0.8017    0.7106       121
#            leaf_blast     0.6466    0.6825    0.6641       126
#            leaf_scald     0.6148    0.6757    0.6438       111
#     narrow_brown_spot     0.7658    0.8252    0.7944       103
#
#              accuracy                         0.7221       745
#             macro avg     0.7287    0.7250    0.7214       745
#          weighted avg     0.7368    0.7221    0.7237       745
#
#
#   ── Model Statistics: MobileNetV2 ──
#   Total Params (M)      : 2.2316
#   Trainable Params (M)  : 2.2316
#   Disk Size (MB)        : 8.7469
#   FLOPs (G)             : 0.5992
#   Inference (ms)        : 11.6912
#   FPS                   : 85.53
#   All results saved -> Model\MobileNetV2/
#     MobileNetV2_weights.pth
#     MobileNetV2_history.json
#     MobileNetV2_stats.json
#     MobileNetV2_test_metrics.json
#     MobileNetV2_classification_report.txt
#
# MobileNetV2 done.

# %%
# =============================================================================
#  MODEL 4 : InceptionV3
# =============================================================================
print('=' * 70)
print('  MODEL: InceptionV3')
print('=' * 70)

# ── Transforms ────────────────────────────────────────────────
inception_train_t = transforms.Compose([
    transforms.Resize(IMAGE_SIZE),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(25),
    transforms.RandomAffine(
        degrees=0,
        translate=(0.2, 0.2),
        scale=(0.7, 1.3),
        shear=8.5,
    ),
    transforms.ColorJitter(brightness=0.3),
    transforms.ToTensor(),
    MINUSONE_NORM,
])
inception_val_t = transforms.Compose([
    transforms.Resize(IMAGE_SIZE),
    transforms.ToTensor(),
    MINUSONE_NORM,
])

inception_train_loader, inception_val_loader, inception_test_loader = make_loaders(
    inception_train_t, inception_val_t
)

# ── Architecture ──────────────────────────────────────────────
# weights=None  → random initialisation, train from scratch
# base_model.trainable = True  → all layers are trainable (PyTorch default)
# aux_logits=False: avoids the auxiliary branch which crashes on 224x224 inputs
# when training from scratch (no pretrained checkpoint needed).
def build_inceptionv3(num_classes=NUM_CLASSES):
    model = torchvision.models.inception_v3(
        weights=None,       # no ImageNet weights
        aux_logits=False    # disable aux branch — safe without pretrained weights
    )
    for p in model.parameters():  # all layers trainable
        p.requires_grad = True
    model.fc = nn.Linear(model.fc.in_features, num_classes)
    return model

inception_model = build_inceptionv3(NUM_CLASSES).to(DEVICE)
print(f'Trainable params : {sum(p.numel() for p in inception_model.parameters() if p.requires_grad):,}')

inception_history = train_model(
    inception_model, 'InceptionV3', inception_train_loader, inception_val_loader
)
inception_test_preds, inception_test_labels = evaluate_on_test(inception_model, inception_test_loader)
inception_stats = compute_model_stats(inception_model, 'InceptionV3')
save_all_results(inception_model, 'InceptionV3', inception_history, inception_stats,
                 inception_test_preds, inception_test_labels)

del inception_model, inception_train_loader, inception_val_loader, inception_test_loader
if DEVICE.type == 'cuda': torch.cuda.empty_cache()
print('\nInceptionV3 done.\n')
# Out:
# ======================================================================
#   MODEL: InceptionV3
# ======================================================================
# Trainable params : 21,797,862
#
# Model  : InceptionV3
# Train batches : 88  |  Val batches : 12
# Device : cuda  (NVIDIA RTX 5000 Ada Generation)
# --------------------------------------------------------------------------------------------------------------
# Epoch 1/50 88/88 [==============================] - 35s 0.4s/step - loss: 1.8253 - accuracy: 0.1945 - precision: 0.2087 - recall: 0.1945 - f1: 0.1769 - val_loss: 1.7443 - val_accuracy: 0.2890 - val_precision: 0.3177 - val_recall: 0.2890 - val_f1: 0.2649
#
# Epoch 2/50 88/88 [==============================] - 29s 0.3s/step - loss: 1.7694 - accuracy: 0.2511 - precision: 0.2538 - recall: 0.2511 - f1: 0.2483 - val_loss: 1.6992 - val_accuracy: 0.3763 - val_precision: 0.3847 - val_recall: 0.3763 - val_f1: 0.3618
#
# Epoch 3/50 88/88 [==============================] - 29s 0.3s/step - loss: 1.7315 - accuracy: 0.2956 - precision: 0.2908 - recall: 0.2956 - f1: 0.2911 - val_loss: 1.6571 - val_accuracy: 0.4341 - val_precision: 0.4363 - val_recall: 0.4341 - val_f1: 0.4130
#
# Epoch 4/50 88/88 [==============================] - 28s 0.3s/step - loss: 1.6899 - accuracy: 0.3362 - precision: 0.3326 - recall: 0.3362 - f1: 0.3332 - val_loss: 1.6103 - val_accuracy: 0.4624 - val_precision: 0.4529 - val_recall: 0.4624 - val_f1: 0.4400
#
# Epoch 5/50 88/88 [==============================] - 29s 0.3s/step - loss: 1.6600 - accuracy: 0.3528 - precision: 0.3481 - recall: 0.3528 - f1: 0.3487 - val_loss: 1.5822 - val_accuracy: 0.4785 - val_precision: 0.4710 - val_recall: 0.4785 - val_f1: 0.4470
#
# Epoch 6/50 88/88 [==============================] - 28s 0.3s/step - loss: 1.6250 - accuracy: 0.3796 - precision: 0.3799 - recall: 0.3796 - f1: 0.3780 - val_loss: 1.5418 - val_accuracy: 0.5054 - val_precision: 0.4988 - val_recall: 0.5054 - val_f1: 0.4795
#
# Epoch 7/50 88/88 [==============================] - 29s 0.3s/step - loss: 1.5984 - accuracy: 0.3919 - precision: 0.3900 - recall: 0.3919 - f1: 0.3886 - val_loss: 1.5167 - val_accuracy: 0.4798 - val_precision: 0.4680 - val_recall: 0.4798 - val_f1: 0.4488
#
# Epoch 8/50 88/88 [==============================] - 29s 0.3s/step - loss: 1.5708 - accuracy: 0.4110 - precision: 0.4146 - recall: 0.4110 - f1: 0.4101 - val_loss: 1.4702 - val_accuracy: 0.5215 - val_precision: 0.5253 - val_recall: 0.5215 - val_f1: 0.4946
#
# Epoch 9/50 88/88 [==============================] - 28s 0.3s/step - loss: 1.5345 - accuracy: 0.4303 - precision: 0.4365 - recall: 0.4303 - f1: 0.4278 - val_loss: 1.4375 - val_accuracy: 0.5121 - val_precision: 0.5159 - val_recall: 0.5121 - val_f1: 0.4851
#
# Epoch 10/50 88/88 [==============================] - 28s 0.3s/step - loss: 1.5149 - accuracy: 0.4439 - precision: 0.4475 - recall: 0.4439 - f1: 0.4389 - val_loss: 1.4069 - val_accuracy: 0.5551 - val_precision: 0.5635 - val_recall: 0.5551 - val_f1: 0.5334
#
# Epoch 11/50 88/88 [==============================] - 29s 0.3s/step - loss: 1.4856 - accuracy: 0.4546 - precision: 0.4592 - recall: 0.4546 - f1: 0.4507 - val_loss: 1.3673 - val_accuracy: 0.5538 - val_precision: 0.5560 - val_recall: 0.5538 - val_f1: 0.5287
#
# Epoch 12/50 88/88 [==============================] - 28s 0.3s/step - loss: 1.4687 - accuracy: 0.4660 - precision: 0.4690 - recall: 0.4660 - f1: 0.4631 - val_loss: 1.3513 - val_accuracy: 0.5591 - val_precision: 0.5701 - val_recall: 0.5591 - val_f1: 0.5354
#
# Epoch 13/50 88/88 [==============================] - 28s 0.3s/step - loss: 1.4346 - accuracy: 0.4830 - precision: 0.4879 - recall: 0.4830 - f1: 0.4787 - val_loss: 1.3199 - val_accuracy: 0.5699 - val_precision: 0.5762 - val_recall: 0.5699 - val_f1: 0.5495
#
# Epoch 14/50 88/88 [==============================] - 29s 0.3s/step - loss: 1.4163 - accuracy: 0.4949 - precision: 0.4989 - recall: 0.4949 - f1: 0.4906 - val_loss: 1.2782 - val_accuracy: 0.5941 - val_precision: 0.6076 - val_recall: 0.5941 - val_f1: 0.5790
#
# Epoch 15/50 88/88 [==============================] - 28s 0.3s/step - loss: 1.3878 - accuracy: 0.5153 - precision: 0.5159 - recall: 0.5153 - f1: 0.5108 - val_loss: 1.2501 - val_accuracy: 0.6048 - val_precision: 0.6107 - val_recall: 0.6048 - val_f1: 0.5881
#
# Epoch 16/50 88/88 [==============================] - 28s 0.3s/step - loss: 1.3711 - accuracy: 0.5190 - precision: 0.5219 - recall: 0.5190 - f1: 0.5145 - val_loss: 1.2159 - val_accuracy: 0.6358 - val_precision: 0.6470 - val_recall: 0.6358 - val_f1: 0.6245
#
# Epoch 17/50 88/88 [==============================] - 29s 0.3s/step - loss: 1.3462 - accuracy: 0.5354 - precision: 0.5394 - recall: 0.5354 - f1: 0.5331 - val_loss: 1.1947 - val_accuracy: 0.6317 - val_precision: 0.6410 - val_recall: 0.6317 - val_f1: 0.6199
#
# Epoch 18/50 88/88 [==============================] - 29s 0.3s/step - loss: 1.3288 - accuracy: 0.5461 - precision: 0.5471 - recall: 0.5461 - f1: 0.5422 - val_loss: 1.1566 - val_accuracy: 0.6465 - val_precision: 0.6461 - val_recall: 0.6465 - val_f1: 0.6375
#
# Epoch 19/50 88/88 [==============================] - 29s 0.3s/step - loss: 1.3031 - accuracy: 0.5617 - precision: 0.5666 - recall: 0.5617 - f1: 0.5588 - val_loss: 1.1482 - val_accuracy: 0.6492 - val_precision: 0.6592 - val_recall: 0.6492 - val_f1: 0.6378
#
# Epoch 20/50 88/88 [==============================] - 29s 0.3s/step - loss: 1.2844 - accuracy: 0.5679 - precision: 0.5697 - recall: 0.5679 - f1: 0.5644 - val_loss: 1.1281 - val_accuracy: 0.6532 - val_precision: 0.6576 - val_recall: 0.6532 - val_f1: 0.6426
#
# Epoch 21/50 88/88 [==============================] - 28s 0.3s/step - loss: 1.2579 - accuracy: 0.5877 - precision: 0.5910 - recall: 0.5877 - f1: 0.5850 - val_loss: 1.1085 - val_accuracy: 0.6680 - val_precision: 0.6844 - val_recall: 0.6680 - val_f1: 0.6592
#
# Epoch 22/50 88/88 [==============================] - 29s 0.3s/step - loss: 1.2430 - accuracy: 0.5890 - precision: 0.5907 - recall: 0.5890 - f1: 0.5854 - val_loss: 1.0994 - val_accuracy: 0.6774 - val_precision: 0.6895 - val_recall: 0.6774 - val_f1: 0.6695
#
# Epoch 23/50 88/88 [==============================] - 28s 0.3s/step - loss: 1.2313 - accuracy: 0.6031 - precision: 0.6058 - recall: 0.6031 - f1: 0.6002 - val_loss: 1.0520 - val_accuracy: 0.7030 - val_precision: 0.7178 - val_recall: 0.7030 - val_f1: 0.6953
#
# Epoch 24/50 88/88 [==============================] - 28s 0.3s/step - loss: 1.1994 - accuracy: 0.6104 - precision: 0.6118 - recall: 0.6104 - f1: 0.6062 - val_loss: 1.0282 - val_accuracy: 0.7083 - val_precision: 0.7243 - val_recall: 0.7083 - val_f1: 0.7007
#
# Epoch 25/50 88/88 [==============================] - 29s 0.3s/step - loss: 1.1858 - accuracy: 0.6206 - precision: 0.6226 - recall: 0.6206 - f1: 0.6169 - val_loss: 1.0122 - val_accuracy: 0.7164 - val_precision: 0.7270 - val_recall: 0.7164 - val_f1: 0.7090
#
# Epoch 26/50 88/88 [==============================] - 28s 0.3s/step - loss: 1.1844 - accuracy: 0.6225 - precision: 0.6267 - recall: 0.6225 - f1: 0.6197 - val_loss: 1.0003 - val_accuracy: 0.7097 - val_precision: 0.7255 - val_recall: 0.7097 - val_f1: 0.7004
#
# Epoch 27/50 88/88 [==============================] - 29s 0.3s/step - loss: 1.1596 - accuracy: 0.6311 - precision: 0.6354 - recall: 0.6311 - f1: 0.6283 - val_loss: 0.9786 - val_accuracy: 0.7285 - val_precision: 0.7399 - val_recall: 0.7285 - val_f1: 0.7207
#
# Epoch 28/50 88/88 [==============================] - 28s 0.3s/step - loss: 1.1599 - accuracy: 0.6325 - precision: 0.6348 - recall: 0.6325 - f1: 0.6280 - val_loss: 0.9626 - val_accuracy: 0.7339 - val_precision: 0.7437 - val_recall: 0.7339 - val_f1: 0.7261
#
# Epoch 29/50 88/88 [==============================] - 29s 0.3s/step - loss: 1.1232 - accuracy: 0.6473 - precision: 0.6496 - recall: 0.6473 - f1: 0.6436 - val_loss: 0.9256 - val_accuracy: 0.7702 - val_precision: 0.7785 - val_recall: 0.7702 - val_f1: 0.7647
#
# Epoch 30/50 88/88 [==============================] - 28s 0.3s/step - loss: 1.1239 - accuracy: 0.6511 - precision: 0.6536 - recall: 0.6511 - f1: 0.6477 - val_loss: 0.9151 - val_accuracy: 0.7755 - val_precision: 0.7818 - val_recall: 0.7755 - val_f1: 0.7699
#
# Epoch 31/50 88/88 [==============================] - 29s 0.3s/step - loss: 1.1066 - accuracy: 0.6546 - precision: 0.6591 - recall: 0.6546 - f1: 0.6515 - val_loss: 0.9052 - val_accuracy: 0.7661 - val_precision: 0.7740 - val_recall: 0.7661 - val_f1: 0.7595
#
# Epoch 32/50 88/88 [==============================] - 28s 0.3s/step - loss: 1.1020 - accuracy: 0.6579 - precision: 0.6600 - recall: 0.6579 - f1: 0.6545 - val_loss: 0.8854 - val_accuracy: 0.7823 - val_precision: 0.7872 - val_recall: 0.7823 - val_f1: 0.7784
#
# Epoch 33/50 88/88 [==============================] - 29s 0.3s/step - loss: 1.0884 - accuracy: 0.6707 - precision: 0.6711 - recall: 0.6707 - f1: 0.6670 - val_loss: 0.8764 - val_accuracy: 0.7930 - val_precision: 0.7955 - val_recall: 0.7930 - val_f1: 0.7871
#
# Epoch 34/50 88/88 [==============================] - 29s 0.3s/step - loss: 1.0587 - accuracy: 0.6805 - precision: 0.6832 - recall: 0.6805 - f1: 0.6772 - val_loss: 0.8813 - val_accuracy: 0.7809 - val_precision: 0.7914 - val_recall: 0.7809 - val_f1: 0.7792
#
# Epoch 35/50 88/88 [==============================] - 29s 0.3s/step - loss: 1.0681 - accuracy: 0.6820 - precision: 0.6831 - recall: 0.6820 - f1: 0.6788 - val_loss: 0.8704 - val_accuracy: 0.8078 - val_precision: 0.8109 - val_recall: 0.8078 - val_f1: 0.8049
#
# Epoch 36/50 88/88 [==============================] - 29s 0.3s/step - loss: 1.0632 - accuracy: 0.6802 - precision: 0.6824 - recall: 0.6802 - f1: 0.6779 - val_loss: 0.8536 - val_accuracy: 0.8091 - val_precision: 0.8155 - val_recall: 0.8091 - val_f1: 0.8065
#
# Epoch 37/50 88/88 [==============================] - 29s 0.3s/step - loss: 1.0470 - accuracy: 0.6896 - precision: 0.6925 - recall: 0.6896 - f1: 0.6869 - val_loss: 0.8455 - val_accuracy: 0.8118 - val_precision: 0.8173 - val_recall: 0.8118 - val_f1: 0.8097
#
# Epoch 38/50 88/88 [==============================] - 28s 0.3s/step - loss: 1.0208 - accuracy: 0.6994 - precision: 0.7022 - recall: 0.6994 - f1: 0.6967 - val_loss: 0.8332 - val_accuracy: 0.8239 - val_precision: 0.8303 - val_recall: 0.8239 - val_f1: 0.8204
#
# Epoch 39/50 88/88 [==============================] - 29s 0.3s/step - loss: 1.0220 - accuracy: 0.7036 - precision: 0.7050 - recall: 0.7036 - f1: 0.7001 - val_loss: 0.8154 - val_accuracy: 0.8199 - val_precision: 0.8255 - val_recall: 0.8199 - val_f1: 0.8179
#
# Epoch 40/50 88/88 [==============================] - 28s 0.3s/step - loss: 1.0158 - accuracy: 0.7109 - precision: 0.7134 - recall: 0.7109 - f1: 0.7088 - val_loss: 0.8106 - val_accuracy: 0.8387 - val_precision: 0.8418 - val_recall: 0.8387 - val_f1: 0.8378
#
# Epoch 41/50 88/88 [==============================] - 29s 0.3s/step - loss: 1.0116 - accuracy: 0.7123 - precision: 0.7135 - recall: 0.7123 - f1: 0.7099 - val_loss: 0.8013 - val_accuracy: 0.8401 - val_precision: 0.8442 - val_recall: 0.8401 - val_f1: 0.8377
#
# Epoch 42/50 88/88 [==============================] - 29s 0.3s/step - loss: 0.9896 - accuracy: 0.7248 - precision: 0.7261 - recall: 0.7248 - f1: 0.7224 - val_loss: 0.7883 - val_accuracy: 0.8495 - val_precision: 0.8576 - val_recall: 0.8495 - val_f1: 0.8474
#
# Epoch 43/50 88/88 [==============================] - 28s 0.3s/step - loss: 0.9771 - accuracy: 0.7344 - precision: 0.7373 - recall: 0.7344 - f1: 0.7319 - val_loss: 0.7765 - val_accuracy: 0.8602 - val_precision: 0.8670 - val_recall: 0.8602 - val_f1: 0.8589
#
# Epoch 44/50 88/88 [==============================] - 26s 0.3s/step - loss: 0.9809 - accuracy: 0.7309 - precision: 0.7320 - recall: 0.7309 - f1: 0.7280 - val_loss: 0.7700 - val_accuracy: 0.8575 - val_precision: 0.8622 - val_recall: 0.8575 - val_f1: 0.8566
#
# Epoch 45/50 88/88 [==============================] - 26s 0.3s/step - loss: 0.9766 - accuracy: 0.7273 - precision: 0.7281 - recall: 0.7273 - f1: 0.7247 - val_loss: 0.7696 - val_accuracy: 0.8683 - val_precision: 0.8727 - val_recall: 0.8683 - val_f1: 0.8677
#
# Epoch 46/50 88/88 [==============================] - 26s 0.3s/step - loss: 0.9623 - accuracy: 0.7401 - precision: 0.7408 - recall: 0.7401 - f1: 0.7376 - val_loss: 0.7672 - val_accuracy: 0.8508 - val_precision: 0.8557 - val_recall: 0.8508 - val_f1: 0.8499
#
# Epoch 47/50 88/88 [==============================] - 26s 0.3s/step - loss: 0.9613 - accuracy: 0.7382 - precision: 0.7402 - recall: 0.7382 - f1: 0.7366 - val_loss: 0.7540 - val_accuracy: 0.8616 - val_precision: 0.8638 - val_recall: 0.8616 - val_f1: 0.8600
#
# Epoch 48/50 88/88 [==============================] - 27s 0.3s/step - loss: 0.9446 - accuracy: 0.7476 - precision: 0.7474 - recall: 0.7476 - f1: 0.7450 - val_loss: 0.7758 - val_accuracy: 0.8468 - val_precision: 0.8523 - val_recall: 0.8468 - val_f1: 0.8459
#
# Epoch 49/50 88/88 [==============================] - 26s 0.3s/step - loss: 0.9459 - accuracy: 0.7533 - precision: 0.7550 - recall: 0.7533 - f1: 0.7517 - val_loss: 0.7516 - val_accuracy: 0.8629 - val_precision: 0.8656 - val_recall: 0.8629 - val_f1: 0.8622
#
# Epoch 50/50 88/88 [==============================] - 27s 0.3s/step - loss: 0.9407 - accuracy: 0.7494 - precision: 0.7504 - recall: 0.7494 - f1: 0.7469 - val_loss: 0.7368 - val_accuracy: 0.8723 - val_precision: 0.8764 - val_recall: 0.8723 - val_f1: 0.8719
#
#
# ============================================================
#   TEST EVALUATION
# ============================================================
#   loss      : 0.7490
#   accuracy  : 0.8577
#   precision : 0.8603
#   recall    : 0.8577
#   f1_score  : 0.8575
# ============================================================
#
# Classification Report:
#                        precision    recall  f1-score   support
#
# bacterial_leaf_blight     0.9322    0.8148    0.8696       135
#            brown_spot     0.8467    0.8523    0.8495       149
#               healthy     0.7956    0.9008    0.8450       121
#            leaf_blast     0.8235    0.7778    0.8000       126
#            leaf_scald     0.8739    0.9369    0.9043       111
#     narrow_brown_spot     0.8922    0.8835    0.8878       103
#
#              accuracy                         0.8577       745
#             macro avg     0.8607    0.8610    0.8594       745
#          weighted avg     0.8603    0.8577    0.8575       745
#
#
#   ── Model Statistics: InceptionV3 ──
#   Total Params (M)      : 21.7979
#   Trainable Params (M)  : 21.7979
#   Disk Size (MB)        : 83.4727
#   FLOPs (G)             : 5.6718
#   Inference (ms)        : 24.0295
#   FPS                   : 41.62
#   All results saved -> Model\InceptionV3/
#     InceptionV3_weights.pth
#     InceptionV3_history.json
#     InceptionV3_stats.json
#     InceptionV3_test_metrics.json
#     InceptionV3_classification_report.txt
#
# InceptionV3 done.

# %%
# =============================================================================
#  TRAINING COMPLETE — all results saved under Model/<ModelName>/
# =============================================================================
import glob as _glob

print('=' * 70)
print('  ALL MODELS TRAINING COMPLETE')
print('=' * 70)
print()
print('Saved files (model-wise folders):')
for p in sorted(_glob.glob(os.path.join(OUTPUT_DIR, '**', '*'), recursive=True)):
    if os.path.isfile(p):
        size_kb = os.path.getsize(p) / 1024
        rel = os.path.relpath(p, OUTPUT_DIR)
        print(f'  {rel:<65}  ({size_kb:.1f} KB)')

print()
print('Each model folder contains:')
print('  <ModelName>_weights.pth               — model weights')
print('  <ModelName>_history.json              — train/val metrics per epoch')
print('  <ModelName>_stats.json                — params, disk size, FLOPs, latency, FPS')
print('  <ModelName>_test_metrics.json         — test accuracy, precision, recall, F1')
print('  <ModelName>_classification_report.txt — per-class report')
print()
print('-- How to reload weights (example: ResNet50) --')
print("  model = build_resnet50(NUM_CLASSES)")
print("  model.load_state_dict(torch.load('Model/ResNet50/ResNet50_weights.pth', map_location=DEVICE))")
print("  model.to(DEVICE).eval()")
print()
print('-- How to reload history (example: ResNet50) --')
print("  with open('Model/ResNet50/ResNet50_history.json') as f:")
print("      h = json.load(f)")
print("  # h['val_accuracy'], h['val_f1'], h['loss'], ...")
# Out:
# ======================================================================
#   ALL MODELS TRAINING COMPLETE
# ======================================================================
#
# Saved files (model-wise folders):
#   InceptionV3\InceptionV3_classification_report.txt                  (0.6 KB)
#   InceptionV3\InceptionV3_history.json                               (7.5 KB)
#   InceptionV3\InceptionV3_stats.json                                 (0.2 KB)
#   InceptionV3\InceptionV3_test_metrics.json                          (0.1 KB)
#   InceptionV3\InceptionV3_weights.pth                                (85480.6 KB)
#   MobileNetV2\MobileNetV2_classification_report.txt                  (0.6 KB)
#   MobileNetV2\MobileNetV2_history.json                               (7.5 KB)
#   MobileNetV2\MobileNetV2_stats.json                                 (0.2 KB)
#   MobileNetV2\MobileNetV2_test_metrics.json                          (0.1 KB)
#   MobileNetV2\MobileNetV2_weights.pth                                (8959.3 KB)
#   ResNet50\ResNet50_classification_report.txt                        (0.6 KB)
#   ResNet50\ResNet50_history.json                                     (6.2 KB)
#   ResNet50\ResNet50_stats.json                                       (0.2 KB)
#   ResNet50\ResNet50_test_metrics.json                                (0.1 KB)
#   ResNet50\ResNet50_weights.pth                                      (92189.3 KB)
#   VGG16\VGG16_classification_report.txt                              (0.6 KB)
#   VGG16\VGG16_history.json                                           (7.5 KB)
#   VGG16\VGG16_stats.json                                             (0.2 KB)
#   VGG16\VGG16_test_metrics.json                                      (0.1 KB)
#   VGG16\VGG16_weights.pth                                            (58528.1 KB)
#
# Each model folder contains:
#   <ModelName>_weights.pth               — model weights
#   <ModelName>_history.json              — train/val metrics per epoch
#   <ModelName>_stats.json                — params, disk size, FLOPs, latency, FPS
#   <ModelName>_test_metrics.json         — test accuracy, precision, recall, F1
#   <ModelName>_classification_report.txt — per-class report
#
# -- How to reload weights (example: ResNet50) --
#   model = build_resnet50(NUM_CLASSES)
#   model.load_state_dict(torch.load('Model/ResNet50/ResNet50_weights.pth', map_location=DEVICE))
#   model.to(DEVICE).eval()
#
# -- How to reload history (example: ResNet50) --
#   with open('Model/ResNet50/ResNet50_history.json') as f:
#       h = json.load(f)
#   # h['val_accuracy'], h['val_f1'], h['loss'], ...
